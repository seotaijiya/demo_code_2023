# %%
from __future__ import absolute_import, division, print_function

import numpy as np
import time
import itertools
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
import torch.optim as optim

import seaborn as sns


from torch.utils.data import Dataset
from torch.utils.data import DataLoader

np.set_printoptions(precision=3)

# %% [markdown]
# ### 1. Generate channel samples

# %%
## Generate location of D2D users and CUE
def loc_init(Size_area, Dist_TX_RX, Num_D2D, Num_Ch):
    tx_loc = Size_area * (np.random.rand(Num_D2D, 2) - 0.5)
    rx_loc = np.zeros((Num_D2D + 1, 2))
    for i in range(Num_D2D):
        temp_chan = Feasible_Loc_Init(tx_loc[i, :], Size_area, Dist_TX_RX)
        rx_loc[i, :] = temp_chan
    tx_loc_CUE = Size_area * (np.random.rand(Num_Ch, 2) - 0.5)

    return rx_loc, tx_loc, tx_loc_CUE

# %%
## Check the feasibililty of generated location
def Feasible_Loc_Init(Cur_loc, Size_area, Dist_TX_RX):
    temp_dist = 2 * Dist_TX_RX * (np.random.rand(1, 2) - 0.5)
    temp_chan = Cur_loc + temp_dist
    while (np.max(abs(temp_chan)) > Size_area / 2) | (np.linalg.norm(temp_dist) > Dist_TX_RX):
        temp_dist = 2 * Dist_TX_RX * (np.random.rand(1, 2) - 0.5)
        temp_chan = Cur_loc + temp_dist
    return temp_chan

# %%
## Generate sample data for channel
def ch_gen(Size_area, D2D_dist, Num_D2D, Num_Ch, Num_samples, PL_alpha=38., PL_const=34.5):
    ch_w_fading = []
    rx_loc_mat = []
    tx_loc_mat = []
    CUE_loc_mat = []
    
    ch_w_fading = []

    ## Perform initialization just once and the rest channel is generated by moving users
    rx_loc, tx_loc, tx_loc_CUE = loc_init(Size_area, D2D_dist, Num_D2D, Num_Ch)

    ## Calculate the
    for i in range(Num_samples):

        rx_loc, tx_loc, tx_loc_CUE = loc_init(Size_area, D2D_dist, Num_D2D, Num_Ch)

        ch_w_temp_band = []
        for j in range(Num_Ch):
            tx_loc_with_CUE = np.vstack((tx_loc, tx_loc_CUE[j]))
            ## generate distance_vector
            dist_vec = rx_loc.reshape(Num_D2D + 1, 1, 2) - tx_loc_with_CUE
            dist_vec = np.linalg.norm(dist_vec, axis=2)
            dist_vec = np.maximum(dist_vec, 3)

            # find path loss // shadowing is not considered
            pu_ch_gain_db = - PL_const - PL_alpha * np.log10(dist_vec)
            pu_ch_gain = 10 ** (pu_ch_gain_db / 10)

            multi_fading = 0.5 * np.random.randn(Num_D2D + 1, Num_D2D + 1) ** 2 + 0.5 * np.random.randn(Num_D2D + 1,
                                                                                                        Num_D2D + 1) ** 2
            final_ch = np.maximum(pu_ch_gain * multi_fading, np.exp(-30))
            ch_w_temp_band.append(np.transpose(final_ch))

        ch_w_fading.append(ch_w_temp_band)
        rx_loc_mat.append(rx_loc)
        tx_loc_mat.append(tx_loc)
        CUE_loc_mat.append(tx_loc_CUE)
        
    return np.array(ch_w_fading), np.array(rx_loc_mat), np.array(tx_loc_mat), np.array(CUE_loc_mat)

# %% [markdown]
# #### Simulation setting

# %%
## Simulation setting for sample channel data

Size_area = 50.0
D2D_dist = 10
Num_user = 2
Num_channel = 2
num_samples_tr = 30

# %% [markdown]
# #### A. Randomly generated training data - 30 sample

# %%
ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr)

# %% [markdown]
# #### B. Check the location of users

# %%
rx_mat[0]
# Out:
# array([[  3.709,  11.233],
#        [ 13.062, -22.761],
#        [  0.   ,   0.   ]])

# %%
tx_mat[0]
# Out:
# array([[  2.717,   5.892],
#        [ 18.583, -19.615]])

# %%
CUE_mat[0]
# Out:
# array([[ -0.638,  21.951],
#        [-16.076,  15.432]])

# %%
rx_mat.shape
# Out:
# (30, 3, 2)

# %% [markdown]
# #### C. Check the location and transmit pairs

# %%
## Change the shape of location matrice to facilitate the plot
## Squeeze all the location of different sample
rx_mat_temp = rx_mat[:,:-1,:].reshape(num_samples_tr*Num_user, -1)
tx_mat_temp = tx_mat.reshape(num_samples_tr*Num_user, -1)
CUE_mat_temp = CUE_mat.reshape(num_samples_tr*Num_channel, -1)

# %%
plt.figure(figsize=(10,5))

plt.scatter(rx_mat_temp[:, 0], rx_mat_temp[:, 1], marker='^', label='Rx')
plt.scatter(tx_mat_temp[:, 0], tx_mat_temp[:, 1], marker='o', label='Tx')
plt.scatter(CUE_mat_temp[:, 0], CUE_mat_temp[:, 1], marker='+', label='CUE')
plt.legend(loc='upper left')

for i in range(rx_mat_temp.shape[0]):
    plt.plot([rx_mat_temp[i, 0], tx_mat_temp[i, 0]], [rx_mat_temp[i,1], tx_mat_temp[i, 1]])

# %% [markdown]
# #### D. plotting by varying the distance between communicating users

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
D2D_dist_mat = [1, 5, 10, 50]
for i in range(4):
    D2D_dist = D2D_dist_mat[i]
    ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr)
    rx_mat_temp = rx_mat[:,:-1,:].reshape(num_samples_tr*Num_user, -1)
    tx_mat_temp = tx_mat.reshape(num_samples_tr*Num_user, -1)
    CUE_mat_temp = CUE_mat.reshape(num_samples_tr*Num_channel, -1)

    axes[i//2, i%2].scatter(rx_mat_temp[:, 0], rx_mat_temp[:, 1], marker='^', label='Rx')
    axes[i//2, i%2].scatter(tx_mat_temp[:, 0], tx_mat_temp[:, 1], marker='o', label='Tx')
    axes[i//2, i%2].scatter(CUE_mat_temp[:, 0], CUE_mat_temp[:, 1], marker='+', label='CUE')
    axes[i//2, i%2].legend(loc='upper left')
    axes[i//2, i%2].set_title(f"D2D distance = {D2D_dist}m", fontsize=14)

    for j in range(rx_mat_temp.shape[0]):
        axes[i//2, i%2].plot([rx_mat_temp[j, 0], tx_mat_temp[j, 0]], [rx_mat_temp[j,1], tx_mat_temp[j, 1]])

# %% [markdown]
# #### E. Check the channel statistics of channel gain

# %%
D2D_dist = 1

# %%
ch_mat, _, _ , _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))

# %%
ch_mat.shape
# Out:
# (10000, 2, 3, 3)

# %%
sig_chan = np.ravel(ch_mat[:,:,:-1,:-1].diagonal(0, 2, 3))

# %% [markdown]
# #### Plotting in decimal

# %%
plt.figure(figsize=(10,5))
plt.hist(sig_chan, bins=20, density=True)
# Out:
# (array([1.407e+05, 8.357e+04, 4.876e+04, 2.783e+04, 1.673e+04, 9.864e+03,
#         5.683e+03, 3.354e+03, 1.963e+03, 1.024e+03, 8.874e+02, 4.949e+02,
#         1.280e+02, 1.195e+02, 7.680e+01, 3.413e+01, 3.413e+01, 0.000e+00,
#         1.707e+01, 1.707e+01]),
#  array([1.914e-10, 2.930e-06, 5.860e-06, 8.789e-06, 1.172e-05, 1.465e-05,
#         1.758e-05, 2.051e-05, 2.344e-05, 2.637e-05, 2.930e-05, 3.223e-05,
#         3.516e-05, 3.809e-05, 4.102e-05, 4.395e-05, 4.688e-05, 4.981e-05,
#         5.274e-05, 5.567e-05, 5.860e-05]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=sig_chan, kde=True, stat="percent")
# Out:
# <AxesSubplot:ylabel='Percent'>

# %% [markdown]
# #### Normalizing through dB operation

# %%
plt.figure(figsize=(10,5))
plt.hist(10*np.log10(sig_chan), bins=20, density=True)
# Out:
# (array([1.823e-05, 3.646e-05, 3.646e-05, 7.292e-05, 1.367e-04, 2.187e-04,
#         5.560e-04, 9.023e-04, 1.914e-03, 3.281e-03, 5.870e-03, 1.058e-02,
#         1.933e-02, 3.491e-02, 5.488e-02, 7.645e-02, 8.273e-02, 5.478e-02,
#         1.666e-02, 1.212e-03]),
#  array([-97.179, -94.437, -91.694, -88.951, -86.208, -83.465, -80.722,
#         -77.979, -75.236, -72.493, -69.75 , -67.008, -64.265, -61.522,
#         -58.779, -56.036, -53.293, -50.55 , -47.807, -45.064, -42.321]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=10*np.log10(sig_chan), kde=True, stat="percent")
# Out:
# <AxesSubplot:ylabel='Percent'>

# %% [markdown]
# #### F. Check the channel statistics of interference

# %%
int_temp = np.triu(ch_mat, 1)

# %%
int_temp.shape
# Out:
# (10000, 2, 3, 3)

# %%
int_chan = int_temp[:,:,:,:-1][int_temp[:,:,:,:-1]!=0]

# %%
plt.figure(figsize=(10,5))
plt.hist(int_chan, bins=20, density=True)
# Out:
# (array([5.910e+05, 3.810e+03, 1.980e+03, 7.201e+02, 6.301e+02, 5.401e+02,
#         2.700e+02, 3.000e+02, 1.200e+02, 2.400e+02, 1.500e+02, 6.001e+01,
#         6.001e+01, 3.000e+01, 6.001e+01, 0.000e+00, 0.000e+00, 3.000e+01,
#         0.000e+00, 3.000e+01]),
#  array([9.358e-14, 1.666e-06, 3.333e-06, 4.999e-06, 6.666e-06, 8.332e-06,
#         9.999e-06, 1.167e-05, 1.333e-05, 1.500e-05, 1.666e-05, 1.833e-05,
#         2.000e-05, 2.166e-05, 2.333e-05, 2.500e-05, 2.666e-05, 2.833e-05,
#         3.000e-05, 3.166e-05, 3.333e-05]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(10,5))
plt.hist(10*np.log10(int_chan), bins=20, density=True)
# Out:
# (array([9.355e-05, 2.339e-04, 5.145e-04, 8.770e-04, 3.111e-03, 7.554e-03,
#         1.641e-02, 2.973e-02, 3.931e-02, 3.954e-02, 3.212e-02, 2.212e-02,
#         1.443e-02, 1.083e-02, 6.724e-03, 4.069e-03, 2.748e-03, 2.117e-03,
#         9.940e-04, 3.508e-04]),
#  array([-130.288, -126.013, -121.737, -117.461, -113.185, -108.909,
#         -104.633, -100.358,  -96.082,  -91.806,  -87.53 ,  -83.254,
#          -78.978,  -74.703,  -70.427,  -66.151,  -61.875,  -57.599,
#          -53.323,  -49.048,  -44.772]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=10*np.log10(int_chan), kde=True, stat="percent")
# Out:
# <AxesSubplot:ylabel='Percent'>

# %%
cue_chan = int_temp[:,:,:,-1][int_temp[:,:,:,-1]!=0]

# %%
int_chan.shape
# Out:
# (20000,)

# %%
cue_chan.shape
# Out:
# (40000,)

# %%
plt.figure(figsize=(10,5))
plt.hist(10*np.log10(cue_chan), bins=20, density=True)
# Out:
# (array([2.313e-05, 1.156e-05, 7.517e-05, 2.197e-04, 7.170e-04, 1.700e-03,
#         4.938e-03, 1.289e-02, 2.648e-02, 4.589e-02, 5.000e-02, 3.610e-02,
#         2.180e-02, 1.224e-02, 7.505e-03, 4.470e-03, 2.880e-03, 1.926e-03,
#         1.203e-03, 2.139e-04]),
#  array([-130.288, -125.965, -121.641, -117.318, -112.994, -108.671,
#         -104.347, -100.024,  -95.7  ,  -91.377,  -87.053,  -82.73 ,
#          -78.406,  -74.083,  -69.759,  -65.436,  -61.112,  -56.789,
#          -52.465,  -48.142,  -43.818]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(10*np.log10(cue_chan), bins=20, alpha=0.5, label='CUE', density=True)
plt.hist(10*np.log10(int_chan), bins=20, alpha=0.5, label='Interference', density=True)
plt.hist(10*np.log10(sig_chan), bins=20, alpha=0.5, label='Signal', density=True)

plt.legend(loc='upper left')

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
D2D_dist_mat = [1, 5, 10, 50]
for i in range(4):
    D2D_dist = D2D_dist_mat[i]
    ch_mat, _, _ , _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))
    sig_chan = np.ravel(ch_mat[:,:,:-1,:-1].diagonal(0, 2, 3))
    int_temp = np.triu(ch_mat, 1)
    int_chan = int_temp[:,:,:,:-1][int_temp[:,:,:,:-1]!=0]
    cue_chan = int_temp[:,:,:,-1][int_temp[:,:,:,-1]!=0]

    axes[i//2, i%2].hist(10*np.log10(cue_chan), bins=20, alpha=0.5, label='Signal', density=True) 
    axes[i//2, i%2].hist(10*np.log10(int_chan), bins=20, alpha=0.5, label='Interference', density=True)
    axes[i//2, i%2].hist(10*np.log10(sig_chan), bins=20, alpha=0.5, label='Signal', density=True) 
    axes[i//2, i%2].legend(loc='upper left')
    axes[i//2, i%2].set_title(f"D2D distance = {D2D_dist}m", fontsize=14)

# %% [markdown]
# ### Calculate the data rate using the given channel and resource allocation

# %%
## Calculate data rate for single channel, single sample
def cal_RATE_one_sample_one_channel(channel, tx_power, noise):
    diag_ch = np.diag(channel)
    inter_ch = channel-np.diag(diag_ch)
    tot_ch = np.multiply(channel, np.expand_dims(tx_power, -1))
    int_ch = np.multiply(inter_ch, np.expand_dims(tx_power, -1))
    sig_ch = np.sum(tot_ch-int_ch, axis=1)
    int_ch = np.sum(int_ch, axis=1)
    SINR_val = np.divide(sig_ch, int_ch+noise)
    cap_val = np.log2(1.0+SINR_val)
    return cap_val

# %%
def cal_CUE_INTER_one_sample_one_channel(channel, tx_power):
    diag_ch = np.diag(channel)
    inter_ch = channel-np.diag(diag_ch)
    int_ch = np.multiply(inter_ch, np.expand_dims(tx_power, -1))
    int_ch = np.sum(int_ch, axis=1)
    return int_ch

# %%
D2D_dist = 10

# %% [markdown]
# #### Randomly generate channel matrix

# %%
ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))

# %% [markdown]
# #### Set all-one transmit power vector

# %%
tx_power_temp = np.ones((1, 3))
BW = 1e7
noise = BW*10**-17.4
tx_power_temp
# Out:
# array([[1., 1., 1.]])

# %% [markdown]
# #### Calculate the data rate for all users

# %%
cal_RATE_one_sample_one_channel(ch_mat[0, 0, :,:], tx_power_temp, noise)
# Out:
# array([[2.187, 5.372, 1.893]])

# %%
rx_mat_temp = rx_mat[:,:-1,:].reshape(Num_user, -1)
tx_mat_temp = tx_mat.reshape(Num_user, -1)
CUE_mat_temp = CUE_mat.reshape(Num_channel, -1)

plt.figure(figsize=(10,5))

plt.scatter(rx_mat_temp[:, 0], rx_mat_temp[:, 1], marker='^', label='Rx')
plt.scatter(tx_mat_temp[:, 0], tx_mat_temp[:, 1], marker='o', label='Tx')
plt.scatter(CUE_mat_temp[:, 0], CUE_mat_temp[:, 1], marker='+', label='CUE')
plt.legend(loc='upper left')

for i in range(rx_mat_temp.shape[0]):
    plt.plot([rx_mat_temp[i, 0], tx_mat_temp[i, 0]], [rx_mat_temp[i,1], tx_mat_temp[i, 1]])

# %% [markdown]
# #### Calculate Rate, EE, outage for multiple samples

# %%
def cal_rate_NP(channel, tx_power_in, tx_max, noise, DUE_thr, I_thr, P_c):
    num_sample = channel.shape[0]
    num_channel = channel.shape[1]
    num_D2D_user = channel.shape[2] - 1

    ## Initialization
    tot_SE = 0
    tot_EE = 0
    tot_cap_CUE_vio = 0
    tot_cap_DUE_vio = 0
    tot_cap_CUE_vio_num = 0.001
    tot_cap_DUE_vio_num = 0.001
    DUE_violation = 0
    CUE_violation = 0
    tot_success_prob = 0
    
    ## Append tx power and CUE tx power
    tx_power = np.hstack((tx_power_in, tx_max * np.ones((tx_power_in.shape[0], 1, num_channel))))

    for i in range(num_sample):
        cur_cap = 0
        DUE_mask = 1
        CUE_mask = 1

        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_power = tx_power[i, :, j]
            cur_power = np.array([cur_power])
            cur_ch_cap = cal_RATE_one_sample_one_channel(cur_ch, cur_power, noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, cur_power)
            cur_cap = cur_cap + cur_ch_cap[0]
            CUE_mask = CUE_mask * (inter[0, num_D2D_user] <= I_thr)

        for j in range(num_D2D_user):
            DUE_mask = DUE_mask * (cur_cap[j] >= DUE_thr)

        D2D_SE_sum = np.sum(cur_cap[:-1])*CUE_mask*DUE_mask
        D2D_EE_sum = np.sum(cur_cap[:-1]/(np.sum(tx_power_in[i], axis=1)+P_c))*CUE_mask*DUE_mask

        if CUE_mask == 0:
            CUE_violation = CUE_violation + 1
            
        if DUE_mask == 0:
            DUE_violation = DUE_violation + 1

        tot_SE = tot_SE + D2D_SE_sum
        tot_EE = tot_EE + D2D_EE_sum


    tot_SE = tot_SE / num_D2D_user / num_sample
    tot_EE = tot_EE / num_D2D_user / num_sample
    PRO_DUE_vio = DUE_violation / (num_sample)
    PRO_CUE_vio = CUE_violation / (num_sample)

    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio

# %% [markdown]
# #### Check the validity of the function
# **** tx_power_in은 D2D tx power만 고려함
# **** All ones transmit power

# %%
tx_power_in = 10**2.0*np.ones((ch_mat.shape[0], 2, 2))

# %%
DUE_thr = 0.0
tx_max = 10**2.0
I_thr = 10**(-10.0/10)
P_c = 10**2.0
BW = 1e7
noise = BW*10**-17.4

# %%
cal_rate_NP(ch_mat, tx_power_in, tx_max, noise, DUE_thr, I_thr, P_c)
# Out:
# (10.611568389483077, 0.035371894631610126, 0.0, 0.0)

# %%
DUE_thr = 4.0
tx_max = 10**2.0
I_thr = 10**(-55.0/10)
P_c = 10**2.0
BW = 1e7
noise = BW*10**-17.4

# %%
cal_rate_NP(ch_mat, tx_power_in, tx_max, noise, DUE_thr, I_thr, P_c)
# Out:
# (6.038794299876328, 0.02012931433292096, 0.3761, 0.2658)

# %% [markdown]
# #### Essential function for optimal scheme

# %%
def all_possible_tx_power(num_channel, num_user, granuty):

    items = [np.arange(granuty)] * num_user * num_channel
    temp_power = list(itertools.product(*items))
    temp_power = np.reshape(temp_power, (-1, num_user, num_channel))

    power_check = np.sum(temp_power, axis=2)
    flag = (power_check / (granuty - 1) <= 1).astype(int)
    flag = (np.sum(flag, axis=1) / num_user == 1).astype(int)
    flag = np.reshape(flag, (-1, 1))
    temp_power_1 = np.reshape(temp_power, (-1, num_user * num_channel))
    temp_power = temp_power_1 * flag
    power = np.reshape(temp_power, (-1, num_user, num_channel)) / (granuty - 1)

    power_mat = []
    for i in range(power.shape[0]):
        sum_val = np.sum(power[i])
        if sum_val != 0:
            power_mat.append(power[i])

    return np.array(power_mat)

# %%
def optimal_power(channel, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE"):

    num_channel = channel.shape[1]
    num_D2D_user = channel.shape[2] - 1
    num_samples = channel.shape[0]
    tot_SE = 0
    power_mat_SE = []
    chan_infea_mat = []

    for i in tqdm(range(num_samples)):
        cur_cap = 0
        DUE_mask = 1
        CUE_mask = 1
        tx_power = tx_max * np.hstack((tx_power_set, np.ones((tx_power_set.shape[0], 1, num_channel))))

        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_ch_cap = cal_RATE_one_sample_one_channel(cur_ch, tx_power[:, :, j], noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, tx_power[:, :, j])
            cur_cap = cur_cap + cur_ch_cap
            CUE_mask = CUE_mask * (inter[:, num_D2D_user] < I_thr)
        
        for j in range(num_D2D_user):
            DUE_mask = DUE_mask * (cur_cap[:,j] > DUE_thr)
        
        CUE_mask = np.expand_dims(CUE_mask, -1)
        DUE_mask = np.expand_dims(DUE_mask, -1)
        
        sum_D2D_SE_temp = np.expand_dims(np.sum(cur_cap[:,:-1], axis=1), -1)
        sum_D2D_EE_temp = np.expand_dims(np.sum(cur_cap[:,:-1]/(np.sum(tx_power[:,:-1,:], axis=2)+P_c), axis=1), -1)
        
        D2D_SE_sum = sum_D2D_SE_temp*CUE_mask*DUE_mask
        D2D_EE_sum = sum_D2D_EE_temp*CUE_mask*DUE_mask

        if opt=="SE":
            arg_max_val = np.argmax(D2D_SE_sum)
        else:
            arg_max_val = np.argmax(D2D_EE_sum)
            
        max_SE = np.max(D2D_SE_sum)
        
        found_tx_val = tx_power[arg_max_val][:-1]

        power_mat_SE.append(found_tx_val)
        
        ## Collect the infeasible channels
        if max_SE == 0:
            chan_infea_mat.append(channel[i])
            

    power_mat_SE = np.array(power_mat_SE)

    tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio = cal_rate_NP(channel, power_mat_SE, tx_max, noise, DUE_thr, I_thr, P_c)

    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio, np.array(chan_infea_mat)

# %% [markdown]
# #### Set the granuity level of transmit power as 20

# %%
Num_power_level = 10

# %%
tx_power_set = all_possible_tx_power(Num_channel, Num_user, Num_power_level - 1)

# %%
tx_power_set.shape
# Out:
# (2024, 2, 2)

# %%
tx_power_set[:4]
# Out:
# array([[[0.   , 0.   ],
#         [0.   , 0.125]],
#
#        [[0.   , 0.   ],
#         [0.   , 0.25 ]],
#
#        [[0.   , 0.   ],
#         [0.   , 0.375]],
#
#        [[0.   , 0.   ],
#         [0.   , 0.5  ]]])

# %%
tx_power_set[-4:]
# Out:
# array([[[1.   , 0.   ],
#         [0.75 , 0.25 ]],
#
#        [[1.   , 0.   ],
#         [0.875, 0.   ]],
#
#        [[1.   , 0.   ],
#         [0.875, 0.125]],
#
#        [[1.   , 0.   ],
#         [1.   , 0.   ]]])

# %% [markdown]
# #### What is the meaning of tx_power_set?

# %% [markdown]
# #### Calculate the optimal performance

# %%
ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**3))

# %%
SE_OPT, EE_OPT, CUE_vio_OPT, DUE_vio_OPT, INF_CHAN_MAT = optimal_power(ch_mat, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
print(f"OPT(SE) = SE:{SE_OPT:.3} bps/Hz, EE:{EE_OPT*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_OPT*100:.2f}%, Vio(DUE):{DUE_vio_OPT*100:.2f}%")
# Out:
# OPT(SE) = SE:9.04 bps/Hz, EE:45.8bps/J/Hz, Vio(CUE):3.70%, Vio(DUE):22.00%

# %%
SE_OPT, EE_OPT, CUE_vio_OPT, DUE_vio_OPT, INF_CHAN_MAT = optimal_power(ch_mat, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="EE")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
print(f"OPT(EE) = SE:{SE_OPT:.3} bps/Hz, EE:{EE_OPT*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_OPT*100:.2f}%, Vio(DUE):{DUE_vio_OPT*100:.2f}%")
# Out:
# OPT(EE) = SE:7.44 bps/Hz, EE:58.1bps/J/Hz, Vio(CUE):3.70%, Vio(DUE):22.00%

# %%
INF_CHAN_MAT.shape
# Out:
# (220, 2, 3, 3)

# %% [markdown]
# #### Random selection

# %%
def random_power(channel, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set):
    num_samples = channel.shape[0]
    tx_power = tx_max * tx_power_set
    tx_sel_idx = np.random.randint(tx_power_set.shape[0], size=num_samples)
    tx_sel = tx_power[tx_sel_idx]
    tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio = cal_rate_NP(channel, tx_sel, tx_max, noise, DUE_thr, I_thr, P_c)
    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio

# %%
SE_RAND, EE_RAND, CUE_vio_RAND, DUE_vio_RAND = random_power(ch_mat, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set)

# %%
print(f"SE:{SE_RAND:.3} bps/Hz, EE:{EE_RAND*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_RAND*100:.2f}%, Vio(DUE):{DUE_vio_RAND*100:.2f}%")
# Out:
# SE:4.21 bps/Hz, EE:25.1bps/J/Hz, Vio(CUE):22.10%, Vio(DUE):49.60%

# %% [markdown]
# ### Generate Dataset  -> It is required for PyTorch

# %%
class ChanDataset(Dataset):
    def __init__(self, Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr, chan_mean, chan_std):
        super(ChanDataset, self).__init__()
        ch_mat, _, _, _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr)
        ch_mat = np.log(ch_mat)
        ch_mat = (ch_mat-chan_mean)/chan_std
        self.x_data = torch.Tensor(ch_mat)

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        return x

# %% [markdown]
# #### Set the number of trainin and validation to 100000 and 10000

# %%
num_samples_tr = int(10**5)
num_samples_val = int(2*10**3)

# %% [markdown]
# #### Generate channel and derive the channel statistics (mean and STD)

# %%
ch_mat, _, _, _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))
chan_mean = np.mean(np.log10(ch_mat))
chan_std = np.std(np.log10(ch_mat))

# %%
tr_dataset = ChanDataset(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr, chan_mean, chan_std)
train_dataloader = DataLoader(tr_dataset, batch_size=1024*8, shuffle=True)

# %%
val_dataset = ChanDataset(Size_area, D2D_dist, Num_user, Num_channel, num_samples_val, chan_mean, chan_std)
val_dataloader = DataLoader(val_dataset, batch_size=num_samples_val, shuffle=True)

# %%
ch_data_conv = val_dataset.x_data.detach().numpy()
ch_data_conv = np.exp(ch_data_conv*chan_std + chan_mean)

# %% [markdown]
# #### Check the value of train / validation data set

# %%
train_dataloader.dataset[1]
# Out:
# tensor([[[ -8.8743,  -8.1703,  -7.7173],
#          [ -7.7274,  -4.9269,  -7.5306],
#          [-10.2921, -10.7047,  -9.8241]],
#
#         [[ -6.9337,  -9.0562,  -9.7502],
#          [ -6.9132,  -4.6722,  -7.9362],
#          [ -8.3019,  -5.6747,  -7.1331]]])

# %%
val_dataloader.dataset[1]
# Out:
# tensor([[[ -6.9070,  -6.7797,  -9.0880],
#          [ -7.1878,  -8.1825,  -9.4788],
#          [-10.7377,  -9.0870,  -7.5845]],
#
#         [[ -5.2822,  -7.1150,  -8.8197],
#          [ -7.3614,  -7.6737,  -8.4975],
#          [ -7.5694,  -6.9598,  -6.5810]]])

# %% [markdown]
# #### Create neural network

# %%
class Net(nn.Module):
    def __init__(self, num_user, num_chan, hidden_dim, num_l):
        super(Net, self).__init__()
        self.num_user = num_user
        self.num_chan = num_chan
        self.hidden_dim = hidden_dim
        self.num_l = num_l

        ## List of linear layers
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(int((num_user+1) * (num_user+1) * num_chan), hidden_dim))
        for lll in range(num_l):
            self.layers.append(nn.Linear(hidden_dim, hidden_dim))

        ## List of dropout layers
        self.dropouts = nn.ModuleList()
        for lll in range(num_l):
            self.dropouts.append(nn.Dropout(0.1))

        ## List of Batch layers
        self.batches = nn.ModuleList()
        for lll in range(num_l):
            self.batches.append(nn.BatchNorm1d(hidden_dim))

        ## output for softmax
        self.out_RA = nn.Linear(hidden_dim, num_user * num_chan)
        
        ## output for sigmoid
        self.out_PW = nn.Linear(hidden_dim, num_user)

    def forward(self, x):
        z = torch.flatten(x, 1)  # flatten all dimensions except the batch dimension
        for (layer, dropout, batch_norm) in zip(self.layers, self.dropouts, self.batches):
            # x = F.relu(nlayer(x))
            z = layer(z)
            z = batch_norm(z)
            z = F.relu(z)
            z = dropout(z)

        u = self.out_RA(z)
        u = u.view(-1, self.num_user, self.num_chan)
        out_RA = F.softmax(u, dim=2)
        
        v = self.out_PW(z)
        v = v.view(-1, self.num_user, 1)
        out_PW = F.sigmoid(v)
        output = out_RA * out_PW
        
        return output

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = Net(Num_user, Num_channel, 1000, 5).to(device)

# %%
net.eval()
# Out:
# Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=18, out_features=1000, bias=True)
#     (1): Linear(in_features=1000, out_features=1000, bias=True)
#     (2): Linear(in_features=1000, out_features=1000, bias=True)
#     (3): Linear(in_features=1000, out_features=1000, bias=True)
#     (4): Linear(in_features=1000, out_features=1000, bias=True)
#     (5): Linear(in_features=1000, out_features=1000, bias=True)
#   )
#   (dropouts): ModuleList(
#     (0): Dropout(p=0.1, inplace=False)
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Dropout(p=0.1, inplace=False)
#   )
#   (batches): ModuleList(
#     (0): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (out_RA): Linear(in_features=1000, out_features=4, bias=True)
#   (out_PW): Linear(in_features=1000, out_features=2, bias=True)
# )

# %% [markdown]
# #### (IMPORTANT) Set the loss function

# %%
def My_Loss(P_DNN, chan, tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat, opt="SE"):
    
    Num_sample = P_DNN.shape[0]
    Num_node = P_DNN.shape[1]
    Num_chan = P_DNN.shape[2]

    RATE_lam = lam_val_mat[0]
    DUE_lam = lam_val_mat[1]
    CUE_lam = lam_val_mat[2]
    
    chan_rev = torch.exp(chan * chan_std + chan_mean)
        
    P_DNN_rev = tx_max * torch.hstack((P_DNN, torch.ones((Num_sample, 1, Num_chan)).to(device)))
    
    P_DNN_rev = torch.transpose(P_DNN_rev, 1, 2)
    P_DNN_rev = P_DNN_rev.unsqueeze(3)    

    tot_gain = chan_rev * P_DNN_rev
    
    tot_gain_sum = torch.sum(tot_gain, 2)
    
    sig_sum = torch.diagonal(tot_gain, 0, 2, 3)
    
    int_sum = tot_gain_sum - sig_sum
    
    SINR_val = torch.divide(sig_sum, int_sum + noise)
    DR = torch.log2(1+SINR_val)
    
    DR_sum = torch.sum(DR, 1)
    int_CUE = int_sum[:,:,-1]

    Tot_rate = torch.mean(DR_sum[:,:-1], 1)
        
    Tot_EE = torch.mean(DR_sum[:,:-1] / (torch.sum(tx_max *P_DNN, 2)+P_c), 1)
    
    DUE_vio = torch.relu(DUE_thr - DR_sum[:,:-1])/(DUE_thr+0.01)
    
    CUE_vio = torch.relu(int_CUE - I_thr)/I_thr
    
    '''
    print("Tot_rate = ", Tot_rate)
    print("Tot_EE = ", Tot_EE)
    print("DUE_vio = ", DUE_vio)
    print("CUE_vio = ", CUE_vio)
    '''
    
    if opt == "SE":
        Loss = - RATE_lam * torch.mean(Tot_rate) + DUE_lam * torch.mean(DUE_vio) + CUE_lam * torch.mean(CUE_vio)    
    else:
        Loss = - 100*RATE_lam * torch.mean(Tot_EE) + DUE_lam * torch.mean(DUE_vio) + CUE_lam * torch.mean(CUE_vio)    

    
    return Loss

# %% [markdown]
# ## Setting the lamda value

# %%
lam_val_mat = torch.ones(3, 1).to(device)

RATE_lam = 1
DUE_lam = 50
CUE_lam = 50

lam_val_mat[0] = RATE_lam
lam_val_mat[1] = DUE_lam
lam_val_mat[2] = CUE_lam

# %% [markdown]
# #### Maximization of SE

# %%
net = Net(Num_user, Num_channel, 1000, 5).to(device)
net.train()
optimizer = torch.optim.Adam(net.parameters(), lr=2*1e-3)

# %%
for i in range(30):
    print("")
    print("**"*50)
    print(f"training epoch = {i}")
    cur_loss_tot = 0
    for index, chan in enumerate(train_dataloader):
        net.train()
        optimizer.zero_grad()

        p_dnn = net(chan.to(device))

        cur_loss = My_Loss(p_dnn, chan.to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat, opt="SE")

        cur_loss_tot += cur_loss

        cur_loss.backward()
        optimizer.step()
        print(cur_loss_tot/(index+1))
# Out:
# ****************************************************************************************************
# training epoch = 0
# /usr/local/lib/python3.9/site-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tensor([82.6076], grad_fn=<DivBackward0>)
# tensor([42.2638], grad_fn=<DivBackward0>)
# tensor([28.9640], grad_fn=<DivBackward0>)
# tensor([22.0712], grad_fn=<DivBackward0>)
# tensor([17.8602], grad_fn=<DivBackward0>)
# tensor([15.0327], grad_fn=<DivBackward0>)
# tensor([13.0236], grad_fn=<DivBackward0>)
# tensor([11.4109], grad_fn=<DivBackward0>)
# tensor([10.1451], grad_fn=<DivBackward0>)
# tensor([9.1077], grad_fn=<DivBackward0>)
# tensor([8.2327], grad_fn=<DivBackward0>)
# tensor([7.4706], grad_fn=<DivBackward0>)
# tensor([6.7885], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 1
# tensor([-1.4499], grad_fn=<DivBackward0>)
# tensor([-1.5232], grad_fn=<DivBackward0>)
# tensor([-1.6208], grad_fn=<DivBackward0>)
# tensor([-1.6918], grad_fn=<DivBackward0>)
# tensor([-1.8320], grad_fn=<DivBackward0>)
# tensor([-1.9157], grad_fn=<DivBackward0>)
# tensor([-1.9816], grad_fn=<DivBackward0>)
# tensor([-2.0572], grad_fn=<DivBackward0>)
# tensor([-2.1528], grad_fn=<DivBackward0>)
# tensor([-2.2387], grad_fn=<DivBackward0>)
# tensor([-2.3119], grad_fn=<DivBackward0>)
# tensor([-2.3867], grad_fn=<DivBackward0>)
# tensor([-2.4237], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 2
# tensor([-3.3528], grad_fn=<DivBackward0>)
# tensor([-3.4305], grad_fn=<DivBackward0>)
# tensor([-3.4744], grad_fn=<DivBackward0>)
# tensor([-3.4926], grad_fn=<DivBackward0>)
# tensor([-3.5802], grad_fn=<DivBackward0>)
# tensor([-3.6588], grad_fn=<DivBackward0>)
# tensor([-3.6902], grad_fn=<DivBackward0>)
# tensor([-3.7361], grad_fn=<DivBackward0>)
# tensor([-3.7897], grad_fn=<DivBackward0>)
# tensor([-3.8291], grad_fn=<DivBackward0>)
# tensor([-3.8846], grad_fn=<DivBackward0>)
# tensor([-3.9381], grad_fn=<DivBackward0>)
# tensor([-3.9919], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 3
# tensor([-4.3062], grad_fn=<DivBackward0>)
# tensor([-4.4546], grad_fn=<DivBackward0>)
# tensor([-4.5186], grad_fn=<DivBackward0>)
# tensor([-4.5660], grad_fn=<DivBackward0>)
# tensor([-4.5736], grad_fn=<DivBackward0>)
# tensor([-4.5547], grad_fn=<DivBackward0>)
# tensor([-4.5997], grad_fn=<DivBackward0>)
# tensor([-4.6159], grad_fn=<DivBackward0>)
# tensor([-4.6674], grad_fn=<DivBackward0>)
# tensor([-4.6882], grad_fn=<DivBackward0>)
# tensor([-4.7182], grad_fn=<DivBackward0>)
# tensor([-4.7384], grad_fn=<DivBackward0>)
# tensor([-4.7660], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 4
# tensor([-5.1964], grad_fn=<DivBackward0>)
# tensor([-5.2155], grad_fn=<DivBackward0>)
# tensor([-5.2011], grad_fn=<DivBackward0>)
# tensor([-5.2064], grad_fn=<DivBackward0>)
# tensor([-5.1829], grad_fn=<DivBackward0>)
# tensor([-5.1971], grad_fn=<DivBackward0>)
# tensor([-5.1961], grad_fn=<DivBackward0>)
# tensor([-5.1948], grad_fn=<DivBackward0>)
# tensor([-5.2073], grad_fn=<DivBackward0>)
# tensor([-5.2304], grad_fn=<DivBackward0>)
# tensor([-5.2400], grad_fn=<DivBackward0>)
# tensor([-5.2437], grad_fn=<DivBackward0>)
# tensor([-5.2819], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 5
# tensor([-5.5547], grad_fn=<DivBackward0>)
# tensor([-5.4923], grad_fn=<DivBackward0>)
# tensor([-5.4381], grad_fn=<DivBackward0>)
# tensor([-5.4452], grad_fn=<DivBackward0>)
# tensor([-5.4614], grad_fn=<DivBackward0>)
# tensor([-5.5504], grad_fn=<DivBackward0>)
# tensor([-5.5570], grad_fn=<DivBackward0>)
# tensor([-5.5924], grad_fn=<DivBackward0>)
# tensor([-5.6180], grad_fn=<DivBackward0>)
# tensor([-5.6460], grad_fn=<DivBackward0>)
# tensor([-5.6708], grad_fn=<DivBackward0>)
# tensor([-5.6912], grad_fn=<DivBackward0>)
# tensor([-5.7278], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 6
# tensor([-5.5825], grad_fn=<DivBackward0>)
# tensor([-5.6635], grad_fn=<DivBackward0>)
# tensor([-5.5980], grad_fn=<DivBackward0>)
# tensor([-5.5915], grad_fn=<DivBackward0>)
# tensor([-5.6099], grad_fn=<DivBackward0>)
# tensor([-5.6560], grad_fn=<DivBackward0>)
# tensor([-5.6864], grad_fn=<DivBackward0>)
# tensor([-5.7232], grad_fn=<DivBackward0>)
# tensor([-5.7159], grad_fn=<DivBackward0>)
# tensor([-5.7110], grad_fn=<DivBackward0>)
# tensor([-5.7187], grad_fn=<DivBackward0>)
# tensor([-5.7070], grad_fn=<DivBackward0>)
# tensor([-5.7310], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 7
# tensor([-5.9884], grad_fn=<DivBackward0>)
# tensor([-5.9287], grad_fn=<DivBackward0>)
# tensor([-5.9216], grad_fn=<DivBackward0>)
# tensor([-5.9595], grad_fn=<DivBackward0>)
# tensor([-5.9693], grad_fn=<DivBackward0>)
# tensor([-6.0074], grad_fn=<DivBackward0>)
# tensor([-6.0460], grad_fn=<DivBackward0>)
# tensor([-6.0518], grad_fn=<DivBackward0>)
# tensor([-6.0728], grad_fn=<DivBackward0>)
# tensor([-6.0713], grad_fn=<DivBackward0>)
# tensor([-6.0772], grad_fn=<DivBackward0>)
# tensor([-6.0591], grad_fn=<DivBackward0>)
# tensor([-6.0579], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 8
# tensor([-6.2082], grad_fn=<DivBackward0>)
# tensor([-6.0865], grad_fn=<DivBackward0>)
# tensor([-6.1034], grad_fn=<DivBackward0>)
# tensor([-6.1018], grad_fn=<DivBackward0>)
# tensor([-6.1184], grad_fn=<DivBackward0>)
# tensor([-6.1293], grad_fn=<DivBackward0>)
# tensor([-6.1730], grad_fn=<DivBackward0>)
# tensor([-6.2177], grad_fn=<DivBackward0>)
# tensor([-6.2207], grad_fn=<DivBackward0>)
# tensor([-6.2279], grad_fn=<DivBackward0>)
# tensor([-6.2345], grad_fn=<DivBackward0>)
# tensor([-6.2614], grad_fn=<DivBackward0>)
# tensor([-6.2774], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 9
# tensor([-6.4111], grad_fn=<DivBackward0>)
# tensor([-6.3991], grad_fn=<DivBackward0>)
# tensor([-6.4662], grad_fn=<DivBackward0>)
# tensor([-6.4633], grad_fn=<DivBackward0>)
# tensor([-6.4023], grad_fn=<DivBackward0>)
# tensor([-6.3087], grad_fn=<DivBackward0>)
# tensor([-6.2831], grad_fn=<DivBackward0>)
# tensor([-6.2459], grad_fn=<DivBackward0>)
# tensor([-6.1980], grad_fn=<DivBackward0>)
# tensor([-6.1692], grad_fn=<DivBackward0>)
# tensor([-6.1405], grad_fn=<DivBackward0>)
# tensor([-6.1382], grad_fn=<DivBackward0>)
# tensor([-6.1525], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 10
# tensor([-5.9346], grad_fn=<DivBackward0>)
# tensor([-5.9684], grad_fn=<DivBackward0>)
# tensor([-6.0468], grad_fn=<DivBackward0>)
# tensor([-6.1248], grad_fn=<DivBackward0>)
# tensor([-6.1522], grad_fn=<DivBackward0>)
# tensor([-6.1507], grad_fn=<DivBackward0>)
# tensor([-6.1510], grad_fn=<DivBackward0>)
# tensor([-6.1586], grad_fn=<DivBackward0>)
# tensor([-6.1737], grad_fn=<DivBackward0>)
# tensor([-6.1796], grad_fn=<DivBackward0>)
# tensor([-6.2039], grad_fn=<DivBackward0>)
# tensor([-6.2103], grad_fn=<DivBackward0>)
# tensor([-6.2244], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 11
# tensor([-6.4227], grad_fn=<DivBackward0>)
# tensor([-6.3825], grad_fn=<DivBackward0>)
# tensor([-6.3497], grad_fn=<DivBackward0>)
# tensor([-6.3834], grad_fn=<DivBackward0>)
# tensor([-6.4064], grad_fn=<DivBackward0>)
# tensor([-6.4464], grad_fn=<DivBackward0>)
# tensor([-6.4465], grad_fn=<DivBackward0>)
# tensor([-6.4800], grad_fn=<DivBackward0>)
# tensor([-6.4631], grad_fn=<DivBackward0>)
# tensor([-6.4664], grad_fn=<DivBackward0>)
# tensor([-6.4650], grad_fn=<DivBackward0>)
# tensor([-6.4715], grad_fn=<DivBackward0>)
# tensor([-6.4657], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 12
# tensor([-6.6002], grad_fn=<DivBackward0>)
# tensor([-6.5460], grad_fn=<DivBackward0>)
# tensor([-6.5131], grad_fn=<DivBackward0>)
# tensor([-6.5453], grad_fn=<DivBackward0>)
# tensor([-6.5622], grad_fn=<DivBackward0>)
# tensor([-6.5789], grad_fn=<DivBackward0>)
# tensor([-6.6036], grad_fn=<DivBackward0>)
# tensor([-6.6259], grad_fn=<DivBackward0>)
# tensor([-6.6330], grad_fn=<DivBackward0>)
# tensor([-6.6536], grad_fn=<DivBackward0>)
# tensor([-6.6560], grad_fn=<DivBackward0>)
# tensor([-6.6788], grad_fn=<DivBackward0>)
# tensor([-6.6996], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 13
# tensor([-6.8624], grad_fn=<DivBackward0>)
# tensor([-6.7714], grad_fn=<DivBackward0>)
# tensor([-6.7691], grad_fn=<DivBackward0>)
# tensor([-6.7766], grad_fn=<DivBackward0>)
# tensor([-6.8096], grad_fn=<DivBackward0>)
# tensor([-6.7962], grad_fn=<DivBackward0>)
# tensor([-6.7791], grad_fn=<DivBackward0>)
# tensor([-6.7768], grad_fn=<DivBackward0>)
# tensor([-6.7740], grad_fn=<DivBackward0>)
# tensor([-6.7738], grad_fn=<DivBackward0>)
# tensor([-6.7827], grad_fn=<DivBackward0>)
# tensor([-6.7843], grad_fn=<DivBackward0>)
# tensor([-6.7799], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 14
# tensor([-6.5998], grad_fn=<DivBackward0>)
# tensor([-6.7455], grad_fn=<DivBackward0>)
# tensor([-6.8378], grad_fn=<DivBackward0>)
# tensor([-6.8434], grad_fn=<DivBackward0>)
# tensor([-6.8397], grad_fn=<DivBackward0>)
# tensor([-6.8350], grad_fn=<DivBackward0>)
# tensor([-6.8148], grad_fn=<DivBackward0>)
# tensor([-6.8090], grad_fn=<DivBackward0>)
# tensor([-6.8208], grad_fn=<DivBackward0>)
# tensor([-6.8196], grad_fn=<DivBackward0>)
# tensor([-6.8042], grad_fn=<DivBackward0>)
# tensor([-6.8100], grad_fn=<DivBackward0>)
# tensor([-6.8427], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 15
# tensor([-7.0385], grad_fn=<DivBackward0>)
# tensor([-7.0241], grad_fn=<DivBackward0>)
# tensor([-6.9974], grad_fn=<DivBackward0>)
# tensor([-6.9614], grad_fn=<DivBackward0>)
# tensor([-6.9563], grad_fn=<DivBackward0>)
# tensor([-6.9208], grad_fn=<DivBackward0>)
# tensor([-6.9086], grad_fn=<DivBackward0>)
# tensor([-6.8975], grad_fn=<DivBackward0>)
# tensor([-6.8918], grad_fn=<DivBackward0>)
# tensor([-6.8945], grad_fn=<DivBackward0>)
# tensor([-6.8835], grad_fn=<DivBackward0>)
# tensor([-6.8902], grad_fn=<DivBackward0>)
# tensor([-6.9041], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 16
# tensor([-6.9677], grad_fn=<DivBackward0>)
# tensor([-6.8941], grad_fn=<DivBackward0>)
# tensor([-6.8957], grad_fn=<DivBackward0>)
# tensor([-6.9297], grad_fn=<DivBackward0>)
# tensor([-6.8995], grad_fn=<DivBackward0>)
# tensor([-6.8901], grad_fn=<DivBackward0>)
# tensor([-6.9056], grad_fn=<DivBackward0>)
# tensor([-6.9350], grad_fn=<DivBackward0>)
# tensor([-6.9455], grad_fn=<DivBackward0>)
# tensor([-6.9457], grad_fn=<DivBackward0>)
# tensor([-6.9550], grad_fn=<DivBackward0>)
# tensor([-6.9665], grad_fn=<DivBackward0>)
# tensor([-6.9685], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 17
# tensor([-7.0499], grad_fn=<DivBackward0>)
# tensor([-7.0141], grad_fn=<DivBackward0>)
# tensor([-6.9454], grad_fn=<DivBackward0>)
# tensor([-6.9248], grad_fn=<DivBackward0>)
# tensor([-6.9273], grad_fn=<DivBackward0>)
# tensor([-6.9398], grad_fn=<DivBackward0>)
# tensor([-6.9187], grad_fn=<DivBackward0>)
# tensor([-6.9243], grad_fn=<DivBackward0>)
# tensor([-6.9454], grad_fn=<DivBackward0>)
# tensor([-6.9480], grad_fn=<DivBackward0>)
# tensor([-6.9676], grad_fn=<DivBackward0>)
# tensor([-6.9830], grad_fn=<DivBackward0>)
# tensor([-6.9928], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 18
# tensor([-6.8222], grad_fn=<DivBackward0>)
# tensor([-6.9288], grad_fn=<DivBackward0>)
# tensor([-6.9453], grad_fn=<DivBackward0>)
# tensor([-6.9702], grad_fn=<DivBackward0>)
# tensor([-7.0035], grad_fn=<DivBackward0>)
# tensor([-6.9887], grad_fn=<DivBackward0>)
# tensor([-7.0228], grad_fn=<DivBackward0>)
# tensor([-7.0067], grad_fn=<DivBackward0>)
# tensor([-7.0103], grad_fn=<DivBackward0>)
# tensor([-7.0268], grad_fn=<DivBackward0>)
# tensor([-7.0426], grad_fn=<DivBackward0>)
# tensor([-7.0248], grad_fn=<DivBackward0>)
# tensor([-7.0201], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 19
# tensor([-7.0088], grad_fn=<DivBackward0>)
# tensor([-6.9906], grad_fn=<DivBackward0>)
# tensor([-6.9360], grad_fn=<DivBackward0>)
# tensor([-6.9266], grad_fn=<DivBackward0>)
# tensor([-6.9147], grad_fn=<DivBackward0>)
# tensor([-6.9092], grad_fn=<DivBackward0>)
# tensor([-6.8941], grad_fn=<DivBackward0>)
# tensor([-6.9370], grad_fn=<DivBackward0>)
# tensor([-6.9319], grad_fn=<DivBackward0>)
# tensor([-6.9250], grad_fn=<DivBackward0>)
# tensor([-6.9290], grad_fn=<DivBackward0>)
# tensor([-6.9410], grad_fn=<DivBackward0>)
# tensor([-6.9109], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 20
# tensor([-7.0585], grad_fn=<DivBackward0>)
# tensor([-7.0202], grad_fn=<DivBackward0>)
# tensor([-7.0243], grad_fn=<DivBackward0>)
# tensor([-7.0700], grad_fn=<DivBackward0>)
# tensor([-7.0990], grad_fn=<DivBackward0>)
# tensor([-7.0770], grad_fn=<DivBackward0>)
# tensor([-7.0703], grad_fn=<DivBackward0>)
# tensor([-7.0660], grad_fn=<DivBackward0>)
# tensor([-7.0815], grad_fn=<DivBackward0>)
# tensor([-7.0617], grad_fn=<DivBackward0>)
# tensor([-7.0597], grad_fn=<DivBackward0>)
# tensor([-7.0496], grad_fn=<DivBackward0>)
# tensor([-7.0541], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 21
# tensor([-7.1535], grad_fn=<DivBackward0>)
# tensor([-7.0553], grad_fn=<DivBackward0>)
# tensor([-7.0442], grad_fn=<DivBackward0>)
# tensor([-7.0703], grad_fn=<DivBackward0>)
# tensor([-7.0901], grad_fn=<DivBackward0>)
# tensor([-7.1099], grad_fn=<DivBackward0>)
# tensor([-7.0950], grad_fn=<DivBackward0>)
# tensor([-7.0828], grad_fn=<DivBackward0>)
# tensor([-7.0761], grad_fn=<DivBackward0>)
# tensor([-7.0812], grad_fn=<DivBackward0>)
# tensor([-7.0884], grad_fn=<DivBackward0>)
# tensor([-7.0913], grad_fn=<DivBackward0>)
# tensor([-7.0735], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 22
# tensor([-6.8519], grad_fn=<DivBackward0>)
# tensor([-6.9859], grad_fn=<DivBackward0>)
# tensor([-6.8932], grad_fn=<DivBackward0>)
# tensor([-6.9474], grad_fn=<DivBackward0>)
# tensor([-6.9667], grad_fn=<DivBackward0>)
# tensor([-6.9491], grad_fn=<DivBackward0>)
# tensor([-6.9776], grad_fn=<DivBackward0>)
# tensor([-6.9913], grad_fn=<DivBackward0>)
# tensor([-7.0146], grad_fn=<DivBackward0>)
# tensor([-7.0305], grad_fn=<DivBackward0>)
# tensor([-7.0258], grad_fn=<DivBackward0>)
# tensor([-7.0296], grad_fn=<DivBackward0>)
# tensor([-7.0389], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 23
# tensor([-6.9513], grad_fn=<DivBackward0>)
# tensor([-7.0388], grad_fn=<DivBackward0>)
# tensor([-7.0629], grad_fn=<DivBackward0>)
# tensor([-7.0785], grad_fn=<DivBackward0>)
# tensor([-7.0698], grad_fn=<DivBackward0>)
# tensor([-7.1136], grad_fn=<DivBackward0>)
# tensor([-7.1356], grad_fn=<DivBackward0>)
# tensor([-7.1200], grad_fn=<DivBackward0>)
# tensor([-7.1148], grad_fn=<DivBackward0>)
# tensor([-7.1223], grad_fn=<DivBackward0>)
# tensor([-7.1218], grad_fn=<DivBackward0>)
# tensor([-7.1387], grad_fn=<DivBackward0>)
# tensor([-7.1232], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 24
# tensor([-7.0274], grad_fn=<DivBackward0>)
# tensor([-7.0403], grad_fn=<DivBackward0>)
# tensor([-7.1233], grad_fn=<DivBackward0>)
# tensor([-7.0355], grad_fn=<DivBackward0>)
# tensor([-7.0845], grad_fn=<DivBackward0>)
# tensor([-7.0936], grad_fn=<DivBackward0>)
# tensor([-7.0684], grad_fn=<DivBackward0>)
# tensor([-7.0727], grad_fn=<DivBackward0>)
# tensor([-7.0884], grad_fn=<DivBackward0>)
# tensor([-7.1069], grad_fn=<DivBackward0>)
# tensor([-7.1130], grad_fn=<DivBackward0>)
# tensor([-7.1189], grad_fn=<DivBackward0>)
# tensor([-7.1516], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 25
# tensor([-7.1137], grad_fn=<DivBackward0>)
# tensor([-7.1266], grad_fn=<DivBackward0>)
# tensor([-7.1336], grad_fn=<DivBackward0>)
# tensor([-7.1545], grad_fn=<DivBackward0>)
# tensor([-7.1790], grad_fn=<DivBackward0>)
# tensor([-7.1493], grad_fn=<DivBackward0>)
# tensor([-7.1215], grad_fn=<DivBackward0>)
# tensor([-7.1193], grad_fn=<DivBackward0>)
# tensor([-7.1227], grad_fn=<DivBackward0>)
# tensor([-7.1267], grad_fn=<DivBackward0>)
# tensor([-7.1220], grad_fn=<DivBackward0>)
# tensor([-7.1374], grad_fn=<DivBackward0>)
# tensor([-7.1459], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 26
# tensor([-7.1802], grad_fn=<DivBackward0>)
# tensor([-7.1691], grad_fn=<DivBackward0>)
# tensor([-7.1012], grad_fn=<DivBackward0>)
# tensor([-7.1465], grad_fn=<DivBackward0>)
# tensor([-7.1310], grad_fn=<DivBackward0>)
# tensor([-7.1417], grad_fn=<DivBackward0>)
# tensor([-7.1430], grad_fn=<DivBackward0>)
# tensor([-7.1745], grad_fn=<DivBackward0>)
# tensor([-7.1770], grad_fn=<DivBackward0>)
# tensor([-7.1655], grad_fn=<DivBackward0>)
# tensor([-7.1806], grad_fn=<DivBackward0>)
# tensor([-7.1945], grad_fn=<DivBackward0>)
# tensor([-7.2075], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 27
# tensor([-7.0957], grad_fn=<DivBackward0>)
# tensor([-7.0906], grad_fn=<DivBackward0>)
# tensor([-7.1414], grad_fn=<DivBackward0>)
# tensor([-7.1482], grad_fn=<DivBackward0>)
# tensor([-7.1559], grad_fn=<DivBackward0>)
# tensor([-7.1487], grad_fn=<DivBackward0>)
# tensor([-7.1270], grad_fn=<DivBackward0>)
# tensor([-7.1397], grad_fn=<DivBackward0>)
# tensor([-7.1630], grad_fn=<DivBackward0>)
# tensor([-7.1635], grad_fn=<DivBackward0>)
# tensor([-7.1814], grad_fn=<DivBackward0>)
# tensor([-7.1825], grad_fn=<DivBackward0>)
# tensor([-7.1869], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 28
# tensor([-7.2259], grad_fn=<DivBackward0>)
# tensor([-7.2594], grad_fn=<DivBackward0>)
# tensor([-7.2686], grad_fn=<DivBackward0>)
# tensor([-7.2416], grad_fn=<DivBackward0>)
# tensor([-7.2434], grad_fn=<DivBackward0>)
# tensor([-7.2365], grad_fn=<DivBackward0>)
# tensor([-7.2397], grad_fn=<DivBackward0>)
# tensor([-7.2353], grad_fn=<DivBackward0>)
# tensor([-7.2346], grad_fn=<DivBackward0>)
# tensor([-7.2126], grad_fn=<DivBackward0>)
# tensor([-7.2034], grad_fn=<DivBackward0>)
# tensor([-7.1916], grad_fn=<DivBackward0>)
# tensor([-7.1992], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 29
# tensor([-7.1021], grad_fn=<DivBackward0>)
# tensor([-7.1770], grad_fn=<DivBackward0>)
# tensor([-7.1794], grad_fn=<DivBackward0>)
# tensor([-7.2090], grad_fn=<DivBackward0>)
# tensor([-7.2126], grad_fn=<DivBackward0>)
# tensor([-7.1930], grad_fn=<DivBackward0>)
# tensor([-7.2204], grad_fn=<DivBackward0>)
# tensor([-7.2088], grad_fn=<DivBackward0>)
# tensor([-7.1705], grad_fn=<DivBackward0>)
# tensor([-7.1956], grad_fn=<DivBackward0>)
# tensor([-7.2070], grad_fn=<DivBackward0>)
# tensor([-7.1978], grad_fn=<DivBackward0>)
# tensor([-7.1967], grad_fn=<DivBackward0>)

# %% [markdown]
# #### Calculate the conventional performance

# %%
SE_OPT, EE_OPT, CUE_vio_OPT, DUE_vio_OPT, INF_CHAN_MAT = optimal_power(ch_data_conv, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE")
print(f"OPT(SE) = SE:{SE_OPT:.3} bps/Hz, EE:{EE_OPT*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_OPT*100:.2f}%, Vio(DUE):{DUE_vio_OPT*100:.2f}%")
SE_OPT, EE_OPT, CUE_vio_OPT, DUE_vio_OPT, INF_CHAN_MAT = optimal_power(ch_data_conv, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="EE")
print(f"OPT(EE) = SE:{SE_OPT:.3} bps/Hz, EE:{EE_OPT*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_OPT*100:.2f}%, Vio(DUE):{DUE_vio_OPT*100:.2f}%")
SE_RAND, EE_RAND, CUE_vio_RAND, DUE_vio_RAND = random_power(ch_data_conv, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set)
print(f"SE:{SE_RAND:.3} bps/Hz, EE:{EE_RAND*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_RAND*100:.2f}%, Vio(DUE):{DUE_vio_RAND*100:.2f}%")
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# OPT(SE) = SE:8.96 bps/Hz, EE:45.6bps/J/Hz, Vio(CUE):4.85%, Vio(DUE):21.80%
#   0%|          | 0/2000 [00:00<?, ?it/s]
# OPT(EE) = SE:7.4 bps/Hz, EE:57.7bps/J/Hz, Vio(CUE):4.85%, Vio(DUE):21.80%
# SE:4.26 bps/Hz, EE:25.3bps/J/Hz, Vio(CUE):20.40%, Vio(DUE):49.65%

# %% [markdown]
# #### Calculate the performance with DNN scheme

# %%
net.eval()
for index, chan_val in enumerate(val_dataloader):
    print(index)
    p_dnn = tx_max * net(chan_val.to(device)).detach().numpy()
    chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
    SE_DNN, EE_DNN, CUE_vio_DNN, DUE_vio_DNN = cal_rate_NP(chan_val_rev, p_dnn, tx_max, noise, DUE_thr, I_thr, P_c)

print(f"SE:{SE_DNN:.3} bps/Hz, EE:{EE_DNN*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_DNN*100:.2f}%, Vio(DUE):{DUE_vio_DNN*100:.2f}%")
# Out:
# 0
# SE:8.85 bps/Hz, EE:46.2bps/J/Hz, Vio(CUE):0.25%, Vio(DUE):22.40%

# %% [markdown]
# #### Maximization of EE

# %%
net_EE = Net(Num_user, Num_channel, 1000, 5).to(device)
net_EE.train()
optimizer = torch.optim.Adam(net_EE.parameters(), lr=2*1e-3)
for i in range(30):
    print("")
    print("**"*50)
    print(f"training epoch = {i}")
    cur_loss_tot = 0
    for index, chan in enumerate(train_dataloader):
        net.train()
        optimizer.zero_grad()

        p_dnn = net_EE(chan.to(device))

        cur_loss = My_Loss(p_dnn, chan.to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat, opt="EE")

        cur_loss_tot += cur_loss

        cur_loss.backward()
        optimizer.step()
        print(cur_loss_tot/(index+1))
# Out:
# ****************************************************************************************************
# training epoch = 0
# tensor([64.2345], grad_fn=<DivBackward0>)
# tensor([34.8610], grad_fn=<DivBackward0>)
# tensor([24.6839], grad_fn=<DivBackward0>)
# tensor([19.3520], grad_fn=<DivBackward0>)
# tensor([15.9374], grad_fn=<DivBackward0>)
# tensor([13.6820], grad_fn=<DivBackward0>)
# tensor([12.0221], grad_fn=<DivBackward0>)
# tensor([10.7154], grad_fn=<DivBackward0>)
# tensor([9.6719], grad_fn=<DivBackward0>)
# tensor([8.8199], grad_fn=<DivBackward0>)
# tensor([8.1231], grad_fn=<DivBackward0>)
# tensor([7.4951], grad_fn=<DivBackward0>)
# tensor([6.9252], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 1
# tensor([0.5162], grad_fn=<DivBackward0>)
# tensor([0.3699], grad_fn=<DivBackward0>)
# tensor([0.2474], grad_fn=<DivBackward0>)
# tensor([0.1540], grad_fn=<DivBackward0>)
# tensor([0.0968], grad_fn=<DivBackward0>)
# tensor([0.0143], grad_fn=<DivBackward0>)
# tensor([-0.0217], grad_fn=<DivBackward0>)
# tensor([-0.0817], grad_fn=<DivBackward0>)
# tensor([-0.1362], grad_fn=<DivBackward0>)
# tensor([-0.1936], grad_fn=<DivBackward0>)
# tensor([-0.2380], grad_fn=<DivBackward0>)
# tensor([-0.2956], grad_fn=<DivBackward0>)
# tensor([-0.3264], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 2
# tensor([-0.6165], grad_fn=<DivBackward0>)
# tensor([-0.7955], grad_fn=<DivBackward0>)
# tensor([-0.8366], grad_fn=<DivBackward0>)
# tensor([-0.8609], grad_fn=<DivBackward0>)
# tensor([-0.9210], grad_fn=<DivBackward0>)
# tensor([-0.9771], grad_fn=<DivBackward0>)
# tensor([-1.0132], grad_fn=<DivBackward0>)
# tensor([-1.0400], grad_fn=<DivBackward0>)
# tensor([-1.0971], grad_fn=<DivBackward0>)
# tensor([-1.1533], grad_fn=<DivBackward0>)
# tensor([-1.1701], grad_fn=<DivBackward0>)
# tensor([-1.2125], grad_fn=<DivBackward0>)
# tensor([-1.2107], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 3
# tensor([-1.5339], grad_fn=<DivBackward0>)
# tensor([-1.6796], grad_fn=<DivBackward0>)
# tensor([-1.7129], grad_fn=<DivBackward0>)
# tensor([-1.7514], grad_fn=<DivBackward0>)
# tensor([-1.7867], grad_fn=<DivBackward0>)
# tensor([-1.7701], grad_fn=<DivBackward0>)
# tensor([-1.7884], grad_fn=<DivBackward0>)
# tensor([-1.7819], grad_fn=<DivBackward0>)
# tensor([-1.7989], grad_fn=<DivBackward0>)
# tensor([-1.8078], grad_fn=<DivBackward0>)
# tensor([-1.8242], grad_fn=<DivBackward0>)
# tensor([-1.8260], grad_fn=<DivBackward0>)
# tensor([-1.8350], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 4
# tensor([-2.0162], grad_fn=<DivBackward0>)
# tensor([-1.9737], grad_fn=<DivBackward0>)
# tensor([-2.0251], grad_fn=<DivBackward0>)
# tensor([-2.0494], grad_fn=<DivBackward0>)
# tensor([-2.0622], grad_fn=<DivBackward0>)
# tensor([-2.0631], grad_fn=<DivBackward0>)
# tensor([-2.0698], grad_fn=<DivBackward0>)
# tensor([-2.0836], grad_fn=<DivBackward0>)
# tensor([-2.0872], grad_fn=<DivBackward0>)
# tensor([-2.1156], grad_fn=<DivBackward0>)
# tensor([-2.1478], grad_fn=<DivBackward0>)
# tensor([-2.1595], grad_fn=<DivBackward0>)
# tensor([-2.1988], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 5
# tensor([-2.2710], grad_fn=<DivBackward0>)
# tensor([-2.2992], grad_fn=<DivBackward0>)
# tensor([-2.3771], grad_fn=<DivBackward0>)
# tensor([-2.3265], grad_fn=<DivBackward0>)
# tensor([-2.3573], grad_fn=<DivBackward0>)
# tensor([-2.3772], grad_fn=<DivBackward0>)
# tensor([-2.3785], grad_fn=<DivBackward0>)
# tensor([-2.3855], grad_fn=<DivBackward0>)
# tensor([-2.3676], grad_fn=<DivBackward0>)
# tensor([-2.3903], grad_fn=<DivBackward0>)
# tensor([-2.4045], grad_fn=<DivBackward0>)
# tensor([-2.4197], grad_fn=<DivBackward0>)
# tensor([-2.4336], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 6
# tensor([-2.5087], grad_fn=<DivBackward0>)
# tensor([-2.6405], grad_fn=<DivBackward0>)
# tensor([-2.6254], grad_fn=<DivBackward0>)
# tensor([-2.6578], grad_fn=<DivBackward0>)
# tensor([-2.6691], grad_fn=<DivBackward0>)
# tensor([-2.6598], grad_fn=<DivBackward0>)
# tensor([-2.6676], grad_fn=<DivBackward0>)
# tensor([-2.6800], grad_fn=<DivBackward0>)
# tensor([-2.6969], grad_fn=<DivBackward0>)
# tensor([-2.7042], grad_fn=<DivBackward0>)
# tensor([-2.6945], grad_fn=<DivBackward0>)
# tensor([-2.6978], grad_fn=<DivBackward0>)
# tensor([-2.7225], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 7
# tensor([-2.8502], grad_fn=<DivBackward0>)
# tensor([-2.8109], grad_fn=<DivBackward0>)
# tensor([-2.8209], grad_fn=<DivBackward0>)
# tensor([-2.7620], grad_fn=<DivBackward0>)
# tensor([-2.8093], grad_fn=<DivBackward0>)
# tensor([-2.7990], grad_fn=<DivBackward0>)
# tensor([-2.8047], grad_fn=<DivBackward0>)
# tensor([-2.8139], grad_fn=<DivBackward0>)
# tensor([-2.8223], grad_fn=<DivBackward0>)
# tensor([-2.8242], grad_fn=<DivBackward0>)
# tensor([-2.8224], grad_fn=<DivBackward0>)
# tensor([-2.8140], grad_fn=<DivBackward0>)
# tensor([-2.7967], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 8
# tensor([-2.9318], grad_fn=<DivBackward0>)
# tensor([-2.8429], grad_fn=<DivBackward0>)
# tensor([-2.8263], grad_fn=<DivBackward0>)
# tensor([-2.8363], grad_fn=<DivBackward0>)
# tensor([-2.8092], grad_fn=<DivBackward0>)
# tensor([-2.8040], grad_fn=<DivBackward0>)
# tensor([-2.8050], grad_fn=<DivBackward0>)
# tensor([-2.8261], grad_fn=<DivBackward0>)
# tensor([-2.8428], grad_fn=<DivBackward0>)
# tensor([-2.8625], grad_fn=<DivBackward0>)
# tensor([-2.8730], grad_fn=<DivBackward0>)
# tensor([-2.8848], grad_fn=<DivBackward0>)
# tensor([-2.8880], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 9
# tensor([-2.8610], grad_fn=<DivBackward0>)
# tensor([-2.9042], grad_fn=<DivBackward0>)
# tensor([-2.9414], grad_fn=<DivBackward0>)
# tensor([-2.9512], grad_fn=<DivBackward0>)
# tensor([-2.9645], grad_fn=<DivBackward0>)
# tensor([-2.9883], grad_fn=<DivBackward0>)
# tensor([-2.9996], grad_fn=<DivBackward0>)
# tensor([-2.9912], grad_fn=<DivBackward0>)
# tensor([-2.9978], grad_fn=<DivBackward0>)
# tensor([-3.0178], grad_fn=<DivBackward0>)
# tensor([-3.0092], grad_fn=<DivBackward0>)
# tensor([-3.0183], grad_fn=<DivBackward0>)
# tensor([-3.0494], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 10
# tensor([-3.1274], grad_fn=<DivBackward0>)
# tensor([-3.0610], grad_fn=<DivBackward0>)
# tensor([-3.0789], grad_fn=<DivBackward0>)
# tensor([-3.0348], grad_fn=<DivBackward0>)
# tensor([-3.0558], grad_fn=<DivBackward0>)
# tensor([-3.0806], grad_fn=<DivBackward0>)
# tensor([-3.1158], grad_fn=<DivBackward0>)
# tensor([-3.1503], grad_fn=<DivBackward0>)
# tensor([-3.1467], grad_fn=<DivBackward0>)
# tensor([-3.1426], grad_fn=<DivBackward0>)
# tensor([-3.1473], grad_fn=<DivBackward0>)
# tensor([-3.1581], grad_fn=<DivBackward0>)
# tensor([-3.1515], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 11
# tensor([-3.2245], grad_fn=<DivBackward0>)
# tensor([-3.1693], grad_fn=<DivBackward0>)
# tensor([-3.1421], grad_fn=<DivBackward0>)
# tensor([-3.1082], grad_fn=<DivBackward0>)
# tensor([-3.1386], grad_fn=<DivBackward0>)
# tensor([-3.1543], grad_fn=<DivBackward0>)
# tensor([-3.1414], grad_fn=<DivBackward0>)
# tensor([-3.1476], grad_fn=<DivBackward0>)
# tensor([-3.1510], grad_fn=<DivBackward0>)
# tensor([-3.1567], grad_fn=<DivBackward0>)
# tensor([-3.1667], grad_fn=<DivBackward0>)
# tensor([-3.1689], grad_fn=<DivBackward0>)
# tensor([-3.1539], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 12
# tensor([-3.3124], grad_fn=<DivBackward0>)
# tensor([-3.2311], grad_fn=<DivBackward0>)
# tensor([-3.2043], grad_fn=<DivBackward0>)
# tensor([-3.2052], grad_fn=<DivBackward0>)
# tensor([-3.2049], grad_fn=<DivBackward0>)
# tensor([-3.2045], grad_fn=<DivBackward0>)
# tensor([-3.2018], grad_fn=<DivBackward0>)
# tensor([-3.1898], grad_fn=<DivBackward0>)
# tensor([-3.1985], grad_fn=<DivBackward0>)
# tensor([-3.2340], grad_fn=<DivBackward0>)
# tensor([-3.2342], grad_fn=<DivBackward0>)
# tensor([-3.2408], grad_fn=<DivBackward0>)
# tensor([-3.2367], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 13
# tensor([-3.3437], grad_fn=<DivBackward0>)
# tensor([-3.3627], grad_fn=<DivBackward0>)
# tensor([-3.3457], grad_fn=<DivBackward0>)
# tensor([-3.3257], grad_fn=<DivBackward0>)
# tensor([-3.3221], grad_fn=<DivBackward0>)
# tensor([-3.3066], grad_fn=<DivBackward0>)
# tensor([-3.3061], grad_fn=<DivBackward0>)
# tensor([-3.3109], grad_fn=<DivBackward0>)
# tensor([-3.3108], grad_fn=<DivBackward0>)
# tensor([-3.3127], grad_fn=<DivBackward0>)
# tensor([-3.3207], grad_fn=<DivBackward0>)
# tensor([-3.3345], grad_fn=<DivBackward0>)
# tensor([-3.3401], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 14
# tensor([-3.2482], grad_fn=<DivBackward0>)
# tensor([-3.2768], grad_fn=<DivBackward0>)
# tensor([-3.2996], grad_fn=<DivBackward0>)
# tensor([-3.3127], grad_fn=<DivBackward0>)
# tensor([-3.3259], grad_fn=<DivBackward0>)
# tensor([-3.3374], grad_fn=<DivBackward0>)
# tensor([-3.3250], grad_fn=<DivBackward0>)
# tensor([-3.3224], grad_fn=<DivBackward0>)
# tensor([-3.3321], grad_fn=<DivBackward0>)
# tensor([-3.3434], grad_fn=<DivBackward0>)
# tensor([-3.3492], grad_fn=<DivBackward0>)
# tensor([-3.3463], grad_fn=<DivBackward0>)
# tensor([-3.3724], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 15
# tensor([-3.3698], grad_fn=<DivBackward0>)
# tensor([-3.4436], grad_fn=<DivBackward0>)
# tensor([-3.4371], grad_fn=<DivBackward0>)
# tensor([-3.4345], grad_fn=<DivBackward0>)
# tensor([-3.4216], grad_fn=<DivBackward0>)
# tensor([-3.4008], grad_fn=<DivBackward0>)
# tensor([-3.4012], grad_fn=<DivBackward0>)
# tensor([-3.4023], grad_fn=<DivBackward0>)
# tensor([-3.4111], grad_fn=<DivBackward0>)
# tensor([-3.4164], grad_fn=<DivBackward0>)
# tensor([-3.4177], grad_fn=<DivBackward0>)
# tensor([-3.4130], grad_fn=<DivBackward0>)
# tensor([-3.4193], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 16
# tensor([-3.4854], grad_fn=<DivBackward0>)
# tensor([-3.5461], grad_fn=<DivBackward0>)
# tensor([-3.5404], grad_fn=<DivBackward0>)
# tensor([-3.4936], grad_fn=<DivBackward0>)
# tensor([-3.4870], grad_fn=<DivBackward0>)
# tensor([-3.4838], grad_fn=<DivBackward0>)
# tensor([-3.4552], grad_fn=<DivBackward0>)
# tensor([-3.4378], grad_fn=<DivBackward0>)
# tensor([-3.4530], grad_fn=<DivBackward0>)
# tensor([-3.4603], grad_fn=<DivBackward0>)
# tensor([-3.4623], grad_fn=<DivBackward0>)
# tensor([-3.4540], grad_fn=<DivBackward0>)
# tensor([-3.4519], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 17
# tensor([-3.5797], grad_fn=<DivBackward0>)
# tensor([-3.5320], grad_fn=<DivBackward0>)
# tensor([-3.5321], grad_fn=<DivBackward0>)
# tensor([-3.5015], grad_fn=<DivBackward0>)
# tensor([-3.4787], grad_fn=<DivBackward0>)
# tensor([-3.4533], grad_fn=<DivBackward0>)
# tensor([-3.4488], grad_fn=<DivBackward0>)
# tensor([-3.4793], grad_fn=<DivBackward0>)
# tensor([-3.4795], grad_fn=<DivBackward0>)
# tensor([-3.4853], grad_fn=<DivBackward0>)
# tensor([-3.4868], grad_fn=<DivBackward0>)
# tensor([-3.4731], grad_fn=<DivBackward0>)
# tensor([-3.4767], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 18
# tensor([-3.5886], grad_fn=<DivBackward0>)
# tensor([-3.6157], grad_fn=<DivBackward0>)
# tensor([-3.6007], grad_fn=<DivBackward0>)
# tensor([-3.5667], grad_fn=<DivBackward0>)
# tensor([-3.5710], grad_fn=<DivBackward0>)
# tensor([-3.5513], grad_fn=<DivBackward0>)
# tensor([-3.5367], grad_fn=<DivBackward0>)
# tensor([-3.5305], grad_fn=<DivBackward0>)
# tensor([-3.5355], grad_fn=<DivBackward0>)
# tensor([-3.5311], grad_fn=<DivBackward0>)
# tensor([-3.5199], grad_fn=<DivBackward0>)
# tensor([-3.5228], grad_fn=<DivBackward0>)
# tensor([-3.5229], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 19
# tensor([-3.4755], grad_fn=<DivBackward0>)
# tensor([-3.4909], grad_fn=<DivBackward0>)
# tensor([-3.4920], grad_fn=<DivBackward0>)
# tensor([-3.5188], grad_fn=<DivBackward0>)
# tensor([-3.5400], grad_fn=<DivBackward0>)
# tensor([-3.5319], grad_fn=<DivBackward0>)
# tensor([-3.5540], grad_fn=<DivBackward0>)
# tensor([-3.5718], grad_fn=<DivBackward0>)
# tensor([-3.5555], grad_fn=<DivBackward0>)
# tensor([-3.5450], grad_fn=<DivBackward0>)
# tensor([-3.5518], grad_fn=<DivBackward0>)
# tensor([-3.5562], grad_fn=<DivBackward0>)
# tensor([-3.5808], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 20
# tensor([-3.6571], grad_fn=<DivBackward0>)
# tensor([-3.6468], grad_fn=<DivBackward0>)
# tensor([-3.6478], grad_fn=<DivBackward0>)
# tensor([-3.6080], grad_fn=<DivBackward0>)
# tensor([-3.5918], grad_fn=<DivBackward0>)
# tensor([-3.5789], grad_fn=<DivBackward0>)
# tensor([-3.5722], grad_fn=<DivBackward0>)
# tensor([-3.5756], grad_fn=<DivBackward0>)
# tensor([-3.5790], grad_fn=<DivBackward0>)
# tensor([-3.5772], grad_fn=<DivBackward0>)
# tensor([-3.5835], grad_fn=<DivBackward0>)
# tensor([-3.5960], grad_fn=<DivBackward0>)
# tensor([-3.5832], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 21
# tensor([-3.6896], grad_fn=<DivBackward0>)
# tensor([-3.6381], grad_fn=<DivBackward0>)
# tensor([-3.6065], grad_fn=<DivBackward0>)
# tensor([-3.6229], grad_fn=<DivBackward0>)
# tensor([-3.6037], grad_fn=<DivBackward0>)
# tensor([-3.5745], grad_fn=<DivBackward0>)
# tensor([-3.5987], grad_fn=<DivBackward0>)
# tensor([-3.6005], grad_fn=<DivBackward0>)
# tensor([-3.6129], grad_fn=<DivBackward0>)
# tensor([-3.5963], grad_fn=<DivBackward0>)
# tensor([-3.6060], grad_fn=<DivBackward0>)
# tensor([-3.6124], grad_fn=<DivBackward0>)
# tensor([-3.5612], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 22
# tensor([-3.6304], grad_fn=<DivBackward0>)
# tensor([-3.6576], grad_fn=<DivBackward0>)
# tensor([-3.5997], grad_fn=<DivBackward0>)
# tensor([-3.6280], grad_fn=<DivBackward0>)
# tensor([-3.6067], grad_fn=<DivBackward0>)
# tensor([-3.5912], grad_fn=<DivBackward0>)
# tensor([-3.5834], grad_fn=<DivBackward0>)
# tensor([-3.6012], grad_fn=<DivBackward0>)
# tensor([-3.6033], grad_fn=<DivBackward0>)
# tensor([-3.6143], grad_fn=<DivBackward0>)
# tensor([-3.6144], grad_fn=<DivBackward0>)
# tensor([-3.6190], grad_fn=<DivBackward0>)
# tensor([-3.6163], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 23
# tensor([-3.5277], grad_fn=<DivBackward0>)
# tensor([-3.5629], grad_fn=<DivBackward0>)
# tensor([-3.5741], grad_fn=<DivBackward0>)
# tensor([-3.5703], grad_fn=<DivBackward0>)
# tensor([-3.5882], grad_fn=<DivBackward0>)
# tensor([-3.6061], grad_fn=<DivBackward0>)
# tensor([-3.6269], grad_fn=<DivBackward0>)
# tensor([-3.6261], grad_fn=<DivBackward0>)
# tensor([-3.6257], grad_fn=<DivBackward0>)
# tensor([-3.6260], grad_fn=<DivBackward0>)
# tensor([-3.6399], grad_fn=<DivBackward0>)
# tensor([-3.6456], grad_fn=<DivBackward0>)
# tensor([-3.6390], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 24
# tensor([-3.5733], grad_fn=<DivBackward0>)
# tensor([-3.5650], grad_fn=<DivBackward0>)
# tensor([-3.5552], grad_fn=<DivBackward0>)
# tensor([-3.5876], grad_fn=<DivBackward0>)
# tensor([-3.6224], grad_fn=<DivBackward0>)
# tensor([-3.6202], grad_fn=<DivBackward0>)
# tensor([-3.6205], grad_fn=<DivBackward0>)
# tensor([-3.6434], grad_fn=<DivBackward0>)
# tensor([-3.6511], grad_fn=<DivBackward0>)
# tensor([-3.6552], grad_fn=<DivBackward0>)
# tensor([-3.6752], grad_fn=<DivBackward0>)
# tensor([-3.6663], grad_fn=<DivBackward0>)
# tensor([-3.6460], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 25
# tensor([-3.7861], grad_fn=<DivBackward0>)
# tensor([-3.6371], grad_fn=<DivBackward0>)
# tensor([-3.5949], grad_fn=<DivBackward0>)
# tensor([-3.6343], grad_fn=<DivBackward0>)
# tensor([-3.6537], grad_fn=<DivBackward0>)
# tensor([-3.6541], grad_fn=<DivBackward0>)
# tensor([-3.6643], grad_fn=<DivBackward0>)
# tensor([-3.6393], grad_fn=<DivBackward0>)
# tensor([-3.6487], grad_fn=<DivBackward0>)
# tensor([-3.6345], grad_fn=<DivBackward0>)
# tensor([-3.6362], grad_fn=<DivBackward0>)
# tensor([-3.6342], grad_fn=<DivBackward0>)
# tensor([-3.6543], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 26
# tensor([-3.6524], grad_fn=<DivBackward0>)
# tensor([-3.6675], grad_fn=<DivBackward0>)
# tensor([-3.6487], grad_fn=<DivBackward0>)
# tensor([-3.6485], grad_fn=<DivBackward0>)
# tensor([-3.6506], grad_fn=<DivBackward0>)
# tensor([-3.6458], grad_fn=<DivBackward0>)
# tensor([-3.6426], grad_fn=<DivBackward0>)
# tensor([-3.6491], grad_fn=<DivBackward0>)
# tensor([-3.6565], grad_fn=<DivBackward0>)
# tensor([-3.6451], grad_fn=<DivBackward0>)
# tensor([-3.6523], grad_fn=<DivBackward0>)
# tensor([-3.6580], grad_fn=<DivBackward0>)
# tensor([-3.6847], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 27
# tensor([-3.7675], grad_fn=<DivBackward0>)
# tensor([-3.7186], grad_fn=<DivBackward0>)
# tensor([-3.7157], grad_fn=<DivBackward0>)
# tensor([-3.7142], grad_fn=<DivBackward0>)
# tensor([-3.7017], grad_fn=<DivBackward0>)
# tensor([-3.6977], grad_fn=<DivBackward0>)
# tensor([-3.6914], grad_fn=<DivBackward0>)
# tensor([-3.6822], grad_fn=<DivBackward0>)
# tensor([-3.6797], grad_fn=<DivBackward0>)
# tensor([-3.6969], grad_fn=<DivBackward0>)
# tensor([-3.7030], grad_fn=<DivBackward0>)
# tensor([-3.6930], grad_fn=<DivBackward0>)
# tensor([-3.7010], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 28
# tensor([-3.7408], grad_fn=<DivBackward0>)
# tensor([-3.6775], grad_fn=<DivBackward0>)
# tensor([-3.7454], grad_fn=<DivBackward0>)
# tensor([-3.7231], grad_fn=<DivBackward0>)
# tensor([-3.7500], grad_fn=<DivBackward0>)
# tensor([-3.7676], grad_fn=<DivBackward0>)
# tensor([-3.7584], grad_fn=<DivBackward0>)
# tensor([-3.7352], grad_fn=<DivBackward0>)
# tensor([-3.7386], grad_fn=<DivBackward0>)
# tensor([-3.7314], grad_fn=<DivBackward0>)
# tensor([-3.7350], grad_fn=<DivBackward0>)
# tensor([-3.7335], grad_fn=<DivBackward0>)
# tensor([-3.7321], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 29
# tensor([-3.6539], grad_fn=<DivBackward0>)
# tensor([-3.7181], grad_fn=<DivBackward0>)
# tensor([-3.7104], grad_fn=<DivBackward0>)
# tensor([-3.6798], grad_fn=<DivBackward0>)
# tensor([-3.6830], grad_fn=<DivBackward0>)
# tensor([-3.6736], grad_fn=<DivBackward0>)
# tensor([-3.6897], grad_fn=<DivBackward0>)
# tensor([-3.6630], grad_fn=<DivBackward0>)
# tensor([-3.6812], grad_fn=<DivBackward0>)
# tensor([-3.6829], grad_fn=<DivBackward0>)
# tensor([-3.6874], grad_fn=<DivBackward0>)
# tensor([-3.6913], grad_fn=<DivBackward0>)
# tensor([-3.6913], grad_fn=<DivBackward0>)

# %%
net_EE.eval()
for index, chan_val in enumerate(val_dataloader):
    print(index)
    p_dnn = tx_max * net_EE(chan_val.to(device)).detach().numpy()
    chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
    SE_DNN, EE_DNN, CUE_vio_DNN, DUE_vio_DNN = cal_rate_NP(chan_val_rev, p_dnn, tx_max, noise, DUE_thr, I_thr, P_c)

print(f"SE:{SE_DNN:.3} bps/Hz, EE:{EE_DNN*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_DNN*100:.2f}%, Vio(DUE):{DUE_vio_DNN*100:.2f}%")
# Out:
# 0
# SE:7.31 bps/Hz, EE:58.2bps/J/Hz, Vio(CUE):0.55%, Vio(DUE):21.75%

# %% [markdown]
# ## D. Easy way to decrease the outage rate
# --- Ensemble

# %%
def cal_rate_NP_ensemble(channel, tx_power_in_1, tx_power_in_2, tx_max, noise, DUE_thr, I_thr, P_c):
    num_sample = channel.shape[0]
    num_channel = channel.shape[1]
    num_D2D_user = channel.shape[2] - 1

    ## Initialization
    tot_SE = 0
    tot_EE = 0
    tot_cap_CUE_vio = 0
    tot_cap_DUE_vio = 0
    tot_cap_CUE_vio_num = 0.001
    tot_cap_DUE_vio_num = 0.001
    DUE_violation = 0
    CUE_violation = 0
    tot_success_prob = 0
    
    ## Append tx power and CUE tx power
    tx_power_1 = np.hstack((tx_power_in_1, tx_max * np.ones((tx_power_in_1.shape[0], 1, num_channel))))
    tx_power_2 = np.hstack((tx_power_in_2, tx_max * np.ones((tx_power_in_2.shape[0], 1, num_channel))))
    
    for i in range(num_sample):
        cur_cap_1 = 0
        DUE_mask_1 = 1
        CUE_mask_1 = 1
        
        cur_cap_2 = 0
        DUE_mask_2 = 1
        CUE_mask_2 = 1
        
        DUE_mask = 1
        CUE_mask = 1

        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_power = tx_power_1[i, :, j]
            cur_power = np.array([cur_power])
            cur_ch_cap = cal_RATE_one_sample_one_channel(cur_ch, cur_power, noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, cur_power)
            cur_cap_1 = cur_cap_1 + cur_ch_cap[0]
            CUE_mask_1 = CUE_mask_1 * (inter[0, num_D2D_user] <= I_thr)

        for j in range(num_D2D_user):
            DUE_mask_1 = DUE_mask_1 * (cur_cap_1[j] >= DUE_thr)

        D2D_SE_sum_1 = np.sum(cur_cap_1[:-1])*CUE_mask_1*DUE_mask_1
        D2D_EE_sum_1 = np.sum(cur_cap_1[:-1]/(np.sum(tx_power_in_1[i], axis=1)+P_c))*CUE_mask_1*DUE_mask_1

        
        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_power = tx_power_2[i, :, j]
            cur_power = np.array([cur_power])
            cur_ch_cap = cal_RATE_one_sample_one_channel(cur_ch, cur_power, noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, cur_power)
            cur_cap_2 = cur_cap_2 + cur_ch_cap[0]
            CUE_mask_2 = CUE_mask_2 * (inter[0, num_D2D_user] <= I_thr)

        for j in range(num_D2D_user):
            DUE_mask_2 = DUE_mask_2 * (cur_cap_2[j] >= DUE_thr)

        D2D_SE_sum_2 = np.sum(cur_cap_2[:-1])*CUE_mask_2*DUE_mask_2
        D2D_EE_sum_2 = np.sum(cur_cap_2[:-1]/(np.sum(tx_power_in_2[i], axis=1)+P_c))*CUE_mask_2*DUE_mask_2

        
        if D2D_SE_sum_1 > D2D_SE_sum_2:
            D2D_SE_sum = D2D_SE_sum_1
            D2D_EE_sum = D2D_EE_sum_1
            CUE_mask = CUE_mask_1
            DUE_mask = DUE_mask_1
        else:
            D2D_SE_sum = D2D_SE_sum_2
            D2D_EE_sum = D2D_EE_sum_2
            CUE_mask = CUE_mask_2
            DUE_mask = DUE_mask_2
        
        
        if CUE_mask == 0:
            CUE_violation = CUE_violation + 1
        if DUE_mask == 0:
            DUE_violation = DUE_violation + 1

        tot_SE = tot_SE + D2D_SE_sum
        tot_EE = tot_EE + D2D_EE_sum


    tot_SE = tot_SE / num_D2D_user / num_sample
    tot_EE = tot_EE / num_D2D_user / num_sample
    PRO_DUE_vio = DUE_violation / (num_sample)
    PRO_CUE_vio = CUE_violation / (num_sample)

    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio

# %%
net_1 = Net(Num_user, Num_channel, 1000, 5).to(device)
net_1.train()
optimizer = torch.optim.Adam(net_1.parameters(), lr=2*1e-3)

# %%
for i in range(20):
    print("")
    print("**"*50)
    print(f"training epoch = {i}")
    cur_loss_tot = 0
    for index, chan in enumerate(train_dataloader):
        net_1.train()
        optimizer.zero_grad()

        p_dnn = net_1(chan.to(device))

        cur_loss = My_Loss(p_dnn, chan.to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat, opt="SE")

        cur_loss_tot += cur_loss

        cur_loss.backward()
        optimizer.step()
        print(cur_loss_tot/(index+1))
# Out:
# ****************************************************************************************************
# training epoch = 0
# tensor([86.5510], grad_fn=<DivBackward0>)
# tensor([44.3734], grad_fn=<DivBackward0>)
# tensor([30.0967], grad_fn=<DivBackward0>)
# tensor([22.8209], grad_fn=<DivBackward0>)
# tensor([18.2602], grad_fn=<DivBackward0>)
# tensor([15.1637], grad_fn=<DivBackward0>)
# tensor([12.8806], grad_fn=<DivBackward0>)
# tensor([11.1447], grad_fn=<DivBackward0>)
# tensor([9.7729], grad_fn=<DivBackward0>)
# tensor([8.6858], grad_fn=<DivBackward0>)
# tensor([7.7847], grad_fn=<DivBackward0>)
# tensor([7.0020], grad_fn=<DivBackward0>)
# tensor([6.3098], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 1
# tensor([-2.0073], grad_fn=<DivBackward0>)
# tensor([-1.9684], grad_fn=<DivBackward0>)
# tensor([-2.0846], grad_fn=<DivBackward0>)
# tensor([-2.1466], grad_fn=<DivBackward0>)
# tensor([-2.2252], grad_fn=<DivBackward0>)
# tensor([-2.3077], grad_fn=<DivBackward0>)
# tensor([-2.4062], grad_fn=<DivBackward0>)
# tensor([-2.4996], grad_fn=<DivBackward0>)
# tensor([-2.5757], grad_fn=<DivBackward0>)
# tensor([-2.6378], grad_fn=<DivBackward0>)
# tensor([-2.7172], grad_fn=<DivBackward0>)
# tensor([-2.7776], grad_fn=<DivBackward0>)
# tensor([-2.8189], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 2
# tensor([-3.6553], grad_fn=<DivBackward0>)
# tensor([-3.6944], grad_fn=<DivBackward0>)
# tensor([-3.7828], grad_fn=<DivBackward0>)
# tensor([-3.7914], grad_fn=<DivBackward0>)
# tensor([-3.8708], grad_fn=<DivBackward0>)
# tensor([-3.8972], grad_fn=<DivBackward0>)
# tensor([-3.9618], grad_fn=<DivBackward0>)
# tensor([-3.9839], grad_fn=<DivBackward0>)
# tensor([-4.0038], grad_fn=<DivBackward0>)
# tensor([-4.0343], grad_fn=<DivBackward0>)
# tensor([-4.0866], grad_fn=<DivBackward0>)
# tensor([-4.1158], grad_fn=<DivBackward0>)
# tensor([-4.1522], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 3
# tensor([-4.6454], grad_fn=<DivBackward0>)
# tensor([-4.6191], grad_fn=<DivBackward0>)
# tensor([-4.6715], grad_fn=<DivBackward0>)
# tensor([-4.6903], grad_fn=<DivBackward0>)
# tensor([-4.7318], grad_fn=<DivBackward0>)
# tensor([-4.7359], grad_fn=<DivBackward0>)
# tensor([-4.7373], grad_fn=<DivBackward0>)
# tensor([-4.7683], grad_fn=<DivBackward0>)
# tensor([-4.7994], grad_fn=<DivBackward0>)
# tensor([-4.8119], grad_fn=<DivBackward0>)
# tensor([-4.8318], grad_fn=<DivBackward0>)
# tensor([-4.8645], grad_fn=<DivBackward0>)
# tensor([-4.8624], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 4
# tensor([-5.4519], grad_fn=<DivBackward0>)
# tensor([-5.3947], grad_fn=<DivBackward0>)
# tensor([-5.3769], grad_fn=<DivBackward0>)
# tensor([-5.3693], grad_fn=<DivBackward0>)
# tensor([-5.3443], grad_fn=<DivBackward0>)
# tensor([-5.3107], grad_fn=<DivBackward0>)
# tensor([-5.3197], grad_fn=<DivBackward0>)
# tensor([-5.3191], grad_fn=<DivBackward0>)
# tensor([-5.3183], grad_fn=<DivBackward0>)
# tensor([-5.3307], grad_fn=<DivBackward0>)
# tensor([-5.3502], grad_fn=<DivBackward0>)
# tensor([-5.3737], grad_fn=<DivBackward0>)
# tensor([-5.3846], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 5
# tensor([-5.5950], grad_fn=<DivBackward0>)
# tensor([-5.5697], grad_fn=<DivBackward0>)
# tensor([-5.5874], grad_fn=<DivBackward0>)
# tensor([-5.5878], grad_fn=<DivBackward0>)
# tensor([-5.6589], grad_fn=<DivBackward0>)
# tensor([-5.6721], grad_fn=<DivBackward0>)
# tensor([-5.7072], grad_fn=<DivBackward0>)
# tensor([-5.7260], grad_fn=<DivBackward0>)
# tensor([-5.7173], grad_fn=<DivBackward0>)
# tensor([-5.7374], grad_fn=<DivBackward0>)
# tensor([-5.7563], grad_fn=<DivBackward0>)
# tensor([-5.7624], grad_fn=<DivBackward0>)
# tensor([-5.7975], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 6
# tensor([-5.9928], grad_fn=<DivBackward0>)
# tensor([-5.9764], grad_fn=<DivBackward0>)
# tensor([-5.8646], grad_fn=<DivBackward0>)
# tensor([-5.8195], grad_fn=<DivBackward0>)
# tensor([-5.7596], grad_fn=<DivBackward0>)
# tensor([-5.7471], grad_fn=<DivBackward0>)
# tensor([-5.7261], grad_fn=<DivBackward0>)
# tensor([-5.7559], grad_fn=<DivBackward0>)
# tensor([-5.8017], grad_fn=<DivBackward0>)
# tensor([-5.7913], grad_fn=<DivBackward0>)
# tensor([-5.8035], grad_fn=<DivBackward0>)
# tensor([-5.8174], grad_fn=<DivBackward0>)
# tensor([-5.8348], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 7
# tensor([-5.9416], grad_fn=<DivBackward0>)
# tensor([-5.9478], grad_fn=<DivBackward0>)
# tensor([-6.0281], grad_fn=<DivBackward0>)
# tensor([-6.0550], grad_fn=<DivBackward0>)
# tensor([-6.1198], grad_fn=<DivBackward0>)
# tensor([-6.1220], grad_fn=<DivBackward0>)
# tensor([-6.1145], grad_fn=<DivBackward0>)
# tensor([-6.1267], grad_fn=<DivBackward0>)
# tensor([-6.1524], grad_fn=<DivBackward0>)
# tensor([-6.1715], grad_fn=<DivBackward0>)
# tensor([-6.1805], grad_fn=<DivBackward0>)
# tensor([-6.1975], grad_fn=<DivBackward0>)
# tensor([-6.2209], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 8
# tensor([-6.1701], grad_fn=<DivBackward0>)
# tensor([-6.2472], grad_fn=<DivBackward0>)
# tensor([-6.2329], grad_fn=<DivBackward0>)
# tensor([-6.2911], grad_fn=<DivBackward0>)
# tensor([-6.3093], grad_fn=<DivBackward0>)
# tensor([-6.3275], grad_fn=<DivBackward0>)
# tensor([-6.3647], grad_fn=<DivBackward0>)
# tensor([-6.3712], grad_fn=<DivBackward0>)
# tensor([-6.3579], grad_fn=<DivBackward0>)
# tensor([-6.3516], grad_fn=<DivBackward0>)
# tensor([-6.3387], grad_fn=<DivBackward0>)
# tensor([-6.3337], grad_fn=<DivBackward0>)
# tensor([-6.3431], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 9
# tensor([-6.5834], grad_fn=<DivBackward0>)
# tensor([-6.4067], grad_fn=<DivBackward0>)
# tensor([-6.3951], grad_fn=<DivBackward0>)
# tensor([-6.3905], grad_fn=<DivBackward0>)
# tensor([-6.3753], grad_fn=<DivBackward0>)
# tensor([-6.3693], grad_fn=<DivBackward0>)
# tensor([-6.3844], grad_fn=<DivBackward0>)
# tensor([-6.4079], grad_fn=<DivBackward0>)
# tensor([-6.4257], grad_fn=<DivBackward0>)
# tensor([-6.4371], grad_fn=<DivBackward0>)
# tensor([-6.4433], grad_fn=<DivBackward0>)
# tensor([-6.4550], grad_fn=<DivBackward0>)
# tensor([-6.4091], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 10
# tensor([-6.5648], grad_fn=<DivBackward0>)
# tensor([-6.4987], grad_fn=<DivBackward0>)
# tensor([-6.5040], grad_fn=<DivBackward0>)
# tensor([-6.4679], grad_fn=<DivBackward0>)
# tensor([-6.4569], grad_fn=<DivBackward0>)
# tensor([-6.4556], grad_fn=<DivBackward0>)
# tensor([-6.4632], grad_fn=<DivBackward0>)
# tensor([-6.4545], grad_fn=<DivBackward0>)
# tensor([-6.4577], grad_fn=<DivBackward0>)
# tensor([-6.4689], grad_fn=<DivBackward0>)
# tensor([-6.4977], grad_fn=<DivBackward0>)
# tensor([-6.4989], grad_fn=<DivBackward0>)
# tensor([-6.4765], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 11
# tensor([-6.5994], grad_fn=<DivBackward0>)
# tensor([-6.6944], grad_fn=<DivBackward0>)
# tensor([-6.6426], grad_fn=<DivBackward0>)
# tensor([-6.6514], grad_fn=<DivBackward0>)
# tensor([-6.6580], grad_fn=<DivBackward0>)
# tensor([-6.6586], grad_fn=<DivBackward0>)
# tensor([-6.6546], grad_fn=<DivBackward0>)
# tensor([-6.6578], grad_fn=<DivBackward0>)
# tensor([-6.6594], grad_fn=<DivBackward0>)
# tensor([-6.6580], grad_fn=<DivBackward0>)
# tensor([-6.6674], grad_fn=<DivBackward0>)
# tensor([-6.6849], grad_fn=<DivBackward0>)
# tensor([-6.6781], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 12
# tensor([-6.7461], grad_fn=<DivBackward0>)
# tensor([-6.6598], grad_fn=<DivBackward0>)
# tensor([-6.6348], grad_fn=<DivBackward0>)
# tensor([-6.6645], grad_fn=<DivBackward0>)
# tensor([-6.7361], grad_fn=<DivBackward0>)
# tensor([-6.7635], grad_fn=<DivBackward0>)
# tensor([-6.7490], grad_fn=<DivBackward0>)
# tensor([-6.7235], grad_fn=<DivBackward0>)
# tensor([-6.7208], grad_fn=<DivBackward0>)
# tensor([-6.7130], grad_fn=<DivBackward0>)
# tensor([-6.7237], grad_fn=<DivBackward0>)
# tensor([-6.7345], grad_fn=<DivBackward0>)
# tensor([-6.7762], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 13
# tensor([-6.8473], grad_fn=<DivBackward0>)
# tensor([-6.8553], grad_fn=<DivBackward0>)
# tensor([-6.7585], grad_fn=<DivBackward0>)
# tensor([-6.7563], grad_fn=<DivBackward0>)
# tensor([-6.7164], grad_fn=<DivBackward0>)
# tensor([-6.7413], grad_fn=<DivBackward0>)
# tensor([-6.7645], grad_fn=<DivBackward0>)
# tensor([-6.7660], grad_fn=<DivBackward0>)
# tensor([-6.7818], grad_fn=<DivBackward0>)
# tensor([-6.7830], grad_fn=<DivBackward0>)
# tensor([-6.7907], grad_fn=<DivBackward0>)
# tensor([-6.7938], grad_fn=<DivBackward0>)
# tensor([-6.7737], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 14
# tensor([-6.8192], grad_fn=<DivBackward0>)
# tensor([-6.9190], grad_fn=<DivBackward0>)
# tensor([-6.8208], grad_fn=<DivBackward0>)
# tensor([-6.7562], grad_fn=<DivBackward0>)
# tensor([-6.7831], grad_fn=<DivBackward0>)
# tensor([-6.7654], grad_fn=<DivBackward0>)
# tensor([-6.7621], grad_fn=<DivBackward0>)
# tensor([-6.7654], grad_fn=<DivBackward0>)
# tensor([-6.7796], grad_fn=<DivBackward0>)
# tensor([-6.7778], grad_fn=<DivBackward0>)
# tensor([-6.7882], grad_fn=<DivBackward0>)
# tensor([-6.7901], grad_fn=<DivBackward0>)
# tensor([-6.7650], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 15
# tensor([-6.6983], grad_fn=<DivBackward0>)
# tensor([-6.6414], grad_fn=<DivBackward0>)
# tensor([-6.6975], grad_fn=<DivBackward0>)
# tensor([-6.6831], grad_fn=<DivBackward0>)
# tensor([-6.7189], grad_fn=<DivBackward0>)
# tensor([-6.6921], grad_fn=<DivBackward0>)
# tensor([-6.7063], grad_fn=<DivBackward0>)
# tensor([-6.7187], grad_fn=<DivBackward0>)
# tensor([-6.6944], grad_fn=<DivBackward0>)
# tensor([-6.6949], grad_fn=<DivBackward0>)
# tensor([-6.6980], grad_fn=<DivBackward0>)
# tensor([-6.7098], grad_fn=<DivBackward0>)
# tensor([-6.7180], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 16
# tensor([-6.6662], grad_fn=<DivBackward0>)
# tensor([-6.6602], grad_fn=<DivBackward0>)
# tensor([-6.7272], grad_fn=<DivBackward0>)
# tensor([-6.7299], grad_fn=<DivBackward0>)
# tensor([-6.7151], grad_fn=<DivBackward0>)
# tensor([-6.7183], grad_fn=<DivBackward0>)
# tensor([-6.7308], grad_fn=<DivBackward0>)
# tensor([-6.7312], grad_fn=<DivBackward0>)
# tensor([-6.7416], grad_fn=<DivBackward0>)
# tensor([-6.7785], grad_fn=<DivBackward0>)
# tensor([-6.7886], grad_fn=<DivBackward0>)
# tensor([-6.7991], grad_fn=<DivBackward0>)
# tensor([-6.8211], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 17
# tensor([-6.9402], grad_fn=<DivBackward0>)
# tensor([-6.8191], grad_fn=<DivBackward0>)
# tensor([-6.9101], grad_fn=<DivBackward0>)
# tensor([-6.8796], grad_fn=<DivBackward0>)
# tensor([-6.8343], grad_fn=<DivBackward0>)
# tensor([-6.8512], grad_fn=<DivBackward0>)
# tensor([-6.8562], grad_fn=<DivBackward0>)
# tensor([-6.8777], grad_fn=<DivBackward0>)
# tensor([-6.8932], grad_fn=<DivBackward0>)
# tensor([-6.9073], grad_fn=<DivBackward0>)
# tensor([-6.9265], grad_fn=<DivBackward0>)
# tensor([-6.9207], grad_fn=<DivBackward0>)
# tensor([-6.9053], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 18
# tensor([-7.0057], grad_fn=<DivBackward0>)
# tensor([-7.0150], grad_fn=<DivBackward0>)
# tensor([-6.9717], grad_fn=<DivBackward0>)
# tensor([-6.9221], grad_fn=<DivBackward0>)
# tensor([-6.9323], grad_fn=<DivBackward0>)
# tensor([-6.9530], grad_fn=<DivBackward0>)
# tensor([-6.9585], grad_fn=<DivBackward0>)
# tensor([-6.9508], grad_fn=<DivBackward0>)
# tensor([-6.9566], grad_fn=<DivBackward0>)
# tensor([-6.9465], grad_fn=<DivBackward0>)
# tensor([-6.9464], grad_fn=<DivBackward0>)
# tensor([-6.9448], grad_fn=<DivBackward0>)
# tensor([-6.9829], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 19
# tensor([-7.0613], grad_fn=<DivBackward0>)
# tensor([-7.0064], grad_fn=<DivBackward0>)
# tensor([-6.9747], grad_fn=<DivBackward0>)
# tensor([-6.9643], grad_fn=<DivBackward0>)
# tensor([-6.9694], grad_fn=<DivBackward0>)
# tensor([-6.9510], grad_fn=<DivBackward0>)
# tensor([-6.9502], grad_fn=<DivBackward0>)
# tensor([-6.9497], grad_fn=<DivBackward0>)
# tensor([-6.9572], grad_fn=<DivBackward0>)
# tensor([-6.9621], grad_fn=<DivBackward0>)
# tensor([-6.9666], grad_fn=<DivBackward0>)
# tensor([-6.9659], grad_fn=<DivBackward0>)
# tensor([-6.9756], grad_fn=<DivBackward0>)

# %%
net_2 = Net(Num_user, Num_channel, 1000, 5).to(device)
net_2.train()
optimizer = torch.optim.Adam(net_2.parameters(), lr=2*1e-3)

# %%
for i in range(20):
    print("")
    print("**"*50)
    print(f"training epoch = {i}")
    cur_loss_tot = 0
    for index, chan in enumerate(train_dataloader):
        net_2.train()
        optimizer.zero_grad()

        p_dnn = net_2(chan.to(device))

        cur_loss = My_Loss(p_dnn, chan.to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat, opt="SE")

        cur_loss_tot += cur_loss

        cur_loss.backward()
        optimizer.step()
        print(cur_loss_tot/(index+1))
# Out:
# ****************************************************************************************************
# training epoch = 0
# tensor([80.0998], grad_fn=<DivBackward0>)
# tensor([40.9379], grad_fn=<DivBackward0>)
# tensor([27.8420], grad_fn=<DivBackward0>)
# tensor([21.1444], grad_fn=<DivBackward0>)
# tensor([17.0375], grad_fn=<DivBackward0>)
# tensor([14.1721], grad_fn=<DivBackward0>)
# tensor([12.0733], grad_fn=<DivBackward0>)
# tensor([10.4586], grad_fn=<DivBackward0>)
# tensor([9.1904], grad_fn=<DivBackward0>)
# tensor([8.1347], grad_fn=<DivBackward0>)
# tensor([7.2850], grad_fn=<DivBackward0>)
# tensor([6.5354], grad_fn=<DivBackward0>)
# tensor([5.9037], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 1
# tensor([-2.1607], grad_fn=<DivBackward0>)
# tensor([-2.2019], grad_fn=<DivBackward0>)
# tensor([-2.2241], grad_fn=<DivBackward0>)
# tensor([-2.2658], grad_fn=<DivBackward0>)
# tensor([-2.3331], grad_fn=<DivBackward0>)
# tensor([-2.3790], grad_fn=<DivBackward0>)
# tensor([-2.4508], grad_fn=<DivBackward0>)
# tensor([-2.5292], grad_fn=<DivBackward0>)
# tensor([-2.5714], grad_fn=<DivBackward0>)
# tensor([-2.6251], grad_fn=<DivBackward0>)
# tensor([-2.6665], grad_fn=<DivBackward0>)
# tensor([-2.7356], grad_fn=<DivBackward0>)
# tensor([-2.7921], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 2
# tensor([-3.5606], grad_fn=<DivBackward0>)
# tensor([-3.4563], grad_fn=<DivBackward0>)
# tensor([-3.5257], grad_fn=<DivBackward0>)
# tensor([-3.5788], grad_fn=<DivBackward0>)
# tensor([-3.5987], grad_fn=<DivBackward0>)
# tensor([-3.6314], grad_fn=<DivBackward0>)
# tensor([-3.6862], grad_fn=<DivBackward0>)
# tensor([-3.7464], grad_fn=<DivBackward0>)
# tensor([-3.8089], grad_fn=<DivBackward0>)
# tensor([-3.8591], grad_fn=<DivBackward0>)
# tensor([-3.8971], grad_fn=<DivBackward0>)
# tensor([-3.9215], grad_fn=<DivBackward0>)
# tensor([-3.9451], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 3
# tensor([-4.4123], grad_fn=<DivBackward0>)
# tensor([-4.5493], grad_fn=<DivBackward0>)
# tensor([-4.5078], grad_fn=<DivBackward0>)
# tensor([-4.5708], grad_fn=<DivBackward0>)
# tensor([-4.5973], grad_fn=<DivBackward0>)
# tensor([-4.6213], grad_fn=<DivBackward0>)
# tensor([-4.6143], grad_fn=<DivBackward0>)
# tensor([-4.6390], grad_fn=<DivBackward0>)
# tensor([-4.6777], grad_fn=<DivBackward0>)
# tensor([-4.6725], grad_fn=<DivBackward0>)
# tensor([-4.6877], grad_fn=<DivBackward0>)
# tensor([-4.7006], grad_fn=<DivBackward0>)
# tensor([-4.6936], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 4
# tensor([-4.9527], grad_fn=<DivBackward0>)
# tensor([-5.0155], grad_fn=<DivBackward0>)
# tensor([-5.0517], grad_fn=<DivBackward0>)
# tensor([-5.0939], grad_fn=<DivBackward0>)
# tensor([-5.0872], grad_fn=<DivBackward0>)
# tensor([-5.1253], grad_fn=<DivBackward0>)
# tensor([-5.1474], grad_fn=<DivBackward0>)
# tensor([-5.1352], grad_fn=<DivBackward0>)
# tensor([-5.1519], grad_fn=<DivBackward0>)
# tensor([-5.1836], grad_fn=<DivBackward0>)
# tensor([-5.2036], grad_fn=<DivBackward0>)
# tensor([-5.2234], grad_fn=<DivBackward0>)
# tensor([-5.2751], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 5
# tensor([-5.6433], grad_fn=<DivBackward0>)
# tensor([-5.5859], grad_fn=<DivBackward0>)
# tensor([-5.5666], grad_fn=<DivBackward0>)
# tensor([-5.5603], grad_fn=<DivBackward0>)
# tensor([-5.5358], grad_fn=<DivBackward0>)
# tensor([-5.5785], grad_fn=<DivBackward0>)
# tensor([-5.6045], grad_fn=<DivBackward0>)
# tensor([-5.6394], grad_fn=<DivBackward0>)
# tensor([-5.6478], grad_fn=<DivBackward0>)
# tensor([-5.6533], grad_fn=<DivBackward0>)
# tensor([-5.6564], grad_fn=<DivBackward0>)
# tensor([-5.6737], grad_fn=<DivBackward0>)
# tensor([-5.6951], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 6
# tensor([-5.7187], grad_fn=<DivBackward0>)
# tensor([-5.8231], grad_fn=<DivBackward0>)
# tensor([-5.8412], grad_fn=<DivBackward0>)
# tensor([-5.8526], grad_fn=<DivBackward0>)
# tensor([-5.8619], grad_fn=<DivBackward0>)
# tensor([-5.8492], grad_fn=<DivBackward0>)
# tensor([-5.8629], grad_fn=<DivBackward0>)
# tensor([-5.8563], grad_fn=<DivBackward0>)
# tensor([-5.8748], grad_fn=<DivBackward0>)
# tensor([-5.8684], grad_fn=<DivBackward0>)
# tensor([-5.8721], grad_fn=<DivBackward0>)
# tensor([-5.8828], grad_fn=<DivBackward0>)
# tensor([-5.8774], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 7
# tensor([-5.8987], grad_fn=<DivBackward0>)
# tensor([-5.8183], grad_fn=<DivBackward0>)
# tensor([-5.8055], grad_fn=<DivBackward0>)
# tensor([-5.8114], grad_fn=<DivBackward0>)
# tensor([-5.8291], grad_fn=<DivBackward0>)
# tensor([-5.8812], grad_fn=<DivBackward0>)
# tensor([-5.8900], grad_fn=<DivBackward0>)
# tensor([-5.9238], grad_fn=<DivBackward0>)
# tensor([-5.9553], grad_fn=<DivBackward0>)
# tensor([-5.9713], grad_fn=<DivBackward0>)
# tensor([-5.9824], grad_fn=<DivBackward0>)
# tensor([-6.0006], grad_fn=<DivBackward0>)
# tensor([-6.0426], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 8
# tensor([-6.0844], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
# tensor([-6.2178], grad_fn=<DivBackward0>)
# tensor([-6.1850], grad_fn=<DivBackward0>)
# tensor([-6.2218], grad_fn=<DivBackward0>)
# tensor([-6.2408], grad_fn=<DivBackward0>)
# tensor([-6.2532], grad_fn=<DivBackward0>)
# tensor([-6.2652], grad_fn=<DivBackward0>)
# tensor([-6.2537], grad_fn=<DivBackward0>)
# tensor([-6.2772], grad_fn=<DivBackward0>)
# tensor([-6.2629], grad_fn=<DivBackward0>)
# tensor([-6.2555], grad_fn=<DivBackward0>)
# tensor([-6.2881], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 9
# tensor([-6.3260], grad_fn=<DivBackward0>)
# tensor([-6.4398], grad_fn=<DivBackward0>)
# tensor([-6.3983], grad_fn=<DivBackward0>)
# tensor([-6.3784], grad_fn=<DivBackward0>)
# tensor([-6.3531], grad_fn=<DivBackward0>)
# tensor([-6.3380], grad_fn=<DivBackward0>)
# tensor([-6.3555], grad_fn=<DivBackward0>)
# tensor([-6.3806], grad_fn=<DivBackward0>)
# tensor([-6.3908], grad_fn=<DivBackward0>)
# tensor([-6.3948], grad_fn=<DivBackward0>)
# tensor([-6.3898], grad_fn=<DivBackward0>)
# tensor([-6.3971], grad_fn=<DivBackward0>)
# tensor([-6.4418], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 10
# tensor([-6.4942], grad_fn=<DivBackward0>)
# tensor([-6.4903], grad_fn=<DivBackward0>)
# tensor([-6.5128], grad_fn=<DivBackward0>)
# tensor([-6.5124], grad_fn=<DivBackward0>)
# tensor([-6.5295], grad_fn=<DivBackward0>)
# tensor([-6.5355], grad_fn=<DivBackward0>)
# tensor([-6.5445], grad_fn=<DivBackward0>)
# tensor([-6.5432], grad_fn=<DivBackward0>)
# tensor([-6.5519], grad_fn=<DivBackward0>)
# tensor([-6.5502], grad_fn=<DivBackward0>)
# tensor([-6.5533], grad_fn=<DivBackward0>)
# tensor([-6.5565], grad_fn=<DivBackward0>)
# tensor([-6.5312], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 11
# tensor([-6.7419], grad_fn=<DivBackward0>)
# tensor([-6.7441], grad_fn=<DivBackward0>)
# tensor([-6.7082], grad_fn=<DivBackward0>)
# tensor([-6.7219], grad_fn=<DivBackward0>)
# tensor([-6.6466], grad_fn=<DivBackward0>)
# tensor([-6.6581], grad_fn=<DivBackward0>)
# tensor([-6.6358], grad_fn=<DivBackward0>)
# tensor([-6.6091], grad_fn=<DivBackward0>)
# tensor([-6.6046], grad_fn=<DivBackward0>)
# tensor([-6.6060], grad_fn=<DivBackward0>)
# tensor([-6.6200], grad_fn=<DivBackward0>)
# tensor([-6.6087], grad_fn=<DivBackward0>)
# tensor([-6.6196], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 12
# tensor([-6.4076], grad_fn=<DivBackward0>)
# tensor([-6.5181], grad_fn=<DivBackward0>)
# tensor([-6.5143], grad_fn=<DivBackward0>)
# tensor([-6.5852], grad_fn=<DivBackward0>)
# tensor([-6.6094], grad_fn=<DivBackward0>)
# tensor([-6.6164], grad_fn=<DivBackward0>)
# tensor([-6.6332], grad_fn=<DivBackward0>)
# tensor([-6.6292], grad_fn=<DivBackward0>)
# tensor([-6.6434], grad_fn=<DivBackward0>)
# tensor([-6.6392], grad_fn=<DivBackward0>)
# tensor([-6.6487], grad_fn=<DivBackward0>)
# tensor([-6.6614], grad_fn=<DivBackward0>)
# tensor([-6.6738], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 13
# tensor([-6.7717], grad_fn=<DivBackward0>)
# tensor([-6.8054], grad_fn=<DivBackward0>)
# tensor([-6.8093], grad_fn=<DivBackward0>)
# tensor([-6.8139], grad_fn=<DivBackward0>)
# tensor([-6.8138], grad_fn=<DivBackward0>)
# tensor([-6.8318], grad_fn=<DivBackward0>)
# tensor([-6.8031], grad_fn=<DivBackward0>)
# tensor([-6.7981], grad_fn=<DivBackward0>)
# tensor([-6.7886], grad_fn=<DivBackward0>)
# tensor([-6.7956], grad_fn=<DivBackward0>)
# tensor([-6.8099], grad_fn=<DivBackward0>)
# tensor([-6.8139], grad_fn=<DivBackward0>)
# tensor([-6.7892], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 14
# tensor([-6.9798], grad_fn=<DivBackward0>)
# tensor([-6.9271], grad_fn=<DivBackward0>)
# tensor([-6.8564], grad_fn=<DivBackward0>)
# tensor([-6.7952], grad_fn=<DivBackward0>)
# tensor([-6.8219], grad_fn=<DivBackward0>)
# tensor([-6.8188], grad_fn=<DivBackward0>)
# tensor([-6.8360], grad_fn=<DivBackward0>)
# tensor([-6.8364], grad_fn=<DivBackward0>)
# tensor([-6.8390], grad_fn=<DivBackward0>)
# tensor([-6.8245], grad_fn=<DivBackward0>)
# tensor([-6.8302], grad_fn=<DivBackward0>)
# tensor([-6.8285], grad_fn=<DivBackward0>)
# tensor([-6.8158], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 15
# tensor([-6.7951], grad_fn=<DivBackward0>)
# tensor([-6.8103], grad_fn=<DivBackward0>)
# tensor([-6.8694], grad_fn=<DivBackward0>)
# tensor([-6.8538], grad_fn=<DivBackward0>)
# tensor([-6.8627], grad_fn=<DivBackward0>)
# tensor([-6.8952], grad_fn=<DivBackward0>)
# tensor([-6.9267], grad_fn=<DivBackward0>)
# tensor([-6.9410], grad_fn=<DivBackward0>)
# tensor([-6.9658], grad_fn=<DivBackward0>)
# tensor([-6.9601], grad_fn=<DivBackward0>)
# tensor([-6.9460], grad_fn=<DivBackward0>)
# tensor([-6.9434], grad_fn=<DivBackward0>)
# tensor([-6.9617], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 16
# tensor([-6.8566], grad_fn=<DivBackward0>)
# tensor([-7.0153], grad_fn=<DivBackward0>)
# tensor([-6.9994], grad_fn=<DivBackward0>)
# tensor([-7.0084], grad_fn=<DivBackward0>)
# tensor([-6.9792], grad_fn=<DivBackward0>)
# tensor([-6.9955], grad_fn=<DivBackward0>)
# tensor([-6.9864], grad_fn=<DivBackward0>)
# tensor([-6.9823], grad_fn=<DivBackward0>)
# tensor([-6.9862], grad_fn=<DivBackward0>)
# tensor([-6.9764], grad_fn=<DivBackward0>)
# tensor([-6.9793], grad_fn=<DivBackward0>)
# tensor([-6.9777], grad_fn=<DivBackward0>)
# tensor([-6.9625], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 17
# tensor([-6.8677], grad_fn=<DivBackward0>)
# tensor([-6.7379], grad_fn=<DivBackward0>)
# tensor([-6.7740], grad_fn=<DivBackward0>)
# tensor([-6.8458], grad_fn=<DivBackward0>)
# tensor([-6.8655], grad_fn=<DivBackward0>)
# tensor([-6.8323], grad_fn=<DivBackward0>)
# tensor([-6.8857], grad_fn=<DivBackward0>)
# tensor([-6.9251], grad_fn=<DivBackward0>)
# tensor([-6.9189], grad_fn=<DivBackward0>)
# tensor([-6.9233], grad_fn=<DivBackward0>)
# tensor([-6.9290], grad_fn=<DivBackward0>)
# tensor([-6.9330], grad_fn=<DivBackward0>)
# tensor([-6.9242], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 18
# tensor([-6.9737], grad_fn=<DivBackward0>)
# tensor([-7.0183], grad_fn=<DivBackward0>)
# tensor([-7.0591], grad_fn=<DivBackward0>)
# tensor([-7.0261], grad_fn=<DivBackward0>)
# tensor([-7.0160], grad_fn=<DivBackward0>)
# tensor([-6.9930], grad_fn=<DivBackward0>)
# tensor([-7.0070], grad_fn=<DivBackward0>)
# tensor([-7.0295], grad_fn=<DivBackward0>)
# tensor([-7.0278], grad_fn=<DivBackward0>)
# tensor([-7.0191], grad_fn=<DivBackward0>)
# tensor([-7.0146], grad_fn=<DivBackward0>)
# tensor([-7.0120], grad_fn=<DivBackward0>)
# tensor([-7.0054], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 19
# tensor([-6.9543], grad_fn=<DivBackward0>)
# tensor([-7.0323], grad_fn=<DivBackward0>)
# tensor([-7.0616], grad_fn=<DivBackward0>)
# tensor([-7.0650], grad_fn=<DivBackward0>)
# tensor([-7.0511], grad_fn=<DivBackward0>)
# tensor([-7.0181], grad_fn=<DivBackward0>)
# tensor([-7.0351], grad_fn=<DivBackward0>)
# tensor([-7.0398], grad_fn=<DivBackward0>)
# tensor([-7.0431], grad_fn=<DivBackward0>)
# tensor([-7.0354], grad_fn=<DivBackward0>)
# tensor([-7.0367], grad_fn=<DivBackward0>)
# tensor([-7.0593], grad_fn=<DivBackward0>)
# tensor([-7.0474], grad_fn=<DivBackward0>)

# %%
net_1.eval()
for index, chan_val in enumerate(val_dataloader):
    print(index)
    p_dnn = tx_max * net_1(chan_val.to(device)).detach().numpy()
    chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
    SE_DNN, EE_DNN, CUE_vio_DNN, DUE_vio_DNN = cal_rate_NP(chan_val_rev, p_dnn, tx_max, noise, DUE_thr, I_thr, P_c)

print(f"DNN1: SE:{SE_DNN:.3} bps/Hz, EE:{EE_DNN*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_DNN*100:.2f}%, Vio(DUE):{DUE_vio_DNN*100:.2f}%")
# Out:
# 0
# DNN1: SE:8.72 bps/Hz, EE:45.9bps/J/Hz, Vio(CUE):0.35%, Vio(DUE):23.30%

# %%
net_2.eval()
for index, chan_val in enumerate(val_dataloader):
    print(index)
    p_dnn = tx_max * net_2(chan_val.to(device)).detach().numpy()
    chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
    SE_DNN, EE_DNN, CUE_vio_DNN, DUE_vio_DNN = cal_rate_NP(chan_val_rev, p_dnn, tx_max, noise, DUE_thr, I_thr, P_c)

print(f"DNN2: SE:{SE_DNN:.3} bps/Hz, EE:{EE_DNN*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_DNN*100:.2f}%, Vio(DUE):{DUE_vio_DNN*100:.2f}%")
# Out:
# 0
# DNN2: SE:8.81 bps/Hz, EE:46.4bps/J/Hz, Vio(CUE):0.55%, Vio(DUE):22.45%

# %%
for index, chan_val in enumerate(val_dataloader):
    print(index)
    p_dnn_1 = tx_max * net_1(chan_val.to(device)).detach().numpy()
    p_dnn_2 = tx_max * net_2(chan_val.to(device)).detach().numpy()
    chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
    SE_DNN, EE_DNN, CUE_vio_DNN, DUE_vio_DNN = cal_rate_NP_ensemble(chan_val_rev, p_dnn_1, p_dnn_2, tx_max, noise, DUE_thr, I_thr, P_c)

print(f"DNN_ENS: SE:{SE_DNN:.3} bps/Hz, EE:{EE_DNN*1000:.3}bps/J/Hz, Vio(CUE):{CUE_vio_DNN*100:.2f}%, Vio(DUE):{DUE_vio_DNN*100:.2f}%")
# Out:
# 0
# DNN_ENS: SE:8.95 bps/Hz, EE:47.1bps/J/Hz, Vio(CUE):0.40%, Vio(DUE):21.20%

# %% [markdown]
# ### Computation time comparison

# %% [markdown]
# #### 1 Optimal scheme

# %%
def optimal_power_for_time(channel, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE"):

    num_channel = channel.shape[1]
    num_D2D_user = channel.shape[2] - 1
    num_samples = channel.shape[0]
    tot_SE = 0
    power_mat_SE = []
    chan_infea_mat = []

    for i in tqdm(range(num_samples)):
        cur_cap = 0
        DUE_mask = 1
        CUE_mask = 1
        tx_power = tx_max * np.hstack((tx_power_set, np.ones((tx_power_set.shape[0], 1, num_channel))))

        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_ch_cap = cal_RATE_one_sample_one_channel(cur_ch, tx_power[:, :, j], noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, tx_power[:, :, j])
            cur_cap = cur_cap + cur_ch_cap
            CUE_mask = CUE_mask * (inter[:, num_D2D_user] < I_thr)
        
        for j in range(num_D2D_user):
            DUE_mask = DUE_mask * (cur_cap[:,j] > DUE_thr)
        
        CUE_mask = np.expand_dims(CUE_mask, -1)
        DUE_mask = np.expand_dims(DUE_mask, -1)
        
        sum_D2D_SE_temp = np.expand_dims(np.sum(cur_cap[:,:-1], axis=1), -1)
        sum_D2D_EE_temp = np.expand_dims(np.sum(cur_cap[:,:-1]/(np.sum(tx_power[:,:-1,:], axis=2)+P_c), axis=1), -1)
        
        D2D_SE_sum = sum_D2D_SE_temp*CUE_mask*DUE_mask
        D2D_EE_sum = sum_D2D_EE_temp*CUE_mask*DUE_mask

        if opt=="SE":
            arg_max_val = np.argmax(D2D_SE_sum)
        else:
            arg_max_val = np.argmax(D2D_EE_sum)
            
        max_SE = np.max(D2D_SE_sum)
        
        found_tx_val = tx_power[arg_max_val][:-1]

        power_mat_SE.append(found_tx_val)
        
        ## Collect the infeasible channels
        if max_SE == 0:
            chan_infea_mat.append(channel[i])
            
    return 1

# %%
ch_data_conv = val_dataset.x_data.detach().numpy()
ch_data_conv = np.exp(ch_data_conv*chan_std + chan_mean)

tx_power_set = all_possible_tx_power(Num_channel, Num_user, Num_power_level - 1)

# %%
# %%time
optimal_power_for_time(ch_data_conv, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE")
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# CPU times: user 5.32 s, sys: 233 ms, total: 5.55 s
# Wall time: 5.53 s
# 1

# %% [markdown]
# #### 2 DNN scheme

# %%
# %%time
net_1.eval()
for index, chan_val in enumerate(val_dataloader):
    for i in range(chan_val.shape[0]):
        p_dnn = tx_max * net_1(chan_val[i:i+1].to(device)).detach().numpy()
# Out:
# CPU times: user 1.83 s, sys: 3.28 ms, total: 1.84 s
# Wall time: 1.84 s

# %% [markdown]
# ####  Increase number of user to 3 (+1)

# %%
Num_user_time = 3

# %%
val_dataset_time = ChanDataset(Size_area, D2D_dist, Num_user_time, Num_channel, num_samples_val, chan_mean, chan_std)
val_dataloader_time = DataLoader(val_dataset_time, batch_size=num_samples_val, shuffle=True)

# %%
# %%time
net_time = Net(Num_user_time, Num_channel, 1000, 5).to(device)
net_time.eval()
for index, chan_val in enumerate(val_dataloader_time):
    for i in range(chan_val.shape[0]):
        p_dnn = tx_max * net_time(chan_val[i:i+1].to(device)).detach().numpy()
# Out:
# CPU times: user 1.81 s, sys: 3.39 ms, total: 1.81 s
# Wall time: 1.81 s

# %%
Num_user_time = 30
val_dataset_time = ChanDataset(Size_area, D2D_dist, Num_user_time, Num_channel, num_samples_val, chan_mean, chan_std)
val_dataloader_time = DataLoader(val_dataset_time, batch_size=num_samples_val, shuffle=True)

# %%
# %%time
net_time = Net(Num_user_time, Num_channel, 1000, 5).to(device)
net_time.eval()
for index, chan_val in enumerate(val_dataloader_time):
    for i in range(chan_val.shape[0]):
        p_dnn = tx_max * net_time(chan_val[i:i+1].to(device)).detach().numpy()
# Out:
# CPU times: user 3.59 s, sys: 16.4 ms, total: 3.61 s
# Wall time: 3.61 s

# %%
ch_data_conv = val_dataset_time.x_data.detach().numpy()
ch_data_conv = np.exp(ch_data_conv*chan_std + chan_mean)

# %%
tx_power_set = all_possible_tx_power(Num_channel, Num_user_time, Num_power_level - 1)

# %%
tx_power_set.shape
# Out:
# (91124, 3, 2)

# %%
# %%time
optimal_power_for_time(ch_data_conv, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE")
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# CPU times: user 4min 24s, sys: 7.73 s, total: 4min 31s
# Wall time: 4min 30s
# 1

# %%
tx_power_set = all_possible_tx_power(Num_channel, 4, Num_power_level - 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 tx_power_set = all_possible_tx_power(Num_channel, 4, Num_power_level - 1)
#
# Input In [47], in all_possible_tx_power(num_channel, num_user, granuty)
#       3 items = [np.arange(granuty)] * num_user * num_channel
#       4 temp_power = list(itertools.product(*items))
# ----> 5 temp_power = np.reshape(temp_power, (-1, num_user, num_channel))
#       7 power_check = np.sum(temp_power, axis=2)
#       8 flag = (power_check / (granuty - 1) <= 1).astype(int)
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:43, in _wrapit(obj, method, *args, **kwds)
#      41 except AttributeError:
#      42     wrap = None
# ---> 43 result = getattr(asarray(obj), method)(*args, **kwds)
#      44 if wrap:
#      45     if not isinstance(result, mu.ndarray):
#
# KeyboardInterrupt:

# %%
tx_power_set.shape

# %%
val_dataset_time = ChanDataset(Size_area, D2D_dist, Num_user_time+1, Num_channel, num_samples_val, chan_mean, chan_std)
val_dataloader_time = DataLoader(val_dataset_time, batch_size=num_samples_val, shuffle=True)

# %%
ch_data_conv = val_dataset_time.x_data.detach().numpy()
ch_data_conv = np.exp(ch_data_conv*chan_std + chan_mean)

# %%
# %%time
optimal_power_for_time(ch_data_conv, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set, opt="SE")
