# %%
from __future__ import absolute_import, division, print_function

import numpy as np
import time
import itertools
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
import torch.optim as optim

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

np.set_printoptions(precision=3)

# %% [markdown]
# ### Generate channel samples

# %%
## Generate location of D2D users and CUE
def loc_init(Size_area, Dist_TX_RX, Num_D2D, Num_Ch):
    tx_loc = Size_area * (np.random.rand(Num_D2D, 2) - 0.5)
    rx_loc = np.zeros((Num_D2D + 1, 2))
    for i in range(Num_D2D):
        temp_chan = Feasible_Loc_Init(tx_loc[i, :], Size_area, Dist_TX_RX)
        rx_loc[i, :] = temp_chan
    tx_loc_CUE = Size_area * (np.random.rand(Num_Ch, 2) - 0.5)

    return rx_loc, tx_loc, tx_loc_CUE

# %%
## Check the feasibililty of generated location
def Feasible_Loc_Init(Cur_loc, Size_area, Dist_TX_RX):
    temp_dist = 2 * Dist_TX_RX * (np.random.rand(1, 2) - 0.5)
    temp_chan = Cur_loc + temp_dist
    while (np.max(abs(temp_chan)) > Size_area / 2) | (np.linalg.norm(temp_dist) > Dist_TX_RX):
        temp_dist = 2 * Dist_TX_RX * (np.random.rand(1, 2) - 0.5)
        temp_chan = Cur_loc + temp_dist
    return temp_chan

# %%
def ch_gen(Size_area, D2D_dist, Num_D2D, Num_Ch, Num_samples, PL_alpha=38., PL_const=34.5):
    ch_w_fading = []
    rx_loc_mat = []
    tx_loc_mat = []
    CUE_loc_mat = []
    
    ch_w_fading = []

    ## Perform initialization just once and the rest channel is generated by moving users
    rx_loc, tx_loc, tx_loc_CUE = loc_init(Size_area, D2D_dist, Num_D2D, Num_Ch)

    ## Calculate the
    for i in range(Num_samples):

        rx_loc, tx_loc, tx_loc_CUE = loc_init(Size_area, D2D_dist, Num_D2D, Num_Ch)

        ch_w_temp_band = []
        for j in range(Num_Ch):
            tx_loc_with_CUE = np.vstack((tx_loc, tx_loc_CUE[j]))
            ## generate distance_vector
            dist_vec = rx_loc.reshape(Num_D2D + 1, 1, 2) - tx_loc_with_CUE
            dist_vec = np.linalg.norm(dist_vec, axis=2)
            dist_vec = np.maximum(dist_vec, 3)

            # find path loss // shadowing is not considered
            pu_ch_gain_db = - PL_const - PL_alpha * np.log10(dist_vec)
            pu_ch_gain = 10 ** (pu_ch_gain_db / 10)

            multi_fading = 0.5 * np.random.randn(Num_D2D + 1, Num_D2D + 1) ** 2 + 0.5 * np.random.randn(Num_D2D + 1,
                                                                                                        Num_D2D + 1) ** 2
            final_ch = np.maximum(pu_ch_gain * multi_fading, np.exp(-30))
            ch_w_temp_band.append(np.transpose(final_ch))

        ch_w_fading.append(ch_w_temp_band)
        rx_loc_mat.append(rx_loc)
        tx_loc_mat.append(tx_loc)
        CUE_loc_mat.append(tx_loc_CUE)
        
    return np.array(ch_w_fading), np.array(rx_loc_mat), np.array(tx_loc_mat), np.array(CUE_loc_mat)

# %%
Size_area = 30.0
D2D_dist = 10
Num_user = 2
Num_channel = 2
num_samples_tr = int(10**5)
num_samples_val = int(10**3)

# %% [markdown]
# ### Randomly generated training data

# %%
ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr)

# %% [markdown]
# ### Check the location of users

# %%
rx_mat[0]
# Out:
# array([[-13.369,  12.585],
#        [ -4.639,  -3.667],
#        [  0.   ,   0.   ]])

# %%
tx_mat[0]
# Out:
# array([[-11.475,   7.341],
#        [ -8.404,  -0.776]])

# %%
CUE_mat[0]
# Out:
# array([[ 3.103, -3.398],
#        [-8.877,  2.944]])

# %%
rx_mat.shape
# Out:
# (100000, 3, 2)

# %%
## Change the shape of location matrice to facilitate the plot
rx_mat_temp = rx_mat[:,:-1,:].reshape(num_samples_tr*Num_user, -1)
tx_mat_temp = tx_mat.reshape(num_samples_tr*Num_user, -1)
CUE_mat_temp = CUE_mat.reshape(num_samples_tr*Num_channel, -1)

# %%
plt.figure(figsize=(10,5))

plt.scatter(rx_mat_temp[:, 0], rx_mat_temp[:, 1], marker='^', label='Rx')
plt.scatter(tx_mat_temp[:, 0], tx_mat_temp[:, 1], marker='o', label='Tx')
plt.scatter(CUE_mat_temp[:, 0], CUE_mat_temp[:, 1], marker='+', label='CUE')
plt.legend(loc='upper left')

for i in range(rx_mat_temp.shape[0]):
    plt.plot([rx_mat_temp[i, 0], tx_mat_temp[i, 0]], [rx_mat_temp[i,1], tx_mat_temp[i, 1]])

# %% [markdown]
# ### plotting by varying the distance between communicating users

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
D2D_dist_mat = [1, 5, 10, 50]
for i in range(4):
    D2D_dist = D2D_dist_mat[i]
    ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr)
    rx_mat_temp = rx_mat[:,:-1,:].reshape(num_samples_tr*Num_user, -1)
    tx_mat_temp = tx_mat.reshape(num_samples_tr*Num_user, -1)
    CUE_mat_temp = CUE_mat.reshape(num_samples_tr*Num_channel, -1)

    axes[i//2, i%2].scatter(rx_mat_temp[:, 0], rx_mat_temp[:, 1], marker='^', label='Rx')
    axes[i//2, i%2].scatter(tx_mat_temp[:, 0], tx_mat_temp[:, 1], marker='o', label='Tx')
    axes[i//2, i%2].scatter(CUE_mat_temp[:, 0], CUE_mat_temp[:, 1], marker='+', label='CUE')
    axes[i//2, i%2].legend(loc='upper left')
    axes[i//2, i%2].set_title(f"D2D distance = {D2D_dist}m", fontsize=14)

    for j in range(rx_mat_temp.shape[0]):
        axes[i//2, i%2].plot([rx_mat_temp[j, 0], tx_mat_temp[j, 0]], [rx_mat_temp[j,1], tx_mat_temp[j, 1]])

# %% [markdown]
# ### Check the channel statistics of channel gain

# %%
D2D_dist = 1

# %%
ch_mat, _, _ , _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))

# %%
ch_mat.shape
# Out:
# (10000, 2, 4, 4)

# %%
sig_chan = np.ravel(ch_mat[:,:,:-1,:-1].diagonal(0, 2, 3))

# %%
plt.figure(figsize=(10,5))
plt.hist(10*np.log10(sig_chan), bins=20, density=True)
# Out:
# (array([1.582e-05, 1.055e-05, 1.582e-05, 2.109e-05, 2.637e-05, 1.002e-04,
#         1.793e-04, 3.269e-04, 6.011e-04, 1.476e-03, 2.758e-03, 5.837e-03,
#         1.138e-02, 2.274e-02, 4.186e-02, 6.706e-02, 8.358e-02, 6.079e-02,
#         1.686e-02, 7.277e-04]),
#  array([-104.894, -101.734,  -98.573,  -95.412,  -92.251,  -89.091,
#          -85.93 ,  -82.769,  -79.609,  -76.448,  -73.287,  -70.126,
#          -66.966,  -63.805,  -60.644,  -57.484,  -54.323,  -51.162,
#          -48.002,  -44.841,  -41.68 ]),
#  <BarContainer object of 20 artists>)

# %%
int_temp = np.triu(ch_mat, 1)

# %%
int_temp.shape
# Out:
# (10000, 2, 4, 4)

# %%
int_chan = int_temp[:,:,:,:-1][int_temp[:,:,:,:-1]!=0]

# %%
plt.figure(figsize=(10,5))
plt.hist(10*np.log10(int_chan), bins=20, density=True)
# Out:
# (array([2.387e-05, 3.183e-05, 1.114e-04, 3.064e-04, 6.843e-04, 1.759e-03,
#         4.902e-03, 1.085e-02, 2.216e-02, 3.548e-02, 4.093e-02, 3.649e-02,
#         2.800e-02, 1.964e-02, 1.397e-02, 9.191e-03, 6.398e-03, 4.850e-03,
#         2.546e-03, 4.019e-04]),
#  array([-127.5  , -123.311, -119.122, -114.933, -110.744, -106.555,
#         -102.367,  -98.178,  -93.989,  -89.8  ,  -85.611,  -81.422,
#          -77.233,  -73.044,  -68.855,  -64.666,  -60.477,  -56.288,
#          -52.1  ,  -47.911,  -43.722]),
#  <BarContainer object of 20 artists>)

# %%
cue_chan = int_temp[:,:,:,-1][int_temp[:,:,:,-1]!=0]

# %%
int_chan.shape
# Out:
# (60000,)

# %%
cue_chan.shape
# Out:
# (60000,)

# %%
plt.figure(figsize=(10,5))
plt.hist(10*np.log10(cue_chan), bins=20, density=True)
# Out:
# (array([8.016e-06, 8.016e-06, 4.008e-05, 7.214e-05, 1.844e-04, 3.647e-04,
#         1.295e-03, 3.218e-03, 7.707e-03, 1.777e-02, 3.470e-02, 4.982e-02,
#         4.642e-02, 3.076e-02, 1.900e-02, 1.198e-02, 8.108e-03, 5.655e-03,
#         2.874e-03, 4.769e-04]),
#  array([-126.963, -122.804, -118.646, -114.487, -110.329, -106.17 ,
#         -102.012,  -97.853,  -93.695,  -89.537,  -85.378,  -81.22 ,
#          -77.061,  -72.903,  -68.744,  -64.586,  -60.427,  -56.269,
#          -52.11 ,  -47.952,  -43.793]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(10*np.log10(cue_chan), bins=20, alpha=0.5, label='CUE', density=True)
plt.hist(10*np.log10(int_chan), bins=20, alpha=0.5, label='Interference', density=True)
plt.hist(10*np.log10(sig_chan), bins=20, alpha=0.5, label='Signal', density=True)

plt.legend(loc='upper left')

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
D2D_dist_mat = [1, 5, 10, 50]
for i in range(4):
    D2D_dist = D2D_dist_mat[i]
    ch_mat, _, _ , _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))
    sig_chan = np.ravel(ch_mat[:,:,:-1,:-1].diagonal(0, 2, 3))
    int_temp = np.triu(ch_mat, 1)
    int_chan = int_temp[:,:,:,:-1][int_temp[:,:,:,:-1]!=0]
    cue_chan = int_temp[:,:,:,-1][int_temp[:,:,:,-1]!=0]

    axes[i//2, i%2].hist(10*np.log10(cue_chan), bins=20, alpha=0.5, label='Signal', density=True) 
    axes[i//2, i%2].hist(10*np.log10(int_chan), bins=20, alpha=0.5, label='Interference', density=True)
    axes[i//2, i%2].hist(10*np.log10(sig_chan), bins=20, alpha=0.5, label='Signal', density=True) 
    axes[i//2, i%2].legend(loc='upper left')
    axes[i//2, i%2].set_title(f"D2D distance = {D2D_dist}m", fontsize=14)

# %%
## Calculate data rate for single channel, single sample
def cal_SINR_one_sample_one_channel(channel, tx_power, noise):
    diag_ch = np.diag(channel)
    inter_ch = channel-np.diag(diag_ch)
    tot_ch = np.multiply(channel, np.expand_dims(tx_power, -1))
    int_ch = np.multiply(inter_ch, np.expand_dims(tx_power, -1))
    sig_ch = np.sum(tot_ch-int_ch, axis=1)
    int_ch = np.sum(int_ch, axis=1)
    SINR_val = np.divide(sig_ch, int_ch+noise)
    cap_val = np.log2(1.0+SINR_val)
    return cap_val

# %%
def cal_CUE_INTER_one_sample_one_channel(channel, tx_power):
    diag_ch = np.diag(channel)
    inter_ch = channel-np.diag(diag_ch)
    int_ch = np.multiply(inter_ch, np.expand_dims(tx_power, -1))
    int_ch = np.sum(int_ch, axis=1)
    return int_ch

# %%
D2D_dist = 10

# %%
ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))

# %% [markdown]
# Temporary channel value

# %%
tx_power_temp = np.ones((1, 4))
BW = 1e7
noise = BW*10**-17.4

# %%
tx_power_temp
# Out:
# array([[1., 1., 1., 1.]])

# %%
cal_SINR_one_sample_one_channel(ch_mat[0, 0, :,:], tx_power_temp, noise)
# Out:
# array([[9.249, 1.209, 4.585, 0.201]])

# %%
rx_mat_temp = rx_mat[:,:-1,:].reshape(Num_user, -1)
tx_mat_temp = tx_mat.reshape(Num_user, -1)
CUE_mat_temp = CUE_mat.reshape(Num_channel, -1)

plt.figure(figsize=(10,5))

plt.scatter(rx_mat_temp[:, 0], rx_mat_temp[:, 1], marker='^', label='Rx')
plt.scatter(tx_mat_temp[:, 0], tx_mat_temp[:, 1], marker='o', label='Tx')
plt.scatter(CUE_mat_temp[:, 0], CUE_mat_temp[:, 1], marker='+', label='CUE')
plt.legend(loc='upper left')

for i in range(rx_mat_temp.shape[0]):
    plt.plot([rx_mat_temp[i, 0], tx_mat_temp[i, 0]], [rx_mat_temp[i,1], tx_mat_temp[i, 1]])

# %%
def cal_rate_NP(channel, tx_power_in, tx_max, noise, DUE_thr, I_thr, P_c):
    num_sample = channel.shape[0]
    num_channel = channel.shape[1]
    num_D2D_user = channel.shape[2] - 1

    ## Initialization
    tot_SE = 0
    tot_EE = 0
    tot_cap_CUE_vio = 0
    tot_cap_DUE_vio = 0
    tot_cap_CUE_vio_num = 0.001
    tot_cap_DUE_vio_num = 0.001
    DUE_violation = 0
    CUE_violation = 0
    tot_success_prob = 0
    
    ## Append tx power and CUE tx power
    tx_power = np.hstack((tx_power_in, tx_max * np.ones((tx_power_in.shape[0], 1, num_channel))))

    for i in range(num_sample):
        cur_cap = 0
        DUE_mask = 1
        CUE_mask = 1

        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_power = tx_power[i, :, j]
            cur_power = np.array([cur_power])
            cur_ch_cap = cal_SINR_one_sample_one_channel(cur_ch, cur_power, noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, cur_power)
            cur_cap = cur_cap + cur_ch_cap[0]
            CUE_mask = CUE_mask * (inter[0, num_D2D_user] <= I_thr)
            if inter[0, num_D2D_user] > I_thr :
                tot_cap_CUE_vio = tot_cap_CUE_vio + cur_ch_cap[0, num_D2D_user]
                tot_cap_CUE_vio_num = tot_cap_CUE_vio_num + 1

        for j in range(num_D2D_user):
            DUE_mask = DUE_mask * (cur_cap[j] >= DUE_thr)

        D2D_SE_sum = np.sum(cur_cap[:-1])*CUE_mask*DUE_mask
        D2D_EE_sum = np.sum(cur_cap[:-1]/(np.sum(tx_power_in[i], axis=1)+P_c))*CUE_mask*DUE_mask

        if CUE_mask == 0:
            CUE_violation = CUE_violation + 1
            
        if DUE_mask == 0:
            DUE_violation = DUE_violation + 1

        tot_SE = tot_SE + D2D_SE_sum
        tot_EE = tot_EE + D2D_EE_sum


    tot_SE = tot_SE / num_D2D_user / num_sample
    tot_EE = tot_EE / num_D2D_user / num_sample
    PRO_DUE_vio = DUE_violation / (num_sample)
    PRO_CUE_vio = CUE_violation / (num_sample)

    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio

# %% [markdown]
# ### tx_power_in은 D2D tx power만 고려함

# %%
tx_power_in = 10**2.0*np.ones((ch_mat.shape[0], 3, 2))

# %%
DUE_thr = 0.0 * 0.6931
tx_max = 10**2.0
I_thr = 10**(-10.0/10)
P_c = 10**2.0
BW = 1e7
noise = BW*10**-17.4

# %%
cal_rate_NP(ch_mat, tx_power_in, tx_max, noise, DUE_thr, I_thr, P_c)
# Out:
# (4.871296576890324, 0.016237655256301057, 0.0, 3.3333333333333334e-08)

# %%
def all_possible_tx_power(num_channel, num_user, granuty):

    items = [np.arange(granuty)] * num_user * num_channel
    temp_power = list(itertools.product(*items))
    temp_power = np.reshape(temp_power, (-1, num_user, num_channel))

    power_check = np.sum(temp_power, axis=2)
    flag = (power_check / (granuty - 1) <= 1).astype(int)
    flag = (np.sum(flag, axis=1) / num_user == 1).astype(int)
    flag = np.reshape(flag, (-1, 1))
    temp_power_1 = np.reshape(temp_power, (-1, num_user * num_channel))
    temp_power = temp_power_1 * flag
    power = np.reshape(temp_power, (-1, num_user, num_channel)) / (granuty - 1)

    power_mat = []
    for i in range(power.shape[0]):
        sum_val = np.sum(power[i])
        if sum_val != 0:
            power_mat.append(power[i])

    return np.array(power_mat)

# %%
def optimal_power(channel, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set):

    num_channel = channel.shape[1]
    num_D2D_user = channel.shape[2] - 1
    num_samples = channel.shape[0]
    num_success = 0
    tot_SE = 0
    power_mat_SE = []

    for i in tqdm(range(num_samples)):
        cur_cap = 0
        DUE_mask = 1
        CUE_mask = 1
        tx_power = tx_max * np.hstack((tx_power_set, np.ones((tx_power_set.shape[0], 1, num_channel))))

        for j in range(num_channel):
            cur_ch = channel[i][j]
            cur_ch_cap = cal_SINR_one_sample_one_channel(cur_ch, tx_power[:, :, j], noise)
            inter = cal_CUE_INTER_one_sample_one_channel(cur_ch, tx_power[:, :, j])
            cur_cap = cur_cap + cur_ch_cap
            CUE_mask = CUE_mask * (inter[:, num_D2D_user] < I_thr)
        
        for j in range(num_D2D_user):
            DUE_mask = DUE_mask * (cur_cap[:,j] > DUE_thr)
        
        CUE_mask = np.expand_dims(CUE_mask, -1)
        DUE_mask = np.expand_dims(DUE_mask, -1)
        
        sum_D2D_SE_temp = np.expand_dims(np.sum(cur_cap[:,:-1], axis=1), -1)
        sum_D2D_EE_temp = np.expand_dims(np.sum(cur_cap[:,:-1]/(np.sum(tx_power[:,:-1,:], axis=2)+P_c), axis=1), -1)
        
        D2D_SE_sum = sum_D2D_SE_temp*CUE_mask*DUE_mask
        D2D_EE_sum = sum_D2D_EE_temp*CUE_mask*DUE_mask

        D2D_SE_arg = np.argmax(D2D_SE_sum)
        max_SE = np.max(D2D_SE_sum)
        
        found_tx_val = tx_power[D2D_SE_arg][:-1]

        power_mat_SE.append(found_tx_val)
        num_success = num_success + 1
        tot_SE = tot_SE + max_SE

    power_mat_SE = np.array(power_mat_SE)

    tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio = cal_rate_NP(channel, power_mat_SE, tx_max, noise, DUE_thr, I_thr, P_c)

    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio

# %%
Num_power_level = 20

# %%
tx_power_set = all_possible_tx_power(Num_channel, Num_user, Num_power_level - 1)

# %%
tx_power_set.shape
# Out:
# (36099, 2, 2)

# %%
SE_OPT, EE_OPT, CUE_vio_OPT, DUE_vio_OPT = optimal_power(ch_mat, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
print(f"SE:{SE_OPT:.3}, EE:{EE_OPT*1000:.3}, Vio(CUE):{CUE_vio_OPT*100:.2}, Vio(DUE):{DUE_vio_OPT*100:.2}")
# Out:
# SE:6.04, EE:30.3, Vio(CUE):0.0, Vio(DUE):3.3e-06

# %% [markdown]
# ### Random selection

# %%
def random_power(channel, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set):
    num_samples = channel.shape[0]
    tx_power = tx_max * tx_power_set
    tx_sel_idx = np.random.randint(tx_power_set.shape[0], size=num_samples)
    tx_sel = tx_power[tx_sel_idx]
    tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio = cal_rate_NP(channel, tx_sel, tx_max, noise, DUE_thr, I_thr, P_c)
    return tot_SE, tot_EE, PRO_CUE_vio, PRO_DUE_vio

# %%
SE_RAND, EE_RAND, CUE_vio_RAND, DUE_vio_RAND = random_power(ch_mat, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set)

# %%
print(f"SE:{SE_RAND:.3}, EE:{EE_RAND*1000:.3}, Vio(CUE):{CUE_vio_RAND*100:.2}, Vio(DUE):{DUE_vio_RAND*100:.2}")
# Out:
# SE:2.11, EE:11.7, Vio(CUE):0.0, Vio(DUE):3.3e-06

# %% [markdown]
# ### Generate Dataset

# %%
class ChanDataset(Dataset):
    def __init__(self, Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr, chan_mean, chan_std):
        super(ChanDataset, self).__init__()
        ch_mat, _, _, _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr)
        ch_mat = np.log(ch_mat)
        ch_mat = (ch_mat-chan_mean)/chan_std
        self.x_data = torch.Tensor(ch_mat)

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        return x

# %%
ch_mat, _, _, _ = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**4))
chan_mean = np.mean(np.log10(ch_mat))
chan_std = np.std(np.log10(ch_mat))

# %%
tr_dataset = ChanDataset(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr, chan_mean, chan_std)
train_dataloader = DataLoader(tr_dataset, batch_size=1024*8, shuffle=True)

# %%
val_dataset = ChanDataset(Size_area, D2D_dist, Num_user, Num_channel, num_samples_val, chan_mean, chan_std)
val_dataloader = DataLoader(val_dataset, batch_size=1024, shuffle=True)

# %%
train_dataloader.dataset[1]
# Out:
# tensor([[[ -6.8555,  -9.8310, -10.5608,  -8.1005],
#          [-11.9243,  -6.6011, -10.1155,  -8.8198],
#          [-12.3934,  -8.3750,  -7.7795,  -9.1315],
#          [ -6.5469, -11.4546, -12.0720,  -8.6405]],
#
#         [[ -5.8775, -10.2630, -12.2794,  -8.7062],
#          [-10.2933,  -7.2659,  -9.5454,  -9.4322],
#          [-11.3564,  -9.2191, -11.6518,  -8.7503],
#          [ -8.8133,  -6.0623,  -9.0221,  -7.3676]]])

# %%
val_dataloader.dataset[1]
# Out:
# tensor([[[ -7.2262,  -7.9427,  -9.0041,  -8.8651],
#          [-12.2686,  -5.6860, -10.4245, -11.4838],
#          [ -8.1281,  -9.5563,  -9.0694,  -7.0759],
#          [ -7.8062,  -8.0963,  -6.6544,  -3.6773]],
#
#         [[ -9.4240,  -8.6300,  -7.3193,  -9.8093],
#          [-10.5406,  -5.0998, -12.0793,  -8.4122],
#          [ -9.2683, -10.0214,  -7.1081,  -7.3463],
#          [-10.1780,  -8.0652, -10.0450, -12.5015]]])

# %%
class Net(nn.Module):
    def __init__(self, num_user, num_chan, hidden_dim, num_l):
        super(Net, self).__init__()
        self.num_user = num_user
        self.num_chan = num_chan
        self.hidden_dim = hidden_dim
        self.num_l = num_l

        ## List of linear layers
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(int((num_user+1) * (num_user+1) * num_chan), hidden_dim))
        for lll in range(num_l):
            self.layers.append(nn.Linear(hidden_dim, hidden_dim))

        ## List of dropout layers
        self.dropouts = nn.ModuleList()
        for lll in range(num_l):
            self.dropouts.append(nn.Dropout(0.1))

        ## List of Batch layers
        self.batches = nn.ModuleList()
        for lll in range(num_l):
            self.batches.append(nn.BatchNorm1d(hidden_dim))

        ## output for softmax
        self.out_RA = nn.Linear(hidden_dim, num_user * num_chan)
        
        ## output for sigmoid
        self.out_PW = nn.Linear(hidden_dim, num_user)

    def forward(self, x):
        z = torch.flatten(x, 1)  # flatten all dimensions except the batch dimension
        for (layer, dropout, batch_norm) in zip(self.layers, self.dropouts, self.batches):
            # x = F.relu(nlayer(x))
            z = layer(z)
            z = batch_norm(z)
            z = F.relu(z)
            z = dropout(z)

        u = self.out_RA(z)
        u = u.view(-1, self.num_user, self.num_chan)
        out_RA = F.softmax(u, dim=2)
        
        v = self.out_PW(z)
        v = v.view(-1, self.num_user, 1)
        out_PW = F.sigmoid(v)
        output = out_RA * out_PW
        
        return output

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = Net(Num_user, Num_channel, 1000, 5).to(device)

# %%
net.eval()
# Out:
# Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=32, out_features=1000, bias=True)
#     (1): Linear(in_features=1000, out_features=1000, bias=True)
#     (2): Linear(in_features=1000, out_features=1000, bias=True)
#     (3): Linear(in_features=1000, out_features=1000, bias=True)
#     (4): Linear(in_features=1000, out_features=1000, bias=True)
#     (5): Linear(in_features=1000, out_features=1000, bias=True)
#   )
#   (dropouts): ModuleList(
#     (0): Dropout(p=0.1, inplace=False)
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Dropout(p=0.1, inplace=False)
#   )
#   (batches): ModuleList(
#     (0): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (out_RA): Linear(in_features=1000, out_features=6, bias=True)
#   (out_PW): Linear(in_features=1000, out_features=3, bias=True)
# )

# %%
abc = net(train_dataloader.dataset[:10].to(device))
# Out:
# /Users/leewoongsup/opt/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
abc.shape
# Out:
# torch.Size([10, 3, 2])

# %%
def My_Loss(P_DNN, chan, tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat):
    
    Num_sample = P_DNN.shape[0]
    Num_node = P_DNN.shape[1]
    Num_chan = P_DNN.shape[2]

    RATE_lam = lam_val_mat[0]
    DUE_lam = lam_val_mat[1]
    CUE_lam = lam_val_mat[2]
    
    chan_rev = torch.exp(chan * chan_std + chan_mean)
        
    P_DNN_rev = tx_max * torch.hstack((P_DNN, torch.ones((Num_sample, 1, Num_chan)).to(device)))
    
    P_DNN_rev = torch.transpose(P_DNN_rev, 1, 2)
    P_DNN_rev = P_DNN_rev.unsqueeze(3)    

    tot_gain = chan_rev * P_DNN_rev
    
    tot_gain_sum = torch.sum(tot_gain, 2)
    
    sig_sum = torch.diagonal(tot_gain, 0, 2, 3)
    
    int_sum = tot_gain_sum - sig_sum
    
    SINR_val = torch.divide(sig_sum, int_sum + noise)
    DR = torch.log2(1+SINR_val)
    
    DR_sum = torch.sum(DR, 1)
    int_CUE = int_sum[:,:,-1]

    Tot_rate = torch.mean(DR_sum[:,:-1], 1)
        
    Tot_EE = torch.mean(DR_sum[:,:-1] / (torch.sum(P_DNN, 2)+P_c), 1)
    
    DUE_vio = torch.relu(DUE_thr - DR_sum[:,:-1])/(DUE_thr+0.01)
    
    CUE_vio = torch.relu(int_CUE - I_thr)/I_thr
    
    '''
    print("Tot_rate = ", Tot_rate)
    print("Tot_EE = ", Tot_EE)
    print("DUE_vio = ", DUE_vio)
    print("CUE_vio = ", CUE_vio)
    '''
    
    Loss = - RATE_lam * torch.mean(Tot_rate) + DUE_lam * torch.mean(DUE_vio) + CUE_lam * torch.mean(CUE_vio)    
    
    
    return Loss

# %%
abc = net(train_dataloader.dataset[:10].to(device))

My_Loss(abc, train_dataloader.dataset[:10].to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wn/zhdc_ghx1jjdzr54n3x6vmtw0000gn/T/ipykernel_18347/3243596389.py in <module>
#       1 abc = net(train_dataloader.dataset[:10].to(device))
#       2
# ----> 3 My_Loss(abc, train_dataloader.dataset[:10].to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat)
#
# NameError: name 'lam_val_mat' is not defined

# %%
lam_val_mat = torch.ones(3, 1).to(device)

RATE_lam = 1
DUE_lam = 1
CUE_lam = 1

lam_val_mat[0] = RATE_lam
lam_val_mat[1] = DUE_lam
lam_val_mat[2] = CUE_lam

# %%
num_samples_tr = int(10**5)

# %%
tr_dataset = ChanDataset(Size_area, D2D_dist, Num_user, Num_channel, num_samples_tr, chan_mean, chan_std)
train_dataloader = DataLoader(tr_dataset, batch_size=1024*8, shuffle=True)

# %%
net = Net(Num_user, Num_channel, 1000, 5).to(device)

net.train()

optimizer = torch.optim.Adam(net.parameters(), lr=2*1e-3)

# %%
for i in range(100):
    print("")
    print("**"*50)
    print(f"training epoch = {i}")
    cur_loss_tot = 0
    for index, chan in enumerate(train_dataloader):
        net.train()
        optimizer.zero_grad()

        p_dnn = net(chan.to(device))

        cur_loss = My_Loss(p_dnn, chan.to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat)

        cur_loss_tot += cur_loss

        cur_loss.backward()
        optimizer.step()
        print(cur_loss_tot/(index+1))
# Out:
# ****************************************************************************************************
# training epoch = 0
# tensor([-3.9786], grad_fn=<DivBackward0>)
# tensor([-4.3273], grad_fn=<DivBackward0>)
# tensor([-4.4755], grad_fn=<DivBackward0>)
# tensor([-4.6727], grad_fn=<DivBackward0>)
# tensor([-4.7934], grad_fn=<DivBackward0>)
# tensor([-4.8922], grad_fn=<DivBackward0>)
# tensor([-4.9710], grad_fn=<DivBackward0>)
# tensor([-5.0398], grad_fn=<DivBackward0>)
# tensor([-5.0920], grad_fn=<DivBackward0>)
# tensor([-5.1384], grad_fn=<DivBackward0>)
# tensor([-5.1786], grad_fn=<DivBackward0>)
# tensor([-5.2143], grad_fn=<DivBackward0>)
# tensor([-5.2484], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 1
# tensor([-5.6849], grad_fn=<DivBackward0>)
# tensor([-5.6917], grad_fn=<DivBackward0>)
# tensor([-5.7160], grad_fn=<DivBackward0>)
# tensor([-5.7270], grad_fn=<DivBackward0>)
# tensor([-5.7427], grad_fn=<DivBackward0>)
# tensor([-5.7497], grad_fn=<DivBackward0>)
# tensor([-5.7522], grad_fn=<DivBackward0>)
# tensor([-5.7618], grad_fn=<DivBackward0>)
# tensor([-5.7666], grad_fn=<DivBackward0>)
# tensor([-5.7741], grad_fn=<DivBackward0>)
# tensor([-5.7809], grad_fn=<DivBackward0>)
# tensor([-5.7907], grad_fn=<DivBackward0>)
# tensor([-5.8031], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 2
# tensor([-5.9319], grad_fn=<DivBackward0>)
# tensor([-5.9333], grad_fn=<DivBackward0>)
# tensor([-5.9196], grad_fn=<DivBackward0>)
# tensor([-5.9250], grad_fn=<DivBackward0>)
# tensor([-5.9255], grad_fn=<DivBackward0>)
# tensor([-5.9316], grad_fn=<DivBackward0>)
# tensor([-5.9355], grad_fn=<DivBackward0>)
# tensor([-5.9421], grad_fn=<DivBackward0>)
# tensor([-5.9500], grad_fn=<DivBackward0>)
# tensor([-5.9546], grad_fn=<DivBackward0>)
# tensor([-5.9612], grad_fn=<DivBackward0>)
# tensor([-5.9631], grad_fn=<DivBackward0>)
# tensor([-5.9599], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 3
# tensor([-6.0268], grad_fn=<DivBackward0>)
# tensor([-6.0395], grad_fn=<DivBackward0>)
# tensor([-6.0412], grad_fn=<DivBackward0>)
# tensor([-6.0365], grad_fn=<DivBackward0>)
# tensor([-6.0425], grad_fn=<DivBackward0>)
# tensor([-6.0409], grad_fn=<DivBackward0>)
# tensor([-6.0434], grad_fn=<DivBackward0>)
# tensor([-6.0457], grad_fn=<DivBackward0>)
# tensor([-6.0461], grad_fn=<DivBackward0>)
# tensor([-6.0452], grad_fn=<DivBackward0>)
# tensor([-6.0457], grad_fn=<DivBackward0>)
# tensor([-6.0471], grad_fn=<DivBackward0>)
# tensor([-6.0481], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 4
# tensor([-6.1256], grad_fn=<DivBackward0>)
# tensor([-6.0883], grad_fn=<DivBackward0>)
# tensor([-6.0783], grad_fn=<DivBackward0>)
# tensor([-6.0856], grad_fn=<DivBackward0>)
# tensor([-6.0987], grad_fn=<DivBackward0>)
# tensor([-6.0987], grad_fn=<DivBackward0>)
# tensor([-6.0952], grad_fn=<DivBackward0>)
# tensor([-6.0878], grad_fn=<DivBackward0>)
# tensor([-6.0864], grad_fn=<DivBackward0>)
# tensor([-6.0884], grad_fn=<DivBackward0>)
# tensor([-6.0898], grad_fn=<DivBackward0>)
# tensor([-6.0906], grad_fn=<DivBackward0>)
# tensor([-6.0902], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 5
# tensor([-6.1409], grad_fn=<DivBackward0>)
# tensor([-6.1095], grad_fn=<DivBackward0>)
# tensor([-6.1020], grad_fn=<DivBackward0>)
# tensor([-6.1025], grad_fn=<DivBackward0>)
# tensor([-6.1019], grad_fn=<DivBackward0>)
# tensor([-6.1036], grad_fn=<DivBackward0>)
# tensor([-6.1078], grad_fn=<DivBackward0>)
# tensor([-6.1016], grad_fn=<DivBackward0>)
# tensor([-6.1049], grad_fn=<DivBackward0>)
# tensor([-6.1057], grad_fn=<DivBackward0>)
# tensor([-6.1092], grad_fn=<DivBackward0>)
# tensor([-6.1117], grad_fn=<DivBackward0>)
# tensor([-6.1115], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 6
# tensor([-6.1360], grad_fn=<DivBackward0>)
# tensor([-6.1337], grad_fn=<DivBackward0>)
# tensor([-6.1261], grad_fn=<DivBackward0>)
# tensor([-6.1261], grad_fn=<DivBackward0>)
# tensor([-6.1237], grad_fn=<DivBackward0>)
# tensor([-6.1281], grad_fn=<DivBackward0>)
# tensor([-6.1274], grad_fn=<DivBackward0>)
# tensor([-6.1268], grad_fn=<DivBackward0>)
# tensor([-6.1290], grad_fn=<DivBackward0>)
# tensor([-6.1303], grad_fn=<DivBackward0>)
# tensor([-6.1283], grad_fn=<DivBackward0>)
# tensor([-6.1304], grad_fn=<DivBackward0>)
# tensor([-6.1297], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 7
# tensor([-6.1723], grad_fn=<DivBackward0>)
# tensor([-6.1607], grad_fn=<DivBackward0>)
# tensor([-6.1535], grad_fn=<DivBackward0>)
# tensor([-6.1597], grad_fn=<DivBackward0>)
# tensor([-6.1572], grad_fn=<DivBackward0>)
# tensor([-6.1538], grad_fn=<DivBackward0>)
# tensor([-6.1487], grad_fn=<DivBackward0>)
# tensor([-6.1479], grad_fn=<DivBackward0>)
# tensor([-6.1467], grad_fn=<DivBackward0>)
# tensor([-6.1470], grad_fn=<DivBackward0>)
# tensor([-6.1460], grad_fn=<DivBackward0>)
# tensor([-6.1428], grad_fn=<DivBackward0>)
# tensor([-6.1408], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 8
# tensor([-6.1514], grad_fn=<DivBackward0>)
# tensor([-6.1642], grad_fn=<DivBackward0>)
# tensor([-6.1489], grad_fn=<DivBackward0>)
# tensor([-6.1463], grad_fn=<DivBackward0>)
# tensor([-6.1454], grad_fn=<DivBackward0>)
# tensor([-6.1378], grad_fn=<DivBackward0>)
# tensor([-6.1413], grad_fn=<DivBackward0>)
# tensor([-6.1412], grad_fn=<DivBackward0>)
# tensor([-6.1464], grad_fn=<DivBackward0>)
# tensor([-6.1469], grad_fn=<DivBackward0>)
# tensor([-6.1498], grad_fn=<DivBackward0>)
# tensor([-6.1500], grad_fn=<DivBackward0>)
# tensor([-6.1534], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 9
# tensor([-6.1435], grad_fn=<DivBackward0>)
# tensor([-6.1685], grad_fn=<DivBackward0>)
# tensor([-6.1671], grad_fn=<DivBackward0>)
# tensor([-6.1646], grad_fn=<DivBackward0>)
# tensor([-6.1642], grad_fn=<DivBackward0>)
# tensor([-6.1596], grad_fn=<DivBackward0>)
# tensor([-6.1577], grad_fn=<DivBackward0>)
# tensor([-6.1556], grad_fn=<DivBackward0>)
# tensor([-6.1538], grad_fn=<DivBackward0>)
# tensor([-6.1526], grad_fn=<DivBackward0>)
# tensor([-6.1539], grad_fn=<DivBackward0>)
# tensor([-6.1560], grad_fn=<DivBackward0>)
# tensor([-6.1597], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 10
# tensor([-6.1666], grad_fn=<DivBackward0>)
# tensor([-6.1619], grad_fn=<DivBackward0>)
# tensor([-6.1532], grad_fn=<DivBackward0>)
# tensor([-6.1507], grad_fn=<DivBackward0>)
# tensor([-6.1554], grad_fn=<DivBackward0>)
# tensor([-6.1598], grad_fn=<DivBackward0>)
# tensor([-6.1571], grad_fn=<DivBackward0>)
# tensor([-6.1608], grad_fn=<DivBackward0>)
# tensor([-6.1615], grad_fn=<DivBackward0>)
# tensor([-6.1620], grad_fn=<DivBackward0>)
# tensor([-6.1631], grad_fn=<DivBackward0>)
# tensor([-6.1615], grad_fn=<DivBackward0>)
# tensor([-6.1639], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 11
# tensor([-6.2084], grad_fn=<DivBackward0>)
# tensor([-6.1977], grad_fn=<DivBackward0>)
# tensor([-6.1961], grad_fn=<DivBackward0>)
# tensor([-6.1913], grad_fn=<DivBackward0>)
# tensor([-6.1863], grad_fn=<DivBackward0>)
# tensor([-6.1791], grad_fn=<DivBackward0>)
# tensor([-6.1815], grad_fn=<DivBackward0>)
# tensor([-6.1769], grad_fn=<DivBackward0>)
# tensor([-6.1770], grad_fn=<DivBackward0>)
# tensor([-6.1794], grad_fn=<DivBackward0>)
# tensor([-6.1756], grad_fn=<DivBackward0>)
# tensor([-6.1701], grad_fn=<DivBackward0>)
# tensor([-6.1787], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 12
# tensor([-6.1860], grad_fn=<DivBackward0>)
# tensor([-6.1864], grad_fn=<DivBackward0>)
# tensor([-6.1634], grad_fn=<DivBackward0>)
# tensor([-6.1713], grad_fn=<DivBackward0>)
# tensor([-6.1778], grad_fn=<DivBackward0>)
# tensor([-6.1666], grad_fn=<DivBackward0>)
# tensor([-6.1701], grad_fn=<DivBackward0>)
# tensor([-6.1727], grad_fn=<DivBackward0>)
# tensor([-6.1721], grad_fn=<DivBackward0>)
# tensor([-6.1743], grad_fn=<DivBackward0>)
# tensor([-6.1742], grad_fn=<DivBackward0>)
# tensor([-6.1735], grad_fn=<DivBackward0>)
# tensor([-6.1824], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 13
# tensor([-6.1668], grad_fn=<DivBackward0>)
# tensor([-6.1894], grad_fn=<DivBackward0>)
# tensor([-6.1826], grad_fn=<DivBackward0>)
# tensor([-6.1723], grad_fn=<DivBackward0>)
# tensor([-6.1682], grad_fn=<DivBackward0>)
# tensor([-6.1690], grad_fn=<DivBackward0>)
# tensor([-6.1699], grad_fn=<DivBackward0>)
# tensor([-6.1720], grad_fn=<DivBackward0>)
# tensor([-6.1756], grad_fn=<DivBackward0>)
# tensor([-6.1750], grad_fn=<DivBackward0>)
# tensor([-6.1761], grad_fn=<DivBackward0>)
# tensor([-6.1744], grad_fn=<DivBackward0>)
# tensor([-6.1838], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 14
# tensor([-6.1933], grad_fn=<DivBackward0>)
# tensor([-6.1912], grad_fn=<DivBackward0>)
# tensor([-6.1815], grad_fn=<DivBackward0>)
# tensor([-6.1850], grad_fn=<DivBackward0>)
# tensor([-6.1831], grad_fn=<DivBackward0>)
# tensor([-6.1897], grad_fn=<DivBackward0>)
# tensor([-6.1886], grad_fn=<DivBackward0>)
# tensor([-6.1819], grad_fn=<DivBackward0>)
# tensor([-6.1864], grad_fn=<DivBackward0>)
# tensor([-6.1880], grad_fn=<DivBackward0>)
# tensor([-6.1845], grad_fn=<DivBackward0>)
# tensor([-6.1802], grad_fn=<DivBackward0>)
# tensor([-6.1792], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 15
# tensor([-6.1933], grad_fn=<DivBackward0>)
# tensor([-6.1908], grad_fn=<DivBackward0>)
# tensor([-6.1847], grad_fn=<DivBackward0>)
# tensor([-6.1879], grad_fn=<DivBackward0>)
# tensor([-6.1879], grad_fn=<DivBackward0>)
# tensor([-6.1917], grad_fn=<DivBackward0>)
# tensor([-6.1915], grad_fn=<DivBackward0>)
# tensor([-6.1844], grad_fn=<DivBackward0>)
# tensor([-6.1780], grad_fn=<DivBackward0>)
# tensor([-6.1776], grad_fn=<DivBackward0>)
# tensor([-6.1807], grad_fn=<DivBackward0>)
# tensor([-6.1838], grad_fn=<DivBackward0>)
# tensor([-6.1816], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 16
# tensor([-6.2389], grad_fn=<DivBackward0>)
# tensor([-6.2109], grad_fn=<DivBackward0>)
# tensor([-6.2002], grad_fn=<DivBackward0>)
# tensor([-6.2041], grad_fn=<DivBackward0>)
# tensor([-6.2011], grad_fn=<DivBackward0>)
# tensor([-6.1951], grad_fn=<DivBackward0>)
# tensor([-6.1897], grad_fn=<DivBackward0>)
# tensor([-6.1896], grad_fn=<DivBackward0>)
# tensor([-6.1918], grad_fn=<DivBackward0>)
# tensor([-6.1866], grad_fn=<DivBackward0>)
# tensor([-6.1834], grad_fn=<DivBackward0>)
# tensor([-6.1838], grad_fn=<DivBackward0>)
# tensor([-6.1739], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 17
# tensor([-6.1994], grad_fn=<DivBackward0>)
# tensor([-6.1876], grad_fn=<DivBackward0>)
# tensor([-6.1882], grad_fn=<DivBackward0>)
# tensor([-6.1761], grad_fn=<DivBackward0>)
# tensor([-6.1785], grad_fn=<DivBackward0>)
# tensor([-6.1842], grad_fn=<DivBackward0>)
# tensor([-6.1879], grad_fn=<DivBackward0>)
# tensor([-6.1867], grad_fn=<DivBackward0>)
# tensor([-6.1912], grad_fn=<DivBackward0>)
# tensor([-6.1912], grad_fn=<DivBackward0>)
# tensor([-6.1927], grad_fn=<DivBackward0>)
# tensor([-6.1888], grad_fn=<DivBackward0>)
# tensor([-6.1943], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 18
# tensor([-6.1949], grad_fn=<DivBackward0>)
# tensor([-6.1994], grad_fn=<DivBackward0>)
# tensor([-6.1931], grad_fn=<DivBackward0>)
# tensor([-6.1838], grad_fn=<DivBackward0>)
# tensor([-6.1811], grad_fn=<DivBackward0>)
# tensor([-6.1851], grad_fn=<DivBackward0>)
# tensor([-6.1873], grad_fn=<DivBackward0>)
# tensor([-6.1833], grad_fn=<DivBackward0>)
# tensor([-6.1863], grad_fn=<DivBackward0>)
# tensor([-6.1899], grad_fn=<DivBackward0>)
# tensor([-6.1893], grad_fn=<DivBackward0>)
# tensor([-6.1923], grad_fn=<DivBackward0>)
# tensor([-6.1934], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 19
# tensor([-6.2123], grad_fn=<DivBackward0>)
# tensor([-6.2183], grad_fn=<DivBackward0>)
# tensor([-6.2118], grad_fn=<DivBackward0>)
# tensor([-6.2021], grad_fn=<DivBackward0>)
# tensor([-6.2011], grad_fn=<DivBackward0>)
# tensor([-6.2020], grad_fn=<DivBackward0>)
# tensor([-6.1966], grad_fn=<DivBackward0>)
# tensor([-6.2037], grad_fn=<DivBackward0>)
# tensor([-6.1991], grad_fn=<DivBackward0>)
# tensor([-6.1955], grad_fn=<DivBackward0>)
# tensor([-6.1936], grad_fn=<DivBackward0>)
# tensor([-6.1920], grad_fn=<DivBackward0>)
# tensor([-6.1840], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 20
# tensor([-6.1912], grad_fn=<DivBackward0>)
# tensor([-6.1809], grad_fn=<DivBackward0>)
# tensor([-6.1714], grad_fn=<DivBackward0>)
# tensor([-6.1779], grad_fn=<DivBackward0>)
# tensor([-6.1865], grad_fn=<DivBackward0>)
# tensor([-6.1877], grad_fn=<DivBackward0>)
# tensor([-6.1928], grad_fn=<DivBackward0>)
# tensor([-6.1911], grad_fn=<DivBackward0>)
# tensor([-6.1936], grad_fn=<DivBackward0>)
# tensor([-6.1929], grad_fn=<DivBackward0>)
# tensor([-6.1912], grad_fn=<DivBackward0>)
# tensor([-6.1944], grad_fn=<DivBackward0>)
# tensor([-6.1934], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 21
# tensor([-6.1873], grad_fn=<DivBackward0>)
# tensor([-6.1918], grad_fn=<DivBackward0>)
# tensor([-6.1995], grad_fn=<DivBackward0>)
# tensor([-6.2102], grad_fn=<DivBackward0>)
# tensor([-6.2040], grad_fn=<DivBackward0>)
# tensor([-6.2018], grad_fn=<DivBackward0>)
# tensor([-6.1936], grad_fn=<DivBackward0>)
# tensor([-6.1920], grad_fn=<DivBackward0>)
# tensor([-6.1956], grad_fn=<DivBackward0>)
# tensor([-6.1967], grad_fn=<DivBackward0>)
# tensor([-6.1954], grad_fn=<DivBackward0>)
# tensor([-6.1966], grad_fn=<DivBackward0>)
# tensor([-6.1960], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 22
# tensor([-6.2026], grad_fn=<DivBackward0>)
# tensor([-6.1908], grad_fn=<DivBackward0>)
# tensor([-6.1952], grad_fn=<DivBackward0>)
# tensor([-6.1982], grad_fn=<DivBackward0>)
# tensor([-6.1929], grad_fn=<DivBackward0>)
# tensor([-6.1983], grad_fn=<DivBackward0>)
# tensor([-6.1941], grad_fn=<DivBackward0>)
# tensor([-6.1956], grad_fn=<DivBackward0>)
# tensor([-6.1910], grad_fn=<DivBackward0>)
# tensor([-6.1948], grad_fn=<DivBackward0>)
# tensor([-6.1965], grad_fn=<DivBackward0>)
# tensor([-6.1953], grad_fn=<DivBackward0>)
# tensor([-6.2006], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 23
# tensor([-6.1852], grad_fn=<DivBackward0>)
# tensor([-6.2208], grad_fn=<DivBackward0>)
# tensor([-6.2143], grad_fn=<DivBackward0>)
# tensor([-6.2161], grad_fn=<DivBackward0>)
# tensor([-6.2130], grad_fn=<DivBackward0>)
# tensor([-6.2120], grad_fn=<DivBackward0>)
# tensor([-6.2075], grad_fn=<DivBackward0>)
# tensor([-6.2019], grad_fn=<DivBackward0>)
# tensor([-6.2031], grad_fn=<DivBackward0>)
# tensor([-6.2006], grad_fn=<DivBackward0>)
# tensor([-6.1991], grad_fn=<DivBackward0>)
# tensor([-6.2015], grad_fn=<DivBackward0>)
# tensor([-6.1960], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 24
# tensor([-6.1685], grad_fn=<DivBackward0>)
# tensor([-6.1817], grad_fn=<DivBackward0>)
# tensor([-6.1731], grad_fn=<DivBackward0>)
# tensor([-6.1767], grad_fn=<DivBackward0>)
# tensor([-6.1751], grad_fn=<DivBackward0>)
# tensor([-6.1883], grad_fn=<DivBackward0>)
# tensor([-6.1922], grad_fn=<DivBackward0>)
# tensor([-6.1946], grad_fn=<DivBackward0>)
# tensor([-6.2003], grad_fn=<DivBackward0>)
# tensor([-6.1993], grad_fn=<DivBackward0>)
# tensor([-6.2025], grad_fn=<DivBackward0>)
# tensor([-6.2008], grad_fn=<DivBackward0>)
# tensor([-6.1924], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 25
# tensor([-6.1898], grad_fn=<DivBackward0>)
# tensor([-6.1883], grad_fn=<DivBackward0>)
# tensor([-6.1927], grad_fn=<DivBackward0>)
# tensor([-6.1914], grad_fn=<DivBackward0>)
# tensor([-6.1907], grad_fn=<DivBackward0>)
# tensor([-6.1967], grad_fn=<DivBackward0>)
# tensor([-6.1997], grad_fn=<DivBackward0>)
# tensor([-6.2010], grad_fn=<DivBackward0>)
# tensor([-6.1995], grad_fn=<DivBackward0>)
# tensor([-6.1996], grad_fn=<DivBackward0>)
# tensor([-6.2010], grad_fn=<DivBackward0>)
# tensor([-6.2012], grad_fn=<DivBackward0>)
# tensor([-6.2057], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 26
# tensor([-6.2173], grad_fn=<DivBackward0>)
# tensor([-6.1997], grad_fn=<DivBackward0>)
# tensor([-6.1933], grad_fn=<DivBackward0>)
# tensor([-6.1919], grad_fn=<DivBackward0>)
# tensor([-6.1914], grad_fn=<DivBackward0>)
# tensor([-6.1993], grad_fn=<DivBackward0>)
# tensor([-6.2054], grad_fn=<DivBackward0>)
# tensor([-6.2015], grad_fn=<DivBackward0>)
# tensor([-6.1986], grad_fn=<DivBackward0>)
# tensor([-6.2004], grad_fn=<DivBackward0>)
# tensor([-6.2004], grad_fn=<DivBackward0>)
# tensor([-6.2014], grad_fn=<DivBackward0>)
# tensor([-6.1984], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 27
# tensor([-6.2169], grad_fn=<DivBackward0>)
# tensor([-6.1791], grad_fn=<DivBackward0>)
# tensor([-6.1848], grad_fn=<DivBackward0>)
# tensor([-6.1869], grad_fn=<DivBackward0>)
# tensor([-6.1906], grad_fn=<DivBackward0>)
# tensor([-6.1916], grad_fn=<DivBackward0>)
# tensor([-6.1973], grad_fn=<DivBackward0>)
# tensor([-6.1986], grad_fn=<DivBackward0>)
# tensor([-6.1998], grad_fn=<DivBackward0>)
# tensor([-6.2026], grad_fn=<DivBackward0>)
# tensor([-6.2028], grad_fn=<DivBackward0>)
# tensor([-6.2044], grad_fn=<DivBackward0>)
# tensor([-6.2044], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 28
# tensor([-6.2118], grad_fn=<DivBackward0>)
# tensor([-6.1962], grad_fn=<DivBackward0>)
# tensor([-6.2059], grad_fn=<DivBackward0>)
# tensor([-6.2011], grad_fn=<DivBackward0>)
# tensor([-6.2041], grad_fn=<DivBackward0>)
# tensor([-6.2104], grad_fn=<DivBackward0>)
# tensor([-6.2088], grad_fn=<DivBackward0>)
# tensor([-6.2086], grad_fn=<DivBackward0>)
# tensor([-6.2017], grad_fn=<DivBackward0>)
# tensor([-6.2035], grad_fn=<DivBackward0>)
# tensor([-6.2052], grad_fn=<DivBackward0>)
# tensor([-6.2032], grad_fn=<DivBackward0>)
# tensor([-6.1972], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 29
# tensor([-6.2615], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2295], grad_fn=<DivBackward0>)
# tensor([-6.2153], grad_fn=<DivBackward0>)
# tensor([-6.2123], grad_fn=<DivBackward0>)
# tensor([-6.2068], grad_fn=<DivBackward0>)
# tensor([-6.2013], grad_fn=<DivBackward0>)
# tensor([-6.2027], grad_fn=<DivBackward0>)
# tensor([-6.2043], grad_fn=<DivBackward0>)
# tensor([-6.2010], grad_fn=<DivBackward0>)
# tensor([-6.2030], grad_fn=<DivBackward0>)
# tensor([-6.2034], grad_fn=<DivBackward0>)
# tensor([-6.2074], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 30
# tensor([-6.1921], grad_fn=<DivBackward0>)
# tensor([-6.1929], grad_fn=<DivBackward0>)
# tensor([-6.2072], grad_fn=<DivBackward0>)
# tensor([-6.2091], grad_fn=<DivBackward0>)
# tensor([-6.2058], grad_fn=<DivBackward0>)
# tensor([-6.2026], grad_fn=<DivBackward0>)
# tensor([-6.2073], grad_fn=<DivBackward0>)
# tensor([-6.2058], grad_fn=<DivBackward0>)
# tensor([-6.2049], grad_fn=<DivBackward0>)
# tensor([-6.2052], grad_fn=<DivBackward0>)
# tensor([-6.2036], grad_fn=<DivBackward0>)
# tensor([-6.2025], grad_fn=<DivBackward0>)
# tensor([-6.2020], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 31
# tensor([-6.2248], grad_fn=<DivBackward0>)
# tensor([-6.2383], grad_fn=<DivBackward0>)
# tensor([-6.2150], grad_fn=<DivBackward0>)
# tensor([-6.2088], grad_fn=<DivBackward0>)
# tensor([-6.2168], grad_fn=<DivBackward0>)
# tensor([-6.2128], grad_fn=<DivBackward0>)
# tensor([-6.2114], grad_fn=<DivBackward0>)
# tensor([-6.2078], grad_fn=<DivBackward0>)
# tensor([-6.2029], grad_fn=<DivBackward0>)
# tensor([-6.2042], grad_fn=<DivBackward0>)
# tensor([-6.2013], grad_fn=<DivBackward0>)
# tensor([-6.2006], grad_fn=<DivBackward0>)
# tensor([-6.2020], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 32
# tensor([-6.2019], grad_fn=<DivBackward0>)
# tensor([-6.2145], grad_fn=<DivBackward0>)
# tensor([-6.2055], grad_fn=<DivBackward0>)
# tensor([-6.2162], grad_fn=<DivBackward0>)
# tensor([-6.2138], grad_fn=<DivBackward0>)
# tensor([-6.2123], grad_fn=<DivBackward0>)
# tensor([-6.2115], grad_fn=<DivBackward0>)
# tensor([-6.2044], grad_fn=<DivBackward0>)
# tensor([-6.2049], grad_fn=<DivBackward0>)
# tensor([-6.2040], grad_fn=<DivBackward0>)
# tensor([-6.2052], grad_fn=<DivBackward0>)
# tensor([-6.2041], grad_fn=<DivBackward0>)
# tensor([-6.2055], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 33
# tensor([-6.2148], grad_fn=<DivBackward0>)
# tensor([-6.1957], grad_fn=<DivBackward0>)
# tensor([-6.2042], grad_fn=<DivBackward0>)
# tensor([-6.2108], grad_fn=<DivBackward0>)
# tensor([-6.2134], grad_fn=<DivBackward0>)
# tensor([-6.2054], grad_fn=<DivBackward0>)
# tensor([-6.2029], grad_fn=<DivBackward0>)
# tensor([-6.2008], grad_fn=<DivBackward0>)
# tensor([-6.2012], grad_fn=<DivBackward0>)
# tensor([-6.2029], grad_fn=<DivBackward0>)
# tensor([-6.2021], grad_fn=<DivBackward0>)
# tensor([-6.2056], grad_fn=<DivBackward0>)
# tensor([-6.2063], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 34
# tensor([-6.2065], grad_fn=<DivBackward0>)
# tensor([-6.2095], grad_fn=<DivBackward0>)
# tensor([-6.2062], grad_fn=<DivBackward0>)
# tensor([-6.1934], grad_fn=<DivBackward0>)
# tensor([-6.2024], grad_fn=<DivBackward0>)
# tensor([-6.1971], grad_fn=<DivBackward0>)
# tensor([-6.2019], grad_fn=<DivBackward0>)
# tensor([-6.2098], grad_fn=<DivBackward0>)
# tensor([-6.2106], grad_fn=<DivBackward0>)
# tensor([-6.2118], grad_fn=<DivBackward0>)
# tensor([-6.2094], grad_fn=<DivBackward0>)
# tensor([-6.2087], grad_fn=<DivBackward0>)
# tensor([-6.2121], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 35
# tensor([-6.2514], grad_fn=<DivBackward0>)
# tensor([-6.2371], grad_fn=<DivBackward0>)
# tensor([-6.2395], grad_fn=<DivBackward0>)
# tensor([-6.2235], grad_fn=<DivBackward0>)
# tensor([-6.2084], grad_fn=<DivBackward0>)
# tensor([-6.2103], grad_fn=<DivBackward0>)
# tensor([-6.2106], grad_fn=<DivBackward0>)
# tensor([-6.2102], grad_fn=<DivBackward0>)
# tensor([-6.2072], grad_fn=<DivBackward0>)
# tensor([-6.2059], grad_fn=<DivBackward0>)
# tensor([-6.2074], grad_fn=<DivBackward0>)
# tensor([-6.2082], grad_fn=<DivBackward0>)
# tensor([-6.2149], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 36
# tensor([-6.2138], grad_fn=<DivBackward0>)
# tensor([-6.2128], grad_fn=<DivBackward0>)
# tensor([-6.2140], grad_fn=<DivBackward0>)
# tensor([-6.2191], grad_fn=<DivBackward0>)
# tensor([-6.2171], grad_fn=<DivBackward0>)
# tensor([-6.2127], grad_fn=<DivBackward0>)
# tensor([-6.2098], grad_fn=<DivBackward0>)
# tensor([-6.2079], grad_fn=<DivBackward0>)
# tensor([-6.2043], grad_fn=<DivBackward0>)
# tensor([-6.2054], grad_fn=<DivBackward0>)
# tensor([-6.2061], grad_fn=<DivBackward0>)
# tensor([-6.2082], grad_fn=<DivBackward0>)
# tensor([-6.2041], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 37
# tensor([-6.1846], grad_fn=<DivBackward0>)
# tensor([-6.2064], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2146], grad_fn=<DivBackward0>)
# tensor([-6.2255], grad_fn=<DivBackward0>)
# tensor([-6.2101], grad_fn=<DivBackward0>)
# tensor([-6.2051], grad_fn=<DivBackward0>)
# tensor([-6.1996], grad_fn=<DivBackward0>)
# tensor([-6.1983], grad_fn=<DivBackward0>)
# tensor([-6.1989], grad_fn=<DivBackward0>)
# tensor([-6.2025], grad_fn=<DivBackward0>)
# tensor([-6.2042], grad_fn=<DivBackward0>)
# tensor([-6.2093], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 38
# tensor([-6.2150], grad_fn=<DivBackward0>)
# tensor([-6.1964], grad_fn=<DivBackward0>)
# tensor([-6.1912], grad_fn=<DivBackward0>)
# tensor([-6.1978], grad_fn=<DivBackward0>)
# tensor([-6.1985], grad_fn=<DivBackward0>)
# tensor([-6.2011], grad_fn=<DivBackward0>)
# tensor([-6.2021], grad_fn=<DivBackward0>)
# tensor([-6.2015], grad_fn=<DivBackward0>)
# tensor([-6.2044], grad_fn=<DivBackward0>)
# tensor([-6.2082], grad_fn=<DivBackward0>)
# tensor([-6.2071], grad_fn=<DivBackward0>)
# tensor([-6.2101], grad_fn=<DivBackward0>)
# tensor([-6.2037], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 39
# tensor([-6.1798], grad_fn=<DivBackward0>)
# tensor([-6.2033], grad_fn=<DivBackward0>)
# tensor([-6.1893], grad_fn=<DivBackward0>)
# tensor([-6.2039], grad_fn=<DivBackward0>)
# tensor([-6.2027], grad_fn=<DivBackward0>)
# tensor([-6.1991], grad_fn=<DivBackward0>)
# tensor([-6.2049], grad_fn=<DivBackward0>)
# tensor([-6.2054], grad_fn=<DivBackward0>)
# tensor([-6.2055], grad_fn=<DivBackward0>)
# tensor([-6.2102], grad_fn=<DivBackward0>)
# tensor([-6.2145], grad_fn=<DivBackward0>)
# tensor([-6.2115], grad_fn=<DivBackward0>)
# tensor([-6.2090], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 40
# tensor([-6.1982], grad_fn=<DivBackward0>)
# tensor([-6.2076], grad_fn=<DivBackward0>)
# tensor([-6.2094], grad_fn=<DivBackward0>)
# tensor([-6.2144], grad_fn=<DivBackward0>)
# tensor([-6.2142], grad_fn=<DivBackward0>)
# tensor([-6.2102], grad_fn=<DivBackward0>)
# tensor([-6.2030], grad_fn=<DivBackward0>)
# tensor([-6.2085], grad_fn=<DivBackward0>)
# tensor([-6.2090], grad_fn=<DivBackward0>)
# tensor([-6.2086], grad_fn=<DivBackward0>)
# tensor([-6.2136], grad_fn=<DivBackward0>)
# tensor([-6.2158], grad_fn=<DivBackward0>)
# tensor([-6.2098], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 41
# tensor([-6.1620], grad_fn=<DivBackward0>)
# tensor([-6.1742], grad_fn=<DivBackward0>)
# tensor([-6.1943], grad_fn=<DivBackward0>)
# tensor([-6.1930], grad_fn=<DivBackward0>)
# tensor([-6.1960], grad_fn=<DivBackward0>)
# tensor([-6.1951], grad_fn=<DivBackward0>)
# tensor([-6.1976], grad_fn=<DivBackward0>)
# tensor([-6.2038], grad_fn=<DivBackward0>)
# tensor([-6.2052], grad_fn=<DivBackward0>)
# tensor([-6.2048], grad_fn=<DivBackward0>)
# tensor([-6.2057], grad_fn=<DivBackward0>)
# tensor([-6.2090], grad_fn=<DivBackward0>)
# tensor([-6.2152], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 42
# tensor([-6.1983], grad_fn=<DivBackward0>)
# tensor([-6.2136], grad_fn=<DivBackward0>)
# tensor([-6.2237], grad_fn=<DivBackward0>)
# tensor([-6.2081], grad_fn=<DivBackward0>)
# tensor([-6.2120], grad_fn=<DivBackward0>)
# tensor([-6.2156], grad_fn=<DivBackward0>)
# tensor([-6.2158], grad_fn=<DivBackward0>)
# tensor([-6.2194], grad_fn=<DivBackward0>)
# tensor([-6.2186], grad_fn=<DivBackward0>)
# tensor([-6.2141], grad_fn=<DivBackward0>)
# tensor([-6.2122], grad_fn=<DivBackward0>)
# tensor([-6.2127], grad_fn=<DivBackward0>)
# tensor([-6.2106], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 43
# tensor([-6.2530], grad_fn=<DivBackward0>)
# tensor([-6.2241], grad_fn=<DivBackward0>)
# tensor([-6.2124], grad_fn=<DivBackward0>)
# tensor([-6.2192], grad_fn=<DivBackward0>)
# tensor([-6.2108], grad_fn=<DivBackward0>)
# tensor([-6.2113], grad_fn=<DivBackward0>)
# tensor([-6.2143], grad_fn=<DivBackward0>)
# tensor([-6.2148], grad_fn=<DivBackward0>)
# tensor([-6.2126], grad_fn=<DivBackward0>)
# tensor([-6.2145], grad_fn=<DivBackward0>)
# tensor([-6.2167], grad_fn=<DivBackward0>)
# tensor([-6.2147], grad_fn=<DivBackward0>)
# tensor([-6.2082], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 44
# tensor([-6.1883], grad_fn=<DivBackward0>)
# tensor([-6.2077], grad_fn=<DivBackward0>)
# tensor([-6.2181], grad_fn=<DivBackward0>)
# tensor([-6.2099], grad_fn=<DivBackward0>)
# tensor([-6.2106], grad_fn=<DivBackward0>)
# tensor([-6.2095], grad_fn=<DivBackward0>)
# tensor([-6.2143], grad_fn=<DivBackward0>)
# tensor([-6.2150], grad_fn=<DivBackward0>)
# tensor([-6.2162], grad_fn=<DivBackward0>)
# tensor([-6.2165], grad_fn=<DivBackward0>)
# tensor([-6.2174], grad_fn=<DivBackward0>)
# tensor([-6.2169], grad_fn=<DivBackward0>)
# tensor([-6.2089], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 45
# tensor([-6.2369], grad_fn=<DivBackward0>)
# tensor([-6.2234], grad_fn=<DivBackward0>)
# tensor([-6.2109], grad_fn=<DivBackward0>)
# tensor([-6.2112], grad_fn=<DivBackward0>)
# tensor([-6.2141], grad_fn=<DivBackward0>)
# tensor([-6.2154], grad_fn=<DivBackward0>)
# tensor([-6.2157], grad_fn=<DivBackward0>)
# tensor([-6.2152], grad_fn=<DivBackward0>)
# tensor([-6.2128], grad_fn=<DivBackward0>)
# tensor([-6.2141], grad_fn=<DivBackward0>)
# tensor([-6.2155], grad_fn=<DivBackward0>)
# tensor([-6.2142], grad_fn=<DivBackward0>)
# tensor([-6.2168], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 46
# tensor([-6.2415], grad_fn=<DivBackward0>)
# tensor([-6.2244], grad_fn=<DivBackward0>)
# tensor([-6.2262], grad_fn=<DivBackward0>)
# tensor([-6.2174], grad_fn=<DivBackward0>)
# tensor([-6.2173], grad_fn=<DivBackward0>)
# tensor([-6.2096], grad_fn=<DivBackward0>)
# tensor([-6.2101], grad_fn=<DivBackward0>)
# tensor([-6.2153], grad_fn=<DivBackward0>)
# tensor([-6.2143], grad_fn=<DivBackward0>)
# tensor([-6.2205], grad_fn=<DivBackward0>)
# tensor([-6.2185], grad_fn=<DivBackward0>)
# tensor([-6.2166], grad_fn=<DivBackward0>)
# tensor([-6.2191], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 47
# tensor([-6.1794], grad_fn=<DivBackward0>)
# tensor([-6.1986], grad_fn=<DivBackward0>)
# tensor([-6.2147], grad_fn=<DivBackward0>)
# tensor([-6.2212], grad_fn=<DivBackward0>)
# tensor([-6.2164], grad_fn=<DivBackward0>)
# tensor([-6.2134], grad_fn=<DivBackward0>)
# tensor([-6.2155], grad_fn=<DivBackward0>)
# tensor([-6.2184], grad_fn=<DivBackward0>)
# tensor([-6.2206], grad_fn=<DivBackward0>)
# tensor([-6.2193], grad_fn=<DivBackward0>)
# tensor([-6.2248], grad_fn=<DivBackward0>)
# tensor([-6.2196], grad_fn=<DivBackward0>)
# tensor([-6.2187], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 48
# tensor([-6.2179], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
# tensor([-6.2052], grad_fn=<DivBackward0>)
# tensor([-6.2106], grad_fn=<DivBackward0>)
# tensor([-6.2205], grad_fn=<DivBackward0>)
# tensor([-6.2217], grad_fn=<DivBackward0>)
# tensor([-6.2220], grad_fn=<DivBackward0>)
# tensor([-6.2236], grad_fn=<DivBackward0>)
# tensor([-6.2222], grad_fn=<DivBackward0>)
# tensor([-6.2179], grad_fn=<DivBackward0>)
# tensor([-6.2177], grad_fn=<DivBackward0>)
# tensor([-6.2172], grad_fn=<DivBackward0>)
# tensor([-6.2089], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 49
# tensor([-6.2105], grad_fn=<DivBackward0>)
# tensor([-6.2076], grad_fn=<DivBackward0>)
# tensor([-6.2067], grad_fn=<DivBackward0>)
# tensor([-6.2121], grad_fn=<DivBackward0>)
# tensor([-6.2147], grad_fn=<DivBackward0>)
# tensor([-6.2118], grad_fn=<DivBackward0>)
# tensor([-6.2125], grad_fn=<DivBackward0>)
# tensor([-6.2131], grad_fn=<DivBackward0>)
# tensor([-6.2104], grad_fn=<DivBackward0>)
# tensor([-6.2100], grad_fn=<DivBackward0>)
# tensor([-6.2130], grad_fn=<DivBackward0>)
# tensor([-6.2166], grad_fn=<DivBackward0>)
# tensor([-6.2085], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 50
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2369], grad_fn=<DivBackward0>)
# tensor([-6.2232], grad_fn=<DivBackward0>)
# tensor([-6.2134], grad_fn=<DivBackward0>)
# tensor([-6.2187], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2181], grad_fn=<DivBackward0>)
# tensor([-6.2197], grad_fn=<DivBackward0>)
# tensor([-6.2186], grad_fn=<DivBackward0>)
# tensor([-6.2178], grad_fn=<DivBackward0>)
# tensor([-6.2188], grad_fn=<DivBackward0>)
# tensor([-6.2183], grad_fn=<DivBackward0>)
# tensor([-6.2157], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 51
# tensor([-6.2374], grad_fn=<DivBackward0>)
# tensor([-6.2307], grad_fn=<DivBackward0>)
# tensor([-6.2247], grad_fn=<DivBackward0>)
# tensor([-6.2302], grad_fn=<DivBackward0>)
# tensor([-6.2203], grad_fn=<DivBackward0>)
# tensor([-6.2121], grad_fn=<DivBackward0>)
# tensor([-6.2131], grad_fn=<DivBackward0>)
# tensor([-6.2145], grad_fn=<DivBackward0>)
# tensor([-6.2130], grad_fn=<DivBackward0>)
# tensor([-6.2136], grad_fn=<DivBackward0>)
# tensor([-6.2168], grad_fn=<DivBackward0>)
# tensor([-6.2199], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 52
# tensor([-6.1864], grad_fn=<DivBackward0>)
# tensor([-6.1895], grad_fn=<DivBackward0>)
# tensor([-6.2198], grad_fn=<DivBackward0>)
# tensor([-6.2307], grad_fn=<DivBackward0>)
# tensor([-6.2264], grad_fn=<DivBackward0>)
# tensor([-6.2272], grad_fn=<DivBackward0>)
# tensor([-6.2221], grad_fn=<DivBackward0>)
# tensor([-6.2216], grad_fn=<DivBackward0>)
# tensor([-6.2209], grad_fn=<DivBackward0>)
# tensor([-6.2215], grad_fn=<DivBackward0>)
# tensor([-6.2196], grad_fn=<DivBackward0>)
# tensor([-6.2180], grad_fn=<DivBackward0>)
# tensor([-6.2150], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 53
# tensor([-6.2308], grad_fn=<DivBackward0>)
# tensor([-6.2541], grad_fn=<DivBackward0>)
# tensor([-6.2241], grad_fn=<DivBackward0>)
# tensor([-6.2289], grad_fn=<DivBackward0>)
# tensor([-6.2228], grad_fn=<DivBackward0>)
# tensor([-6.2234], grad_fn=<DivBackward0>)
# tensor([-6.2263], grad_fn=<DivBackward0>)
# tensor([-6.2197], grad_fn=<DivBackward0>)
# tensor([-6.2188], grad_fn=<DivBackward0>)
# tensor([-6.2155], grad_fn=<DivBackward0>)
# tensor([-6.2184], grad_fn=<DivBackward0>)
# tensor([-6.2204], grad_fn=<DivBackward0>)
# tensor([-6.2168], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 54
# tensor([-6.2347], grad_fn=<DivBackward0>)
# tensor([-6.2308], grad_fn=<DivBackward0>)
# tensor([-6.2269], grad_fn=<DivBackward0>)
# tensor([-6.2161], grad_fn=<DivBackward0>)
# tensor([-6.2126], grad_fn=<DivBackward0>)
# tensor([-6.2159], grad_fn=<DivBackward0>)
# tensor([-6.2182], grad_fn=<DivBackward0>)
# tensor([-6.2188], grad_fn=<DivBackward0>)
# tensor([-6.2183], grad_fn=<DivBackward0>)
# tensor([-6.2173], grad_fn=<DivBackward0>)
# tensor([-6.2154], grad_fn=<DivBackward0>)
# tensor([-6.2180], grad_fn=<DivBackward0>)
# tensor([-6.2160], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 55
# tensor([-6.2537], grad_fn=<DivBackward0>)
# tensor([-6.2483], grad_fn=<DivBackward0>)
# tensor([-6.2336], grad_fn=<DivBackward0>)
# tensor([-6.2434], grad_fn=<DivBackward0>)
# tensor([-6.2384], grad_fn=<DivBackward0>)
# tensor([-6.2397], grad_fn=<DivBackward0>)
# tensor([-6.2358], grad_fn=<DivBackward0>)
# tensor([-6.2300], grad_fn=<DivBackward0>)
# tensor([-6.2304], grad_fn=<DivBackward0>)
# tensor([-6.2280], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2242], grad_fn=<DivBackward0>)
# tensor([-6.2154], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 56
# tensor([-6.2205], grad_fn=<DivBackward0>)
# tensor([-6.2328], grad_fn=<DivBackward0>)
# tensor([-6.2337], grad_fn=<DivBackward0>)
# tensor([-6.2364], grad_fn=<DivBackward0>)
# tensor([-6.2306], grad_fn=<DivBackward0>)
# tensor([-6.2326], grad_fn=<DivBackward0>)
# tensor([-6.2357], grad_fn=<DivBackward0>)
# tensor([-6.2311], grad_fn=<DivBackward0>)
# tensor([-6.2257], grad_fn=<DivBackward0>)
# tensor([-6.2244], grad_fn=<DivBackward0>)
# tensor([-6.2224], grad_fn=<DivBackward0>)
# tensor([-6.2243], grad_fn=<DivBackward0>)
# tensor([-6.2191], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 57
# tensor([-6.2127], grad_fn=<DivBackward0>)
# tensor([-6.2013], grad_fn=<DivBackward0>)
# tensor([-6.2094], grad_fn=<DivBackward0>)
# tensor([-6.2146], grad_fn=<DivBackward0>)
# tensor([-6.2219], grad_fn=<DivBackward0>)
# tensor([-6.2224], grad_fn=<DivBackward0>)
# tensor([-6.2245], grad_fn=<DivBackward0>)
# tensor([-6.2244], grad_fn=<DivBackward0>)
# tensor([-6.2215], grad_fn=<DivBackward0>)
# tensor([-6.2194], grad_fn=<DivBackward0>)
# tensor([-6.2182], grad_fn=<DivBackward0>)
# tensor([-6.2218], grad_fn=<DivBackward0>)
# tensor([-6.2122], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 58
# tensor([-6.2063], grad_fn=<DivBackward0>)
# tensor([-6.2292], grad_fn=<DivBackward0>)
# tensor([-6.2058], grad_fn=<DivBackward0>)
# tensor([-6.2005], grad_fn=<DivBackward0>)
# tensor([-6.2065], grad_fn=<DivBackward0>)
# tensor([-6.2170], grad_fn=<DivBackward0>)
# tensor([-6.2171], grad_fn=<DivBackward0>)
# tensor([-6.2150], grad_fn=<DivBackward0>)
# tensor([-6.2171], grad_fn=<DivBackward0>)
# tensor([-6.2193], grad_fn=<DivBackward0>)
# tensor([-6.2225], grad_fn=<DivBackward0>)
# tensor([-6.2231], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 59
# tensor([-6.2444], grad_fn=<DivBackward0>)
# tensor([-6.2480], grad_fn=<DivBackward0>)
# tensor([-6.2363], grad_fn=<DivBackward0>)
# tensor([-6.2340], grad_fn=<DivBackward0>)
# tensor([-6.2318], grad_fn=<DivBackward0>)
# tensor([-6.2298], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2282], grad_fn=<DivBackward0>)
# tensor([-6.2248], grad_fn=<DivBackward0>)
# tensor([-6.2209], grad_fn=<DivBackward0>)
# tensor([-6.2231], grad_fn=<DivBackward0>)
# tensor([-6.2275], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 60
# tensor([-6.2515], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
# tensor([-6.2216], grad_fn=<DivBackward0>)
# tensor([-6.2291], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2293], grad_fn=<DivBackward0>)
# tensor([-6.2334], grad_fn=<DivBackward0>)
# tensor([-6.2303], grad_fn=<DivBackward0>)
# tensor([-6.2287], grad_fn=<DivBackward0>)
# tensor([-6.2304], grad_fn=<DivBackward0>)
# tensor([-6.2266], grad_fn=<DivBackward0>)
# tensor([-6.2276], grad_fn=<DivBackward0>)
# tensor([-6.2227], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 61
# tensor([-6.2499], grad_fn=<DivBackward0>)
# tensor([-6.2495], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2187], grad_fn=<DivBackward0>)
# tensor([-6.2186], grad_fn=<DivBackward0>)
# tensor([-6.2140], grad_fn=<DivBackward0>)
# tensor([-6.2189], grad_fn=<DivBackward0>)
# tensor([-6.2214], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2256], grad_fn=<DivBackward0>)
# tensor([-6.2255], grad_fn=<DivBackward0>)
# tensor([-6.2207], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 62
# tensor([-6.2199], grad_fn=<DivBackward0>)
# tensor([-6.2246], grad_fn=<DivBackward0>)
# tensor([-6.2196], grad_fn=<DivBackward0>)
# tensor([-6.2226], grad_fn=<DivBackward0>)
# tensor([-6.2223], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2172], grad_fn=<DivBackward0>)
# tensor([-6.2174], grad_fn=<DivBackward0>)
# tensor([-6.2186], grad_fn=<DivBackward0>)
# tensor([-6.2231], grad_fn=<DivBackward0>)
# tensor([-6.2220], grad_fn=<DivBackward0>)
# tensor([-6.2233], grad_fn=<DivBackward0>)
# tensor([-6.2226], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 63
# tensor([-6.1812], grad_fn=<DivBackward0>)
# tensor([-6.2204], grad_fn=<DivBackward0>)
# tensor([-6.2180], grad_fn=<DivBackward0>)
# tensor([-6.2310], grad_fn=<DivBackward0>)
# tensor([-6.2247], grad_fn=<DivBackward0>)
# tensor([-6.2163], grad_fn=<DivBackward0>)
# tensor([-6.2196], grad_fn=<DivBackward0>)
# tensor([-6.2169], grad_fn=<DivBackward0>)
# tensor([-6.2192], grad_fn=<DivBackward0>)
# tensor([-6.2229], grad_fn=<DivBackward0>)
# tensor([-6.2225], grad_fn=<DivBackward0>)
# tensor([-6.2201], grad_fn=<DivBackward0>)
# tensor([-6.2237], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 64
# tensor([-6.2338], grad_fn=<DivBackward0>)
# tensor([-6.2236], grad_fn=<DivBackward0>)
# tensor([-6.2297], grad_fn=<DivBackward0>)
# tensor([-6.2305], grad_fn=<DivBackward0>)
# tensor([-6.2309], grad_fn=<DivBackward0>)
# tensor([-6.2352], grad_fn=<DivBackward0>)
# tensor([-6.2313], grad_fn=<DivBackward0>)
# tensor([-6.2280], grad_fn=<DivBackward0>)
# tensor([-6.2263], grad_fn=<DivBackward0>)
# tensor([-6.2233], grad_fn=<DivBackward0>)
# tensor([-6.2199], grad_fn=<DivBackward0>)
# tensor([-6.2227], grad_fn=<DivBackward0>)
# tensor([-6.2308], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 65
# tensor([-6.2402], grad_fn=<DivBackward0>)
# tensor([-6.2197], grad_fn=<DivBackward0>)
# tensor([-6.2128], grad_fn=<DivBackward0>)
# tensor([-6.2085], grad_fn=<DivBackward0>)
# tensor([-6.2172], grad_fn=<DivBackward0>)
# tensor([-6.2208], grad_fn=<DivBackward0>)
# tensor([-6.2220], grad_fn=<DivBackward0>)
# tensor([-6.2250], grad_fn=<DivBackward0>)
# tensor([-6.2282], grad_fn=<DivBackward0>)
# tensor([-6.2254], grad_fn=<DivBackward0>)
# tensor([-6.2255], grad_fn=<DivBackward0>)
# tensor([-6.2266], grad_fn=<DivBackward0>)
# tensor([-6.2271], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 66
# tensor([-6.2739], grad_fn=<DivBackward0>)
# tensor([-6.2581], grad_fn=<DivBackward0>)
# tensor([-6.2473], grad_fn=<DivBackward0>)
# tensor([-6.2259], grad_fn=<DivBackward0>)
# tensor([-6.2236], grad_fn=<DivBackward0>)
# tensor([-6.2243], grad_fn=<DivBackward0>)
# tensor([-6.2230], grad_fn=<DivBackward0>)
# tensor([-6.2203], grad_fn=<DivBackward0>)
# tensor([-6.2234], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
# tensor([-6.2271], grad_fn=<DivBackward0>)
# tensor([-6.2270], grad_fn=<DivBackward0>)
# tensor([-6.2308], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 67
# tensor([-6.2533], grad_fn=<DivBackward0>)
# tensor([-6.2267], grad_fn=<DivBackward0>)
# tensor([-6.2238], grad_fn=<DivBackward0>)
# tensor([-6.2257], grad_fn=<DivBackward0>)
# tensor([-6.2147], grad_fn=<DivBackward0>)
# tensor([-6.2160], grad_fn=<DivBackward0>)
# tensor([-6.2195], grad_fn=<DivBackward0>)
# tensor([-6.2208], grad_fn=<DivBackward0>)
# tensor([-6.2226], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2316], grad_fn=<DivBackward0>)
# tensor([-6.2313], grad_fn=<DivBackward0>)
# tensor([-6.2203], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 68
# tensor([-6.1899], grad_fn=<DivBackward0>)
# tensor([-6.2103], grad_fn=<DivBackward0>)
# tensor([-6.2112], grad_fn=<DivBackward0>)
# tensor([-6.2242], grad_fn=<DivBackward0>)
# tensor([-6.2252], grad_fn=<DivBackward0>)
# tensor([-6.2238], grad_fn=<DivBackward0>)
# tensor([-6.2273], grad_fn=<DivBackward0>)
# tensor([-6.2284], grad_fn=<DivBackward0>)
# tensor([-6.2316], grad_fn=<DivBackward0>)
# tensor([-6.2267], grad_fn=<DivBackward0>)
# tensor([-6.2282], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2294], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 69
# tensor([-6.2486], grad_fn=<DivBackward0>)
# tensor([-6.2394], grad_fn=<DivBackward0>)
# tensor([-6.2293], grad_fn=<DivBackward0>)
# tensor([-6.2248], grad_fn=<DivBackward0>)
# tensor([-6.2291], grad_fn=<DivBackward0>)
# tensor([-6.2292], grad_fn=<DivBackward0>)
# tensor([-6.2305], grad_fn=<DivBackward0>)
# tensor([-6.2342], grad_fn=<DivBackward0>)
# tensor([-6.2365], grad_fn=<DivBackward0>)
# tensor([-6.2388], grad_fn=<DivBackward0>)
# tensor([-6.2317], grad_fn=<DivBackward0>)
# tensor([-6.2301], grad_fn=<DivBackward0>)
# tensor([-6.2282], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 70
# tensor([-6.2482], grad_fn=<DivBackward0>)
# tensor([-6.2499], grad_fn=<DivBackward0>)
# tensor([-6.2376], grad_fn=<DivBackward0>)
# tensor([-6.2302], grad_fn=<DivBackward0>)
# tensor([-6.2371], grad_fn=<DivBackward0>)
# tensor([-6.2353], grad_fn=<DivBackward0>)
# tensor([-6.2316], grad_fn=<DivBackward0>)
# tensor([-6.2339], grad_fn=<DivBackward0>)
# tensor([-6.2352], grad_fn=<DivBackward0>)
# tensor([-6.2308], grad_fn=<DivBackward0>)
# tensor([-6.2312], grad_fn=<DivBackward0>)
# tensor([-6.2291], grad_fn=<DivBackward0>)
# tensor([-6.2240], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 71
# tensor([-6.2224], grad_fn=<DivBackward0>)
# tensor([-6.2434], grad_fn=<DivBackward0>)
# tensor([-6.2309], grad_fn=<DivBackward0>)
# tensor([-6.2319], grad_fn=<DivBackward0>)
# tensor([-6.2211], grad_fn=<DivBackward0>)
# tensor([-6.2283], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2319], grad_fn=<DivBackward0>)
# tensor([-6.2338], grad_fn=<DivBackward0>)
# tensor([-6.2305], grad_fn=<DivBackward0>)
# ...
# training epoch = 76
# tensor([-6.2520], grad_fn=<DivBackward0>)
# tensor([-6.2384], grad_fn=<DivBackward0>)
# tensor([-6.2506], grad_fn=<DivBackward0>)
# tensor([-6.2370], grad_fn=<DivBackward0>)
# tensor([-6.2251], grad_fn=<DivBackward0>)
# tensor([-6.2310], grad_fn=<DivBackward0>)
# tensor([-6.2343], grad_fn=<DivBackward0>)
# tensor([-6.2338], grad_fn=<DivBackward0>)
# tensor([-6.2349], grad_fn=<DivBackward0>)
# tensor([-6.2373], grad_fn=<DivBackward0>)
# tensor([-6.2318], grad_fn=<DivBackward0>)
# tensor([-6.2295], grad_fn=<DivBackward0>)
# tensor([-6.2276], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 77
# tensor([-6.2021], grad_fn=<DivBackward0>)
# tensor([-6.2153], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
# tensor([-6.2280], grad_fn=<DivBackward0>)
# tensor([-6.2251], grad_fn=<DivBackward0>)
# tensor([-6.2252], grad_fn=<DivBackward0>)
# tensor([-6.2249], grad_fn=<DivBackward0>)
# tensor([-6.2234], grad_fn=<DivBackward0>)
# tensor([-6.2232], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2299], grad_fn=<DivBackward0>)
# tensor([-6.2267], grad_fn=<DivBackward0>)
# tensor([-6.2262], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 78
# tensor([-6.2478], grad_fn=<DivBackward0>)
# tensor([-6.2266], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2218], grad_fn=<DivBackward0>)
# tensor([-6.2159], grad_fn=<DivBackward0>)
# tensor([-6.2210], grad_fn=<DivBackward0>)
# tensor([-6.2174], grad_fn=<DivBackward0>)
# tensor([-6.2150], grad_fn=<DivBackward0>)
# tensor([-6.2172], grad_fn=<DivBackward0>)
# tensor([-6.2200], grad_fn=<DivBackward0>)
# tensor([-6.2203], grad_fn=<DivBackward0>)
# tensor([-6.2222], grad_fn=<DivBackward0>)
# tensor([-6.2303], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 79
# tensor([-6.2531], grad_fn=<DivBackward0>)
# tensor([-6.2273], grad_fn=<DivBackward0>)
# tensor([-6.2198], grad_fn=<DivBackward0>)
# tensor([-6.2250], grad_fn=<DivBackward0>)
# tensor([-6.2291], grad_fn=<DivBackward0>)
# tensor([-6.2284], grad_fn=<DivBackward0>)
# tensor([-6.2273], grad_fn=<DivBackward0>)
# tensor([-6.2290], grad_fn=<DivBackward0>)
# tensor([-6.2283], grad_fn=<DivBackward0>)
# tensor([-6.2296], grad_fn=<DivBackward0>)
# tensor([-6.2272], grad_fn=<DivBackward0>)
# tensor([-6.2259], grad_fn=<DivBackward0>)
# tensor([-6.2197], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 80
# tensor([-6.2374], grad_fn=<DivBackward0>)
# tensor([-6.2202], grad_fn=<DivBackward0>)
# tensor([-6.2177], grad_fn=<DivBackward0>)
# tensor([-6.2287], grad_fn=<DivBackward0>)
# tensor([-6.2349], grad_fn=<DivBackward0>)
# tensor([-6.2286], grad_fn=<DivBackward0>)
# tensor([-6.2349], grad_fn=<DivBackward0>)
# tensor([-6.2262], grad_fn=<DivBackward0>)
# tensor([-6.2264], grad_fn=<DivBackward0>)
# tensor([-6.2267], grad_fn=<DivBackward0>)
# tensor([-6.2285], grad_fn=<DivBackward0>)
# tensor([-6.2279], grad_fn=<DivBackward0>)
# tensor([-6.2240], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 81
# tensor([-6.2071], grad_fn=<DivBackward0>)
# tensor([-6.2072], grad_fn=<DivBackward0>)
# tensor([-6.2023], grad_fn=<DivBackward0>)
# tensor([-6.2082], grad_fn=<DivBackward0>)
# tensor([-6.2143], grad_fn=<DivBackward0>)
# tensor([-6.2214], grad_fn=<DivBackward0>)
# tensor([-6.2235], grad_fn=<DivBackward0>)
# tensor([-6.2246], grad_fn=<DivBackward0>)
# tensor([-6.2276], grad_fn=<DivBackward0>)
# tensor([-6.2302], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2253], grad_fn=<DivBackward0>)
# tensor([-6.2230], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 82
# tensor([-6.2154], grad_fn=<DivBackward0>)
# tensor([-6.2275], grad_fn=<DivBackward0>)
# tensor([-6.2245], grad_fn=<DivBackward0>)
# tensor([-6.2275], grad_fn=<DivBackward0>)
# tensor([-6.2320], grad_fn=<DivBackward0>)
# tensor([-6.2265], grad_fn=<DivBackward0>)
# tensor([-6.2246], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
# tensor([-6.2264], grad_fn=<DivBackward0>)
# tensor([-6.2266], grad_fn=<DivBackward0>)
# tensor([-6.2244], grad_fn=<DivBackward0>)
# tensor([-6.2239], grad_fn=<DivBackward0>)
# tensor([-6.2327], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 83
# tensor([-6.1928], grad_fn=<DivBackward0>)
# tensor([-6.2153], grad_fn=<DivBackward0>)
# tensor([-6.2239], grad_fn=<DivBackward0>)
# tensor([-6.2232], grad_fn=<DivBackward0>)
# tensor([-6.2237], grad_fn=<DivBackward0>)
# tensor([-6.2259], grad_fn=<DivBackward0>)
# tensor([-6.2278], grad_fn=<DivBackward0>)
# tensor([-6.2293], grad_fn=<DivBackward0>)
# tensor([-6.2269], grad_fn=<DivBackward0>)
# tensor([-6.2267], grad_fn=<DivBackward0>)
# tensor([-6.2290], grad_fn=<DivBackward0>)
# tensor([-6.2296], grad_fn=<DivBackward0>)
# tensor([-6.2273], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 84
# tensor([-6.2437], grad_fn=<DivBackward0>)
# tensor([-6.2386], grad_fn=<DivBackward0>)
# tensor([-6.2325], grad_fn=<DivBackward0>)
# tensor([-6.2344], grad_fn=<DivBackward0>)
# tensor([-6.2252], grad_fn=<DivBackward0>)
# tensor([-6.2277], grad_fn=<DivBackward0>)
# tensor([-6.2247], grad_fn=<DivBackward0>)
# tensor([-6.2262], grad_fn=<DivBackward0>)
# tensor([-6.2278], grad_fn=<DivBackward0>)
# tensor([-6.2254], grad_fn=<DivBackward0>)
# tensor([-6.2247], grad_fn=<DivBackward0>)
# tensor([-6.2279], grad_fn=<DivBackward0>)
# tensor([-6.2330], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 85
# tensor([-6.2172], grad_fn=<DivBackward0>)
# tensor([-6.2248], grad_fn=<DivBackward0>)
# tensor([-6.2142], grad_fn=<DivBackward0>)
# tensor([-6.2203], grad_fn=<DivBackward0>)
# tensor([-6.2217], grad_fn=<DivBackward0>)
# tensor([-6.2184], grad_fn=<DivBackward0>)
# tensor([-6.2201], grad_fn=<DivBackward0>)
# tensor([-6.2266], grad_fn=<DivBackward0>)
# tensor([-6.2271], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
# tensor([-6.2292], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2355], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 86
# tensor([-6.2468], grad_fn=<DivBackward0>)
# tensor([-6.2551], grad_fn=<DivBackward0>)
# tensor([-6.2472], grad_fn=<DivBackward0>)
# tensor([-6.2444], grad_fn=<DivBackward0>)
# tensor([-6.2317], grad_fn=<DivBackward0>)
# tensor([-6.2249], grad_fn=<DivBackward0>)
# tensor([-6.2251], grad_fn=<DivBackward0>)
# tensor([-6.2327], grad_fn=<DivBackward0>)
# tensor([-6.2316], grad_fn=<DivBackward0>)
# tensor([-6.2312], grad_fn=<DivBackward0>)
# tensor([-6.2313], grad_fn=<DivBackward0>)
# tensor([-6.2280], grad_fn=<DivBackward0>)
# tensor([-6.2267], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 87
# tensor([-6.2031], grad_fn=<DivBackward0>)
# tensor([-6.2069], grad_fn=<DivBackward0>)
# tensor([-6.2244], grad_fn=<DivBackward0>)
# tensor([-6.2336], grad_fn=<DivBackward0>)
# tensor([-6.2365], grad_fn=<DivBackward0>)
# tensor([-6.2326], grad_fn=<DivBackward0>)
# tensor([-6.2319], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
# tensor([-6.2222], grad_fn=<DivBackward0>)
# tensor([-6.2230], grad_fn=<DivBackward0>)
# tensor([-6.2225], grad_fn=<DivBackward0>)
# tensor([-6.2280], grad_fn=<DivBackward0>)
# tensor([-6.2310], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 88
# tensor([-6.1793], grad_fn=<DivBackward0>)
# tensor([-6.1941], grad_fn=<DivBackward0>)
# tensor([-6.1971], grad_fn=<DivBackward0>)
# tensor([-6.2070], grad_fn=<DivBackward0>)
# tensor([-6.2119], grad_fn=<DivBackward0>)
# tensor([-6.2125], grad_fn=<DivBackward0>)
# tensor([-6.2206], grad_fn=<DivBackward0>)
# tensor([-6.2245], grad_fn=<DivBackward0>)
# tensor([-6.2245], grad_fn=<DivBackward0>)
# tensor([-6.2291], grad_fn=<DivBackward0>)
# tensor([-6.2286], grad_fn=<DivBackward0>)
# tensor([-6.2271], grad_fn=<DivBackward0>)
# tensor([-6.2269], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 89
# tensor([-6.2214], grad_fn=<DivBackward0>)
# tensor([-6.2316], grad_fn=<DivBackward0>)
# tensor([-6.2372], grad_fn=<DivBackward0>)
# tensor([-6.2283], grad_fn=<DivBackward0>)
# tensor([-6.2294], grad_fn=<DivBackward0>)
# tensor([-6.2242], grad_fn=<DivBackward0>)
# tensor([-6.2242], grad_fn=<DivBackward0>)
# tensor([-6.2238], grad_fn=<DivBackward0>)
# tensor([-6.2223], grad_fn=<DivBackward0>)
# tensor([-6.2234], grad_fn=<DivBackward0>)
# tensor([-6.2251], grad_fn=<DivBackward0>)
# tensor([-6.2243], grad_fn=<DivBackward0>)
# tensor([-6.2223], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 90
# tensor([-6.2069], grad_fn=<DivBackward0>)
# tensor([-6.2214], grad_fn=<DivBackward0>)
# tensor([-6.2221], grad_fn=<DivBackward0>)
# tensor([-6.2200], grad_fn=<DivBackward0>)
# tensor([-6.2300], grad_fn=<DivBackward0>)
# tensor([-6.2228], grad_fn=<DivBackward0>)
# tensor([-6.2200], grad_fn=<DivBackward0>)
# tensor([-6.2248], grad_fn=<DivBackward0>)
# tensor([-6.2249], grad_fn=<DivBackward0>)
# tensor([-6.2238], grad_fn=<DivBackward0>)
# tensor([-6.2255], grad_fn=<DivBackward0>)
# tensor([-6.2264], grad_fn=<DivBackward0>)
# tensor([-6.2243], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 91
# tensor([-6.2495], grad_fn=<DivBackward0>)
# tensor([-6.2355], grad_fn=<DivBackward0>)
# tensor([-6.2257], grad_fn=<DivBackward0>)
# tensor([-6.2230], grad_fn=<DivBackward0>)
# tensor([-6.2212], grad_fn=<DivBackward0>)
# tensor([-6.2291], grad_fn=<DivBackward0>)
# tensor([-6.2256], grad_fn=<DivBackward0>)
# tensor([-6.2269], grad_fn=<DivBackward0>)
# tensor([-6.2280], grad_fn=<DivBackward0>)
# tensor([-6.2320], grad_fn=<DivBackward0>)
# tensor([-6.2348], grad_fn=<DivBackward0>)
# tensor([-6.2326], grad_fn=<DivBackward0>)
# tensor([-6.2264], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 92
# tensor([-6.2646], grad_fn=<DivBackward0>)
# tensor([-6.2331], grad_fn=<DivBackward0>)
# tensor([-6.2454], grad_fn=<DivBackward0>)
# tensor([-6.2401], grad_fn=<DivBackward0>)
# tensor([-6.2386], grad_fn=<DivBackward0>)
# tensor([-6.2347], grad_fn=<DivBackward0>)
# tensor([-6.2342], grad_fn=<DivBackward0>)
# tensor([-6.2350], grad_fn=<DivBackward0>)
# tensor([-6.2297], grad_fn=<DivBackward0>)
# tensor([-6.2258], grad_fn=<DivBackward0>)
# tensor([-6.2292], grad_fn=<DivBackward0>)
# tensor([-6.2310], grad_fn=<DivBackward0>)
# tensor([-6.2319], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 93
# tensor([-6.2599], grad_fn=<DivBackward0>)
# tensor([-6.2382], grad_fn=<DivBackward0>)
# tensor([-6.2405], grad_fn=<DivBackward0>)
# tensor([-6.2411], grad_fn=<DivBackward0>)
# tensor([-6.2401], grad_fn=<DivBackward0>)
# tensor([-6.2339], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2318], grad_fn=<DivBackward0>)
# tensor([-6.2308], grad_fn=<DivBackward0>)
# tensor([-6.2346], grad_fn=<DivBackward0>)
# tensor([-6.2320], grad_fn=<DivBackward0>)
# tensor([-6.2300], grad_fn=<DivBackward0>)
# tensor([-6.2307], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 94
# tensor([-6.1930], grad_fn=<DivBackward0>)
# tensor([-6.2256], grad_fn=<DivBackward0>)
# tensor([-6.2476], grad_fn=<DivBackward0>)
# tensor([-6.2349], grad_fn=<DivBackward0>)
# tensor([-6.2378], grad_fn=<DivBackward0>)
# tensor([-6.2312], grad_fn=<DivBackward0>)
# tensor([-6.2317], grad_fn=<DivBackward0>)
# tensor([-6.2327], grad_fn=<DivBackward0>)
# tensor([-6.2309], grad_fn=<DivBackward0>)
# tensor([-6.2315], grad_fn=<DivBackward0>)
# tensor([-6.2297], grad_fn=<DivBackward0>)
# tensor([-6.2315], grad_fn=<DivBackward0>)
# tensor([-6.2283], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 95
# tensor([-6.2823], grad_fn=<DivBackward0>)
# tensor([-6.2667], grad_fn=<DivBackward0>)
# tensor([-6.2486], grad_fn=<DivBackward0>)
# tensor([-6.2490], grad_fn=<DivBackward0>)
# tensor([-6.2366], grad_fn=<DivBackward0>)
# tensor([-6.2360], grad_fn=<DivBackward0>)
# tensor([-6.2349], grad_fn=<DivBackward0>)
# tensor([-6.2299], grad_fn=<DivBackward0>)
# tensor([-6.2277], grad_fn=<DivBackward0>)
# tensor([-6.2315], grad_fn=<DivBackward0>)
# tensor([-6.2305], grad_fn=<DivBackward0>)
# tensor([-6.2336], grad_fn=<DivBackward0>)
# tensor([-6.2353], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 96
# tensor([-6.2817], grad_fn=<DivBackward0>)
# tensor([-6.2601], grad_fn=<DivBackward0>)
# tensor([-6.2452], grad_fn=<DivBackward0>)
# tensor([-6.2521], grad_fn=<DivBackward0>)
# tensor([-6.2414], grad_fn=<DivBackward0>)
# tensor([-6.2311], grad_fn=<DivBackward0>)
# tensor([-6.2259], grad_fn=<DivBackward0>)
# tensor([-6.2307], grad_fn=<DivBackward0>)
# tensor([-6.2289], grad_fn=<DivBackward0>)
# tensor([-6.2293], grad_fn=<DivBackward0>)
# tensor([-6.2304], grad_fn=<DivBackward0>)
# tensor([-6.2279], grad_fn=<DivBackward0>)
# tensor([-6.2344], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 97
# tensor([-6.2354], grad_fn=<DivBackward0>)
# tensor([-6.2334], grad_fn=<DivBackward0>)
# tensor([-6.2306], grad_fn=<DivBackward0>)
# tensor([-6.2399], grad_fn=<DivBackward0>)
# tensor([-6.2316], grad_fn=<DivBackward0>)
# tensor([-6.2311], grad_fn=<DivBackward0>)
# tensor([-6.2304], grad_fn=<DivBackward0>)
# tensor([-6.2303], grad_fn=<DivBackward0>)
# tensor([-6.2283], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
# tensor([-6.2299], grad_fn=<DivBackward0>)
# tensor([-6.2272], grad_fn=<DivBackward0>)
# tensor([-6.2252], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 98
# tensor([-6.2121], grad_fn=<DivBackward0>)
# tensor([-6.2294], grad_fn=<DivBackward0>)
# tensor([-6.2298], grad_fn=<DivBackward0>)
# tensor([-6.2234], grad_fn=<DivBackward0>)
# tensor([-6.2277], grad_fn=<DivBackward0>)
# tensor([-6.2376], grad_fn=<DivBackward0>)
# tensor([-6.2334], grad_fn=<DivBackward0>)
# tensor([-6.2318], grad_fn=<DivBackward0>)
# tensor([-6.2281], grad_fn=<DivBackward0>)
# tensor([-6.2300], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2288], grad_fn=<DivBackward0>)
# tensor([-6.2237], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 99
# tensor([-6.2081], grad_fn=<DivBackward0>)
# tensor([-6.2203], grad_fn=<DivBackward0>)
# tensor([-6.2311], grad_fn=<DivBackward0>)
# tensor([-6.2446], grad_fn=<DivBackward0>)
# tensor([-6.2470], grad_fn=<DivBackward0>)
# tensor([-6.2421], grad_fn=<DivBackward0>)
# tensor([-6.2360], grad_fn=<DivBackward0>)
# tensor([-6.2332], grad_fn=<DivBackward0>)
# tensor([-6.2261], grad_fn=<DivBackward0>)
# tensor([-6.2210], grad_fn=<DivBackward0>)
# tensor([-6.2274], grad_fn=<DivBackward0>)
# tensor([-6.2274], grad_fn=<DivBackward0>)
# tensor([-6.2283], grad_fn=<DivBackward0>)

# %%
DUE_thr = 0.5
tx_max = 10**2.0
I_thr = 10**(-50.0/10)
P_c = 10**2.0
BW = 1e7
noise = BW*10**-17.4

# %%
net = Net(Num_user, Num_channel, 1000, 5).to(device)

net.train()

optimizer = torch.optim.Adam(net.parameters(), lr=2*1e-3)

lam_val_mat = torch.ones(3, 1).to(device)

RATE_lam = 1
DUE_lam = 10
CUE_lam = 10

lam_val_mat[0] = RATE_lam
lam_val_mat[1] = DUE_lam
lam_val_mat[2] = CUE_lam

for i in range(100):
    print("")
    print("**"*50)
    print(f"training epoch = {i}")
    cur_loss_tot = 0
    for index, chan in enumerate(train_dataloader):
        net.train()
        optimizer.zero_grad()

        p_dnn = net(chan.to(device))

        cur_loss = My_Loss(p_dnn, chan.to(device), tx_max, noise, DUE_thr, I_thr, P_c, device, chan_mean, chan_std, lam_val_mat)

        cur_loss_tot += cur_loss

        cur_loss.backward()
        optimizer.step()
        print(cur_loss_tot/(index+1))
# Out:
# ****************************************************************************************************
# training epoch = 0
# tensor([6.1957], grad_fn=<DivBackward0>)
# tensor([1.1773], grad_fn=<DivBackward0>)
# tensor([-0.5058], grad_fn=<DivBackward0>)
# tensor([-1.4095], grad_fn=<DivBackward0>)
# tensor([-1.9458], grad_fn=<DivBackward0>)
# tensor([-2.3190], grad_fn=<DivBackward0>)
# tensor([-2.5857], grad_fn=<DivBackward0>)
# tensor([-2.8042], grad_fn=<DivBackward0>)
# tensor([-2.9845], grad_fn=<DivBackward0>)
# tensor([-3.1296], grad_fn=<DivBackward0>)
# tensor([-3.2633], grad_fn=<DivBackward0>)
# tensor([-3.3755], grad_fn=<DivBackward0>)
# tensor([-3.4673], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 1
# tensor([-4.7422], grad_fn=<DivBackward0>)
# tensor([-4.7302], grad_fn=<DivBackward0>)
# tensor([-4.7848], grad_fn=<DivBackward0>)
# tensor([-4.8255], grad_fn=<DivBackward0>)
# tensor([-4.8562], grad_fn=<DivBackward0>)
# tensor([-4.8860], grad_fn=<DivBackward0>)
# tensor([-4.9093], grad_fn=<DivBackward0>)
# tensor([-4.9419], grad_fn=<DivBackward0>)
# tensor([-4.9672], grad_fn=<DivBackward0>)
# tensor([-4.9911], grad_fn=<DivBackward0>)
# tensor([-5.0157], grad_fn=<DivBackward0>)
# tensor([-5.0360], grad_fn=<DivBackward0>)
# tensor([-5.0646], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 2
# tensor([-5.3356], grad_fn=<DivBackward0>)
# tensor([-5.3716], grad_fn=<DivBackward0>)
# tensor([-5.4120], grad_fn=<DivBackward0>)
# tensor([-5.4138], grad_fn=<DivBackward0>)
# tensor([-5.4145], grad_fn=<DivBackward0>)
# tensor([-5.4375], grad_fn=<DivBackward0>)
# tensor([-5.4472], grad_fn=<DivBackward0>)
# tensor([-5.4718], grad_fn=<DivBackward0>)
# tensor([-5.4900], grad_fn=<DivBackward0>)
# tensor([-5.5115], grad_fn=<DivBackward0>)
# tensor([-5.5259], grad_fn=<DivBackward0>)
# tensor([-5.5427], grad_fn=<DivBackward0>)
# tensor([-5.5548], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 3
# tensor([-5.6108], grad_fn=<DivBackward0>)
# tensor([-5.6703], grad_fn=<DivBackward0>)
# tensor([-5.7142], grad_fn=<DivBackward0>)
# tensor([-5.7449], grad_fn=<DivBackward0>)
# tensor([-5.7766], grad_fn=<DivBackward0>)
# tensor([-5.7910], grad_fn=<DivBackward0>)
# tensor([-5.7979], grad_fn=<DivBackward0>)
# tensor([-5.8132], grad_fn=<DivBackward0>)
# tensor([-5.8205], grad_fn=<DivBackward0>)
# tensor([-5.8369], grad_fn=<DivBackward0>)
# tensor([-5.8496], grad_fn=<DivBackward0>)
# tensor([-5.8602], grad_fn=<DivBackward0>)
# tensor([-5.8621], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 4
# tensor([-6.0156], grad_fn=<DivBackward0>)
# tensor([-6.0187], grad_fn=<DivBackward0>)
# tensor([-5.9969], grad_fn=<DivBackward0>)
# tensor([-6.0094], grad_fn=<DivBackward0>)
# tensor([-6.0086], grad_fn=<DivBackward0>)
# tensor([-6.0135], grad_fn=<DivBackward0>)
# tensor([-6.0180], grad_fn=<DivBackward0>)
# tensor([-6.0315], grad_fn=<DivBackward0>)
# tensor([-6.0253], grad_fn=<DivBackward0>)
# tensor([-6.0279], grad_fn=<DivBackward0>)
# tensor([-6.0288], grad_fn=<DivBackward0>)
# tensor([-6.0346], grad_fn=<DivBackward0>)
# tensor([-6.0376], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 5
# tensor([-6.1201], grad_fn=<DivBackward0>)
# tensor([-6.1102], grad_fn=<DivBackward0>)
# tensor([-6.0971], grad_fn=<DivBackward0>)
# tensor([-6.1039], grad_fn=<DivBackward0>)
# tensor([-6.1130], grad_fn=<DivBackward0>)
# tensor([-6.1188], grad_fn=<DivBackward0>)
# tensor([-6.1289], grad_fn=<DivBackward0>)
# tensor([-6.1392], grad_fn=<DivBackward0>)
# tensor([-6.1449], grad_fn=<DivBackward0>)
# tensor([-6.1497], grad_fn=<DivBackward0>)
# tensor([-6.1509], grad_fn=<DivBackward0>)
# tensor([-6.1421], grad_fn=<DivBackward0>)
# tensor([-6.1514], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 6
# tensor([-6.2101], grad_fn=<DivBackward0>)
# tensor([-6.2161], grad_fn=<DivBackward0>)
# tensor([-6.1978], grad_fn=<DivBackward0>)
# tensor([-6.2045], grad_fn=<DivBackward0>)
# tensor([-6.2134], grad_fn=<DivBackward0>)
# tensor([-6.2119], grad_fn=<DivBackward0>)
# tensor([-6.2172], grad_fn=<DivBackward0>)
# tensor([-6.2196], grad_fn=<DivBackward0>)
# tensor([-6.2171], grad_fn=<DivBackward0>)
# tensor([-6.2210], grad_fn=<DivBackward0>)
# tensor([-6.2242], grad_fn=<DivBackward0>)
# tensor([-6.2268], grad_fn=<DivBackward0>)
# tensor([-6.2355], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 7
# tensor([-6.3007], grad_fn=<DivBackward0>)
# tensor([-6.3012], grad_fn=<DivBackward0>)
# tensor([-6.2829], grad_fn=<DivBackward0>)
# tensor([-6.2858], grad_fn=<DivBackward0>)
# tensor([-6.2917], grad_fn=<DivBackward0>)
# tensor([-6.2872], grad_fn=<DivBackward0>)
# tensor([-6.2924], grad_fn=<DivBackward0>)
# tensor([-6.2932], grad_fn=<DivBackward0>)
# tensor([-6.3059], grad_fn=<DivBackward0>)
# tensor([-6.3106], grad_fn=<DivBackward0>)
# tensor([-6.3137], grad_fn=<DivBackward0>)
# tensor([-6.3210], grad_fn=<DivBackward0>)
# tensor([-6.3200], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 8
# tensor([-6.3660], grad_fn=<DivBackward0>)
# tensor([-6.3593], grad_fn=<DivBackward0>)
# tensor([-6.3665], grad_fn=<DivBackward0>)
# tensor([-6.3757], grad_fn=<DivBackward0>)
# tensor([-6.3864], grad_fn=<DivBackward0>)
# tensor([-6.3846], grad_fn=<DivBackward0>)
# tensor([-6.3888], grad_fn=<DivBackward0>)
# tensor([-6.3839], grad_fn=<DivBackward0>)
# tensor([-6.3748], grad_fn=<DivBackward0>)
# tensor([-6.3787], grad_fn=<DivBackward0>)
# tensor([-6.3758], grad_fn=<DivBackward0>)
# tensor([-6.3759], grad_fn=<DivBackward0>)
# tensor([-6.3731], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 9
# tensor([-6.4385], grad_fn=<DivBackward0>)
# tensor([-6.4434], grad_fn=<DivBackward0>)
# tensor([-6.4171], grad_fn=<DivBackward0>)
# tensor([-6.4226], grad_fn=<DivBackward0>)
# tensor([-6.4064], grad_fn=<DivBackward0>)
# tensor([-6.4083], grad_fn=<DivBackward0>)
# tensor([-6.3993], grad_fn=<DivBackward0>)
# tensor([-6.4003], grad_fn=<DivBackward0>)
# tensor([-6.3958], grad_fn=<DivBackward0>)
# tensor([-6.4009], grad_fn=<DivBackward0>)
# tensor([-6.4032], grad_fn=<DivBackward0>)
# tensor([-6.4048], grad_fn=<DivBackward0>)
# tensor([-6.4023], grad_fn=<DivBackward0>)
#
# ****************************************************************************************************
# training epoch = 10
# tensor([-6.4147], grad_fn=<DivBackward0>)
# tensor([-6.3984], grad_fn=<DivBackward0>)
# tensor([-6.4004], grad_fn=<DivBackward0>)

# %%
net.eval()
for index, chan_val in enumerate(train_dataloader):
    print(index)
    p_dnn = net(chan_val.to(device)).detach().numpy()
    print("p_dnn = ", p_dnn)
    chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
    print(cal_rate_NP(chan_val_rev, p_dnn, tx_max, noise, DUE_thr, I_thr, P_c))
# Out:
# 0
# p_dnn =  [[[1.736e-03 8.874e-01]
#   [7.650e-04 4.175e-02]
#   [4.202e-01 4.456e-02]]
#
#  [[1.458e-03 9.767e-01]
#   [9.934e-01 7.761e-20]
#   [8.406e-11 9.043e-01]]
#
#  [[3.392e-11 9.315e-01]
#   [4.926e-01 2.305e-05]
#   [9.772e-04 9.184e-01]]
#
#  ...
#
#  [[5.633e-01 2.726e-14]
#   [4.691e-01 6.449e-02]
#   [4.555e-13 8.218e-02]]
#
#  [[9.787e-01 4.458e-05]
#   [3.215e-03 9.904e-01]
#   [1.477e-02 9.843e-01]]
#
#  [[3.682e-09 9.438e-01]
#   [2.217e-06 1.418e-03]
#   [4.285e-01 1.135e-17]]]
# D2D_SE_sum =  4.248316489969407
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.667262424580619
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.198360688652089
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.991228824461575
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.289810631969701
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.591034570966224
# D2D_SE_sum =  8.693175850738077
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.961539442417805
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.987411000178833
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.593782396734657
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.0359078838482794
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.87498285801991
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.387415221502566
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.411049387477521
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.556573405627164
# D2D_SE_sum =  6.216834422670897
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  22.46190886213011
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.273620052215119
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.653269085778776
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.20424148952061
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.581741899622736
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.967741469743718
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.696635208273493
# D2D_SE_sum =  0.0
# D2D_SE_sum =  17.798929816003387
# D2D_SE_sum =  8.811579475363514
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.403091171804565
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.320137057468486
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.325688311278173
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.997378995079071
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.39492061846782
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.533991206313614
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.918033145225614
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.065181051115493
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.58197298420843
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.56553956851706
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.63850114099146
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.850651418045807
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.05624093257417
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.754151388701425
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.077751433600742
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.233049754487551
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.88125128612737
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.670617883741647
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.134644781610803
# D2D_SE_sum =  0.0
# D2D_SE_sum =  16.62833900137047
# D2D_SE_sum =  4.871798731491922
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.758345654972348
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.415882467318538
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.659415047460081
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.580223502905716
# D2D_SE_sum =  4.8712264609037215
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.891903409406854
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.217424772371999
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.376845906998867
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.876571542928053
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.98700176951474
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.3674944717829827
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.355746077455995
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.137268189451572
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  17.546693093919824
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.367456126410413
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  20.341883438581522
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.3738723583052
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.237376570032147
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.100691157341814
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.310525080426561
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.808841601351663
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.1782261771842704
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.016616235246934
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.211319967505196
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.397916265462581
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.83498495352283
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.802961230261076
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.981109882176016
# D2D_SE_sum =  8.913087581162836
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.351802261689833
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.443989678849098
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  16.005535159693803
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.490402522598156
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.990788954477401
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.21449742749124
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.824159823609467
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.472074058489776
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.294852203579207
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.563261569649743
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.004452958127703
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.789142163768133
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.724747064568412
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.316942980539663
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.583917459034328
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.534082295385316
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.936750874364467
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.1347723239722205
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.5286453076415
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.19490953803036
# D2D_SE_sum =  16.455484202179825
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  18.0451178407724
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.430897883921272
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.257626191652613
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.99384337331059
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.620713327349089
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.13943137268312
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.52882500956716
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.099625625314922
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.573163658608221
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.180969138138341
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.376426993641164
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.428632973001472
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.376846820144799
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.615272139073952
# D2D_SE_sum =  8.545558015371896
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.508121586294902
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.578318844085999
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.638037331951452
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.400771543380552
# D2D_SE_sum =  9.645350397073912
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.832830054369911
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.579901928196828
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.596132627119703
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.862393614166496
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.2664955620493
# D2D_SE_sum =  3.792369281168982
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.52864133970701
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.411993276195274
# D2D_SE_sum =  12.006149953824206
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.7804671032782995
# D2D_SE_sum =  8.412419105611512
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.842802508032792
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.177035573802149
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.929065023853532
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.297342047591258
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.965852437022318
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.649837970212065
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.636704741331839
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.852379253327609
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.202544149906084
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.05036201431938
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.830773342703175
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.619216874668856
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.639309362143964
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.646599511950452
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.081011122987375
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.892709778927252
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.4785353470314035
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.124606540280448
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.45789856476969
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.910190825996638
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.204963638279459
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.4785285126079115
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.901869289435449
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.198749991556204
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.001430516457972
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.799770063307589
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.800638207644312
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.214516349185837
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.122001129644588
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.11366596695634
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.948397279587629
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.644593522667087
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.970503819801284
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.64692437317934
# D2D_SE_sum =  3.631678621734219
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.624353865311509
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.91841758106939
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.2723270718342796
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.485135951300595
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.216590392086502
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.61095956284468
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.86867452806995
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.14465689285489
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.028208305404082
# D2D_SE_sum =  0.0
# D2D_SE_sum =  17.588651578465225
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.113619907210863
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.5506506900923505
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.606558294264419
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.48554797664032
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.656276237290754
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.825828865607015
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.278285923723523
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.295477057006934
# D2D_SE_sum =  9.85386118422543
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.280644598174312
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.573985476015483
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.7702865339911837
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.29680058406694
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.404708394736991
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.6443684839790675
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.980766288812049
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  17.001274013517744
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.355137962955725
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.40638059223315
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.831476013877861
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.180062835337651
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.130865846979525
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.7628418546870535
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  14.403624409913412
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.93707351292756
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.36636106313031
# D2D_SE_sum =  7.924098183773051
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.584066425107284
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.943887080993137
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.853800287060637
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.613976397551366
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.380552483230198
# D2D_SE_sum =  3.4960294687396463
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.542150382652369
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.317512646732319
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.883596178660137
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.4972766664552895
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.367212215002386
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.913075663365596
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.9615270580338526
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.642246457107277
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.136367912641612
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.086248079098354
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.931017500271873
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.7082063826754053
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.243026255017455
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.708680257612302
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.5135582620225714
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.178341488925974
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.755174127640657
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.7437665927719195
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.4314758361646485
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.238599115819049
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.149650491387366
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.969858091391668
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.0566483551398855
# D2D_SE_sum =  7.029170082759775
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.996445860521743
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.996325292526052
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.472566581273492
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.571198941012376
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.06600712694288
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.364505741893229
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.79096258548523
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.715004286485286
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.794318826901721
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.130404909757444
# D2D_SE_sum =  11.400613328994833
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.370635521671529
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.4485854588897755
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.707373449615764
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.365781027536777
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.058337306495906
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# ...
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.992904549103413
# D2D_SE_sum =  4.613512078875323
# D2D_SE_sum =  2.203451688260839
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.64158454329486
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.708511032978024
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.4347417730406082
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.888617605429776
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  16.61974245007267
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.393328890859455
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.998687573244773
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.9508756336551487
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.391301058581154
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.07278657932625
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.4978895924626565
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.571108915325931
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.740182682296737
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  17.165798851083643
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.6004975683709795
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.904091498323375
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.21064574740475
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.27408591353662
# D2D_SE_sum =  7.088779376452254
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.418727389106067
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.55375104129249
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.864913424195727
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.3384397944508284
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.537173271602626
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.444521169201671
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.4767438061920535
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.4598090260081396
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.563528759893375
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.9833322836591942
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.057633542302689
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.076112818943569
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.900732692360283
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.058071557620077
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.477111783132916
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.6089978169100037
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.8035700807701005
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.387204759407805
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.279846623797055
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.433155175607956
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.896619395908822
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  8.514475644168044
# D2D_SE_sum =  4.375078203724362
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.154747634029452
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.982994772342112
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.920834128832507
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.479418091122543
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.564068435664712
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  7.263291536314313
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.0639755517184666
# D2D_SE_sum =  9.47626805573013
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  15.947959195465275
# D2D_SE_sum =  0.0
# D2D_SE_sum =  13.09902024981081
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.284813244608342
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.054810715982595
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  5.104056411261695
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  16.401799137614017
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.056919717964472
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.565575313965257
# D2D_SE_sum =  4.884917910826484
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.133292507422267
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  11.126195451618555
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  12.857230030216165
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  10.262260886776321
# D2D_SE_sum =  9.283153294464475
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.8186173236068095
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  6.148383086712126
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  3.780906416252129
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.571784217366001
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  4.242355987672821
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  9.463734612859753
# D2D_SE_sum =  0.0
# D2D_SE_sum =  0.0
# D2D_SE_sum =  2.088156918638953
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/wn/zhdc_ghx1jjdzr54n3x6vmtw0000gn/T/ipykernel_18347/3986240090.py in <module>
#       5     print("p_dnn = ", p_dnn)
#       6     chan_val_rev = np.exp(chan_val * chan_std + chan_mean).detach().numpy()
# ----> 7     print(cal_rate_NP(chan_val_rev, p_dnn, tx_max, noise, DUE_thr, I_thr, P_c))
#
# /var/folders/wn/zhdc_ghx1jjdzr54n3x6vmtw0000gn/T/ipykernel_18347/1406429881.py in cal_rate_NP(channel, tx_power_in, tx_max, noise, DUE_thr, I_thr, P_c)
#      36
#      37         for j in range(num_D2D_user):
# ---> 38             DUE_mask = DUE_mask * (cur_cap[j] > DUE_thr)
#      39             if cur_cap[j] < DUE_thr:
#      40                 tot_cap_DUE_vio = tot_cap_DUE_vio + cur_cap[j]
#
# KeyboardInterrupt:

# %%
ch_mat, rx_mat, tx_mat, CUE_mat = ch_gen(Size_area, D2D_dist, Num_user, Num_channel, int(10**3))

# %%
DUE_thr = 0.1

# %%
SE_OPT, EE_OPT, CUE_vio_OPT, DUE_vio_OPT = optimal_power(ch_mat, tx_max, noise, DUE_thr, I_thr, P_c, tx_power_set)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
print(f"SE:{SE_OPT:.3}, EE:{EE_OPT*1000:.3}, Vio(CUE):{CUE_vio_OPT*100:.4}, Vio(DUE):{DUE_vio_OPT*100:.4}")
# Out:
# SE:6.53, EE:33.8, Vio(CUE):2.1, Vio(DUE):5.5
